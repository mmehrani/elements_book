# %%
import numpy as np

# %%
text_file = open('richards_book.txt',encoding="cp437")
text_file_lines = text_file.readlines()
text_file_lines
# Out:
# ['EUCLIDÆS ELEMENTS OF GEOMETRY\n',
#  'The Greek text of J.L. Heiberg (1883û1885)\n',
#  'from Euclidis Elementa, edidit et Latine interpretatus est I.L. Heiberg, in aedibus\n',
#  'B.G. Teubneri, 1883û1885\n',
#  'edited, and provided with a modern English translation, by\n',
#  'Richard Fitzpatrick\n',
#  'First edition - 2007\n',
#  'Revised and corrected - 2008\n',
#  'ISBN 978-0-6151-7984-1\n',
#  'Contents\n',
#  'Introduction 4\n',
#  'Book 1 5\n',
#  'Book 2 49\n',
#  'Book 3 69\n',
#  'Book 4 109\n',
#  'Book 5 129\n',
#  'Book 6 155\n',
#  'Book 7 193\n',
#  'Book 8 227\n',
#  'Book 9 253\n',
#  'Book 10 281\n',
#  'Book 11 423\n',
#  'Book 12 471\n',
#  'Book 13 505\n',
#  'Greek-English Lexicon 539\n',
#  'Introduction\n',
#  'EuclidÆs Elements is by far the most famous mathematical work of classical antiquity, and also has the distinction\n',
#  'of being the worldÆs oldest continuously used mathematical textbook. Little is known about the author, beyond\n',
#  'the fact that he lived in Alexandria around 300 BCE. The main subjects of the work are geometry, proportion, and\n',
#  'number theory.\n',
#  'Most of the theorems appearing in the Elements were not discovered by Euclid himself, but were the work of\n',
#  'earlier Greek mathematicians such as Pythagoras (and his school), Hippocrates of Chios, Theaetetus of Athens, and\n',
#  'Eudoxus of Cnidos. However, Euclid is generally credited with arranging these theorems in a logical manner, so as to\n',
#  'demonstrate (admittedly, not always with the rigour demanded by modern mathematics) that they necessarily follow\n',
#  'from five simple axioms. Euclid is also credited with devising a number of particularly ingenious proofs of previously\n',
#  'discovered theorems: e.g., Theorem 48 in Book 1.\n',
#  'The geometrical constructions employed in the Elements are restricted to those which can be achieved using a\n',
#  'straight-rule and a compass. Furthermore, empirical proofs by means of measurement are strictly forbidden: i.e.,\n',
#  'any comparison of two magnitudes is restricted to saying that the magnitudes are either equal, or that one is greater\n',
#  'than the other.\n',
#  'The Elements consists of thirteen books. Book 1 outlines the fundamental propositions of plane geometry, including the three cases in which triangles are congruent, various theorems involving parallel lines, the theorem regarding\n',
#  'the sum of the angles in a triangle, and the Pythagorean theorem. Book 2 is commonly said to deal with ôgeometric\n',
#  'algebraö, since most of the theorems contained within it have simple algebraic interpretations. Book 3 investigates\n',
#  'circles and their properties, and includes theorems on tangents and inscribed angles. Book 4 is concerned with regular polygons inscribed in, and circumscribed around, circles. Book 5 develops the arithmetic theory of proportion.\n',
#  'Book 6 applies the theory of proportion to plane geometry, and contains theorems on similar figures. Book 7 deals\n',
#  'with elementary number theory: e.g., prime numbers, greatest common denominators, etc. Book 8 is concerned with\n',
#  'geometric series. Book 9 contains various applications of results in the previous two books, and includes theorems\n',
#  'on the infinitude of prime numbers, as well as the sum of a geometric series. Book 10 attempts to classify incommensurable (i.e., irrational) magnitudes using the so-called ômethod of exhaustionö, an ancient precursor to integration.\n',
#  'Book 11 deals with the fundamental propositions of three-dimensional geometry. Book 12 calculates the relative\n',
#  'volumes of cones, pyramids, cylinders, and spheres using the method of exhaustion. Finally, Book 13 investigates the\n',
#  'five so-called Platonic solids.\n',
#  'This edition of EuclidÆs Elements presents the definitive Greek textùi.e., that edited by J.L. Heiberg (1883û\n',
#  '1885)ùaccompanied by a modern English translation, as well as a Greek-English lexicon. Neither the spurious\n',
#  'books 14 and 15, nor the extensive scholia which have been added to the Elements over the centuries, are included.\n',
#  'The aim of the translation is to make the mathematical argument as clear and unambiguous as possible, whilst still\n',
#  'adhering closely to the meaning of the original Greek. Text within square parenthesis (in both Greek and English)\n',
#  'indicates material identified by Heiberg as being later interpolations to the original text (some particularly obvious or\n',
#  'unhelpful interpolations have been omitted altogether). Text within round parenthesis (in English) indicates material\n',
#  'which is implied, but not actually present, in the Greek text.\n',
#  'My thanks to Mariusz Wodzicki (Berkeley) for typesetting advice, and to Sam Watson & Jonathan Fenno (U.\n',
#  'Mississippi), and Gregory Wong (UCSD) for pointing out a number of errors in Book 1.\n',
#  '4\n',
#  'ELEMENTS BOOK 1\n',
#  'Fundamentals of Plane Geometry Involving\n',
#  'Straight-Lines\n',
#  '5\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'VOroi. Definitions\n',
#  '??. ??????? ?????, ?? ????? ?????. 1. A point is that of which there is no part.\n',
#  '??. ?????? ?? ????? ???????. 2. And a line is a length without breadth.\n',
#  '??. ??????? ?? ?????? ??????. 3. And the extremities of a line are points.\n',
#  '??. ?????? ?????? ?????, ???? ?? ???? ???? ??? ?????? 4. A straight-line is (any) one which lies evenly with\n',
#  '???????? ??????. points on itself.\n',
#  '??. ?????????? ?? ?????, ? ????? ??? ?????? ????? ????. 5. And a surface is that which has length and breadth\n',
#  '??. ??????????? ?? ?????? ???????. only.\n',
#  '??. ????????? ????????? ?????, ???? ?? ???? ???? ??? 6. And the extremities of a surface are lines.\n',
#  '?????? ???????? ??????. 7. A plane surface is (any) one which lies evenly with\n',
#  '??. ????????? ?? ????? ????? ? ?? ??????? ??? ??????? the straight-lines on itself.\n',
#  '????????? ??????? ??? ?? ??? ??????? ???????? ???? 8. And a plane angle is the inclination of the lines to\n',
#  '??????? ??? ??????? ??????. one another, when two lines in a plane meet one another,\n',
#  '??. ????? ?? ?? ??????????? ??? ?????? ??????? ??????? and are not lying in a straight-line.\n',
#  '????, ??????????? ???????? ? ?????. 9. And when the lines containing the angle are\n',
#  '??. ????? ?? ?????? ??? ??????? ???????? ??? ?????? straight then the angle is called rectilinear.\n',
#  '?????? ???? ???????? ????, ???? ??????? ??? ???? ?????? 10. And when a straight-line stood upon (another)\n',
#  '????, ??? ? ?????????? ?????? ??????? ????????, ??? ?? straight-line makes adjacent angles (which are) equal to\n',
#  '?????????. one another, each of the equal angles is a right-angle, and\n',
#  '???. ???????? ????? ????? ? ?????? ?????. the former straight-line is called a perpendicular to that\n',
#  '???. ?????? ?? ? ??????? ?????. upon which it stands.\n',
#  '???. ????? ?????, ? ????? ???? ?????. 11. An obtuse angle is one greater than a right-angle.\n',
#  '???. ????? ???? ?? ??? ????? ? ????? ???? ????????????. 12. And an acute angle (is) one less than a right-angle.\n',
#  '???. ?????? ???? ????? ???????? ??? ???? ??????? 13. A boundary is that which is the extremity of some???????????? [? ???????? ??????????], ???? ?? ??? ???? thing.\n',
#  '??????? ??? ????? ??? ???????? ???????? ????? ?? 14. A figure is that which is contained by some bound????????????? ??????? [???? ??? ??? ?????? ???????????] ary or boundaries.\n',
#  '???? ???????? ?????. 15. A circle is a plane figure contained by a single line\n',
#  '???. ??????? ?? ??? ?????? ?? ??????? ????????. [which is called a circumference], (such that) all of the\n',
#  '???. ????????? ?? ??? ?????? ????? ?????? ??? ??? ??? straight-lines radiating towards [the circumference] from\n',
#  '??????? ?????? ??? ??????????? ??? ??????? ?? ???? one point amongst those lying inside the figure are equal\n',
#  '??? ??? ??? ?????? ???????????, ???? ??? ???? ?????? ??? to one another.\n',
#  '??????. 16. And the point is called the center of the circle.\n',
#  '???. ??????????? ?? ???? ?? ???????????? ????? ??? ?? 17. And a diameter of the circle is any straight-line,\n',
#  '??? ????????? ??? ??? ??????????????? ??? ????? ????- being drawn through the center, and terminated in each\n',
#  '???????. ??????? ?? ??? ?????????? ?? ????, ? ??? ??? direction by the circumference of the circle. (And) any\n',
#  '?????? ?????. such (straight-line) also cuts the circle in half.å\n',
#  '???. ??????? ?????????? ???? ?? ??? ??????? ??- 18. And a semi-circle is the figure contained by the\n',
#  '?????????, ????????? ??? ?? ??? ?????, ??????????? ?? ?? diameter and the circumference cuts off by it. And the\n',
#  '??? ????????, ?????????? ?? ?? ??? ???????? ? ???????? center of the semi-circle is the same (point) as (the center\n',
#  '??????? ???????????. of) the circle.\n',
#  '??. ??? ?? ?????????? ???????? ?????????? ??? 19. Rectilinear figures are those (figures) contained\n',
#  '???????? ???? ?? ??? ????? ???? ???? ???????, ????????? by straight-lines: trilateral figures being those contained\n',
#  '?? ?? ??? ??? ????? ???? ???? ???????, ???????? ?? ?? by three straight-lines, quadrilateral by four, and multi??? ????? ??????? ???? ???????. lateral by more than four.\n',
#  '??? ???? ?? ??? ?????????? ???????? ?????????? ??? 20. And of the trilateral figures: an equilateral trian???????? ???? ?? ???? ????? ??????, ??????????? ?? ?? gle is that having three equal sides, an isosceles (triangle)\n',
#  '???? ???????? ??????, ????????? ?? ?? ??? ????? ?????? that having only two equal sides, and a scalene (triangle)\n',
#  '???? ??????. that having three unequal sides.\n',
#  '6\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '???. ??? ?? ???????????? ???????? ?????????? ??? 21. And further of the trilateral figures: a right-angled\n',
#  '?????, ? ?????????? ?? ???? ??? ??????????, ?????????? triangle is that having a right-angle, an obtuse-angled\n',
#  '??, ? ?????????? ???, ??? ?????????? ??, ?????? ??, ? (triangle) that having an obtuse angle, and an acute?????????? ???, ??? ?????????? ??, ?????????? ?? ?? ??? angled (triangle) that having three acute angles.\n',
#  '?????????? ??????? ?? ??? ?????? ???? ???????? ????, ? 22. And of the quadrilateral figures: a square is that\n',
#  '???? ?????????? ????? ???? ??????????? ?? ?? ???? ????? which is right-angled and equilateral, a rectangle that\n',
#  '??????????? ???????? ????????. which is right-angled but not equilateral, a rhombus that\n',
#  '???. ?????????? ????? ???????, ??????? ?? ?? ???? which is equilateral but not right-angled, and a rhomboid\n',
#  '??????? ????? ??? ???????????? ??? ??????? ??? ??????? that having opposite sides and angles equal to one an?? ???? ??? ???????? ???????????? ????????. other which is neither right-angled nor equilateral. And\n',
#  'let quadrilateral figures besides these be called trapezia.\n',
#  '23. Parallel lines are straight-lines which, being in the\n',
#  'same plane, and being produced to infinity in each direction, meet with one another in neither (of these directions).\n',
#  'å This should really be counted as a postulate, rather than as part of a definition.\n',
#  'A╩t mata. Postulates\n',
#  '??. ???????? ??? ?????? ??????? ??? ??? ??????? 1. Let it have been postulatedå\n',
#  'to draw a straight-line\n',
#  '??????? ??????? ???????. from any point to any point.\n',
#  '??. ??? ???????????? ??????? ???? ?? ??????? ??? 2. And to produce a finite straight-line continuously\n',
#  '??????? ????????. in a straight-line.\n',
#  '??. ??? ????? ?????? ??? ?????????? ?????? ?????????. 3. And to draw a circle with any center and radius.\n',
#  '??. ??? ????? ??? ????? ?????? ???? ???????? ?????. 4. And that all right-angles are equal to one another.\n',
#  '??. ??? ??? ??? ??? ??????? ?????? ?????????? ??? ????? 5. And that if a straight-line falling across two (other)\n',
#  '??? ??? ?? ???? ???? ?????? ??? ????? ????????? ????, straight-lines makes internal angles on the same side\n',
#  '???????????? ??? ??? ??????? ??? ??????? ??????????, ??? (of itself whose sum is) less than two right-angles, then\n',
#  '? ???? ????? ?? ??? ??? ????? ?????????. the two (other) straight-lines, being produced to infinity,\n',
#  'meet on that side (of the original straight-line) that the\n',
#  '(sum of the internal angles) is less than two right-angles\n',
#  '(and do not meet on the other side).ç\n',
#  'å The Greek present perfect tense indicates a past action with present significance. Hence, the 3rd-person present perfect imperative >Hit sjw\n',
#  'could be translated as ôlet it be postulatedö, in the sense ôlet it stand as postulatedö, but not ôlet the postulate be now brought forwardö. The\n',
#  'literal translation ôlet it have been postulatedö sounds awkward in English, but more accurately captures the meaning of the Greek.\n',
#  'ç This postulate effectively specifies that we are dealing with the geometry of flat, rather than curved, space.\n',
#  'Koina╚ Ωnnoiai. Common Notions\n',
#  '??. ?? ?? ???? ??? ??? ???????? ????? ???. 1. Things equal to the same thing are also equal to\n',
#  '??. ??? ??? ????? ??? ????????, ?? ??? ????? ???. one another.\n',
#  '??. ??? ??? ??? ???? ??? ????????, ?? ????????????? 2. And if equal things are added to equal things then\n',
#  '????? ???. the wholes are equal.\n',
#  '??. ??? ?? ??????????? ??? ?????? ??? ???????? ?????. 3. And if equal things are subtracted from equal things\n',
#  '??. ??? ?? ???? ??? ?????? ?????? [?????]. then the remainders are equal.å\n',
#  '4. And things coinciding with one another are equal\n',
#  'to one another.\n',
#  '5. And the whole [is] greater than the part.\n',
#  'å As an obvious extension of C.N.s 2 & 3ùif equal things are added or subtracted from the two sides of an inequality then the inequality remains\n',
#  '7\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'an inequality of the same type.\n',
#  'a■. Proposition 1\n',
#  '???? ??? ???????? ??????? ???????????? ???????? To construct an equilateral triangle on a given finite\n',
#  '?????????? ???????????. straight-line.\n',
#  '? ?\n',
#  '?\n',
#  '? ? D A E B\n',
#  'C\n',
#  '????? ? ??????? ?????? ??????????? ? ??. Let AB be the given finite straight-line.\n',
#  '??? ?? ??? ??? ?? ??????? ???????? ?????????? So it is required to construct an equilateral triangle on\n',
#  '???????????. the straight-line AB.\n',
#  '?????? ??? ?? ? ?????????? ?? ?? ?? ?????? Let the circle BCD with center A and radius AB have\n',
#  '???????? ? ???, ??? ????? ?????? ??? ?? ? ?????????? ?? been drawn [Post. 3], and again let the circle ACE with\n',
#  '?? ?? ?????? ???????? ? ???, ??? ??? ??? ? ???????, center B and radius BA have been drawn [Post. 3]. And\n',
#  '???? ? ????????? ???????? ?? ??????, ??? ?? ?, ? ?????? let the straight-lines CA and CB have been joined from\n',
#  '???????????? ??????? ?? ??, ??. the point C, where the circles cut one another,å\n',
#  'to the\n',
#  '??? ???? ?? ? ??????? ??????? ???? ??? ??? ??????, points A and B (respectively) [Post. 1].\n',
#  '??? ????? ? ?? ?? ??? ?????, ???? ?? ? ??????? ??????? And since the point A is the center of the circle CDB,\n',
#  '???? ??? ??? ??????, ??? ????? ? ?? ?? ??. ??????? ?? AC is equal to AB [Def. 1.15]. Again, since the point\n',
#  '??? ? ?? ?? ?? ???? ??????? ??? ??? ??, ?? ?? ?? ????? B is the center of the circle CAE, BC is equal to BA\n',
#  '???. ?? ?? ?? ???? ??? ??? ???????? ????? ???? ??? ? ?? ??? [Def. 1.15]. But CA was also shown (to be) equal to AB.\n',
#  '?? ?? ????? ???? ?? ????? ??? ?? ??, ??, ?? ???? ???????? Thus, CA and CB are each equal to AB. But things equal\n',
#  '?????. to the same thing are also equal to one another [C.N. 1].\n',
#  '??????????? ??? ???? ?? ??? ????????. ??? ?????????? Thus, CA is also equal to CB. Thus, the three (straight??? ??? ???????? ??????? ???????????? ??? ??. ???? ???? lines) CA, AB, and BC are equal to one another.\n',
#  '???????. Thus, the triangle ABC is equilateral, and has been\n',
#  'constructed on the given finite straight-line AB. (Which\n',
#  'is) the very thing it was required to do.\n',
#  'å The assumption that the circles do indeed cut one another should be counted as an additional postulate. There is also an implicit assumption\n',
#  'that two straight-lines cannot share a common segment.\n',
#  'b■. Proposition 2å\n',
#  '???? ?? ??????? ?????? ?? ??????? ?????? ???? ??????? To place a straight-line equal to a given straight-line\n',
#  '??????. at a given point (as an extremity).\n',
#  '????? ?? ??? ????? ??????? ?? ?, ? ?? ??????? ?????? Let A be the given point, and BC the given straight? ??? ??? ?? ???? ?? ? ?????? ?? ??????? ?????? ?? ?? line. So it is required to place a straight-line at point A\n',
#  '???? ??????? ??????. equal to the given straight-line BC.\n',
#  '?????????? ??? ??? ??? ? ??????? ??? ?? ? ??????? For let the straight-line AB have been joined from\n',
#  '?????? ? ??, ??? ????????? ??? ????? ???????? ?????????? point A to point B [Post. 1], and let the equilateral trian?? ???, ??? ????????????? ??? ??????? ???? ??, ?? gle DAB have been been constructed upon it [Prop. 1.1].\n',
#  '8\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '??????? ?? ??, ??, ??? ?????? ??? ?? ? ?????????? ?? ?? And let the straight-lines AE and BF have been pro?? ?????? ???????? ? ???, ??? ????? ?????? ?? ? ??? duced in a straight-line with DA and DB (respectively)\n',
#  '?????????? ?? ?? ?????? ???????? ? ???. [Post. 2]. And let the circle CGH with center B and radius BC have been drawn [Post. 3], and again let the circle GKL with center D and radius DG have been drawn\n',
#  '[Post. 3].\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  'L\n',
#  'K\n',
#  'H\n',
#  'C\n',
#  'D\n',
#  'B\n',
#  'A\n',
#  'G\n',
#  'F\n',
#  'E\n',
#  '????? ??? ?? ? ??????? ??????? ???? ??? ???, ??? ????? Therefore, since the point B is the center of (the cir? ?? ?? ??. ?????, ???? ?? ? ??????? ??????? ???? ??? cle) CGH, BC is equal to BG [Def. 1.15]. Again, since\n',
#  '??? ??????, ??? ????? ? ?? ?? ??, ?? ? ?? ?? ?? ??? the point D is the center of the circle GKL, DL is equal\n',
#  '?????. ????? ??? ? ?? ????? ?? ?? ????? ???. ??????? ?? to DG [Def. 1.15]. And within these, DA is equal to DB.\n',
#  '??? ? ?? ?? ?? ???? ??????? ??? ??? ??, ?? ?? ?? ????? Thus, the remainder AL is equal to the remainder BG\n',
#  '???. ?? ?? ?? ???? ??? ??? ???????? ????? ???? ??? ? ?? [C.N. 3]. But BC was also shown (to be) equal to BG.\n',
#  '??? ?? ?? ????? ???. Thus, AL and BC are each equal to BG. But things equal\n',
#  '???? ??? ?? ??????? ?????? ?? ? ?? ??????? ?????? to the same thing are also equal to one another [C.N. 1].\n',
#  '?? ?? ??? ?????? ?????? ? ??? ???? ???? ???????. Thus, AL is also equal to BC.\n',
#  'Thus, the straight-line AL, equal to the given straightline BC, has been placed at the given point A. (Which\n',
#  'is) the very thing it was required to do.\n',
#  'å This proposition admits of a number of different cases, depending on the relative positions of the point A and the line BC. In such situations,\n',
#  'Euclid invariably only considers one particular caseùusually, the most difficultùand leaves the remaining cases as exercises for the reader.\n',
#  'g■. Proposition 3\n',
#  '??? ???????? ??????? ?????? ??? ??? ???????? ?? For two given unequal straight-lines, to cut off from\n',
#  '???????? ???? ??????? ???????. the greater a straight-line equal to the lesser.\n',
#  '???????? ?? ???????? ??? ??????? ?????? ?? ??, ?, ?? Let AB and C be the two given unequal straight-lines,\n',
#  '?????? ???? ? ??? ??? ?? ??? ??? ???????? ??? ?? ?? of which let the greater be AB. So it is required to cut off\n',
#  '???????? ?? ? ???? ??????? ???????. a straight-line equal to the lesser C from the greater AB.\n',
#  '?????? ???? ?? ? ?????? ?? ? ?????? ??? ? ??? ??? Let the line AD, equal to the straight-line C, have\n',
#  '?????? ??? ?? ? ?????????? ?? ?? ?? ?????? ???????? been placed at point A [Prop. 1.2]. And let the circle\n',
#  '? ???. DEF have been drawn with center A and radius AD\n',
#  '??? ???? ?? ? ??????? ??????? ???? ??? ??? ??????, [Post. 3].\n',
#  '9\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '??? ????? ? ?? ?? ??? ???? ??? ? ? ?? ?? ????? ???. And since point A is the center of circle DEF, AE\n',
#  '??????? ??? ??? ??, ? ?? ?? ????? ???? ???? ??? ? ?? is equal to AD [Def. 1.15]. But, C is also equal to AD.\n',
#  '?? ? ????? ???. Thus, AE and C are each equal to AD. So AE is also\n',
#  'equal to C [C.N. 1].\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  'E\n',
#  'D\n',
#  'C\n',
#  'A\n',
#  'F\n',
#  'B\n',
#  '??? ??? ???????? ??????? ?????? ??? ??, ? ??? ??? Thus, for two given unequal straight-lines, AB and C,\n',
#  '???????? ??? ?? ?? ???????? ?? ? ??? ???????? ? ??? ???? the (straight-line) AE, equal to the lesser C, has been cut\n',
#  '???? ???????. off from the greater AB. (Which is) the very thing it was\n',
#  'required to do.\n',
#  'd■. Proposition 4\n',
#  '???? ??? ??????? ??? ??? ??????? [????] ???? ???????? If two triangles have two sides equal to two sides, re???? ??? ???????? ??????? ??? ??? ?????? ?? ????? ???? spectively, and have the angle(s) enclosed by the equal\n',
#  '??? ??? ??? ??? ???? ??????? ????????????, ??? ??? straight-lines equal, then they will also have the base\n',
#  '????? ?? ????? ???? ????, ??? ?? ???????? ?? ??????? ???? equal to the base, and the triangle will be equal to the tri?????, ??? ?? ?????? ?????? ???? ??????? ??????? ???? ??????? angle, and the remaining angles subtended by the equal\n',
#  '??????? ???????, ??? ?? ?? ???? ??????? ????????????. sides will be equal to the corresponding remaining angles.\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '? ? ? B F\n',
#  'A\n',
#  'C E\n',
#  'D\n',
#  '????? ??? ??????? ?? ???, ??? ??? ??? ??????? Let ABC and DEF be two triangles having the two\n',
#  '??? ??, ?? ???? ???? ???????? ???? ??, ?? ???? ?????? sides AB and AC equal to the two sides DE and DF, re???????? ??????? ??? ??? ?? ?? ?? ??? ?? ?? ?? ?? spectively. (That is) AB to DE, and AC to DF. And (let)\n',
#  '??? ?????? ??? ??? ??? ????? ?? ??? ??? ????. ????, the angle BAC (be) equal to the angle EDF. I say that\n',
#  '??? ??? ????? ? ?? ????? ?? ?? ??? ?????, ??? ?? ??? the base BC is also equal to the base EF, and triangle\n',
#  '???????? ?? ??? ??????? ???? ?????, ??? ?? ?????? ?????? ABC will be equal to triangle DEF, and the remaining\n',
#  '???? ??????? ??????? ???? ??????? ??????? ???????, ??? ?? angles subtended by the equal sides will be equal to the\n',
#  '?? ???? ??????? ????????????, ? ??? ??? ??? ?? ??? ???, corresponding remaining angles. (That is) ABC to DEF,\n',
#  '? ?? ??? ??? ?? ??? ???. and ACB to DFE.\n',
#  '?????????????? ??? ??? ??? ???????? ??? ?? ??? For if triangle ABC is applied to triangle DEF,\n',
#  'å\n',
#  'the\n',
#  '???????? ??? ????????? ??? ??? ? ??????? ??? ?? ? ??????? point A being placed on the point D, and the straight-line\n',
#  '10\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '??? ?? ?? ??????? ??? ??? ??, ????????? ??? ?? ? ??????? AB on DE, then the point B will also coincide with E,\n',
#  '??? ?? ? ??? ?? ???? ????? ??? ?? ?? ??? ??????????? ?? on account of AB being equal to DE. So (because of)\n',
#  '??? ?? ??? ??? ?? ????????? ??? ? ?? ?????? ??? ??? ?? AB coinciding with DE, the straight-line AC will also\n',
#  '??? ?? ???? ????? ??? ??? ??? ?????? ?? ??? ???? ???? ??? coincide with DF, on account of the angle BAC being\n',
#  '?? ? ??????? ??? ?? ? ??????? ????????? ??? ?? ???? ????? equal to EDF. So the point C will also coincide with the\n',
#  '????? ??? ?? ?? ??. ???? ??? ??? ?? ? ??? ?? ? ?????????? point F, again on account of AC being equal to DF. But,\n',
#  '???? ????? ? ?? ??? ????? ??? ?? ?????????. ?? ??? ??? point B certainly also coincided with point E, so that the\n',
#  '??? ? ??? ?? ? ???????????? ??? ?? ? ??? ?? ? ? ?? ????? base BC will coincide with the base EF. For if B coin??? ??? ?? ??? ?????????, ??? ??????? ?????? ???????????? cides with E, and C with F, and the base BC does not\n',
#  '???? ????? ????????. ????????? ??? ? ?? ????? ??? ??? coincide with EF, then two straight-lines will encompass\n',
#  '?? ??? ??? ???? ?????? ???? ??? ???? ?? ??? ???????? an area. The very thing is impossible [Post. 1].ç Thus,\n',
#  '??? ???? ?? ??? ???????? ????????? ??? ???? ???? ?????, the base BC will coincide with EF, and will be equal to\n',
#  '??? ?? ?????? ?????? ??? ??? ?????? ?????? ??????????? ??? it [C.N. 4]. So the whole triangle ABC will coincide with\n',
#  '???? ?????? ???????, ? ??? ??? ??? ?? ??? ??? ? ?? ??? the whole triangle DEF, and will be equal to it [C.N. 4].\n',
#  '??? ?? ??? ???. And the remaining angles will coincide with the remain-\n',
#  '???? ??? ??? ??????? ??? ??? ??????? [????] ??? ing angles, and will be equal to them [C.N. 4]. (That is)\n',
#  '???????? ???? ??? ???????? ??????? ??? ??? ?????? ?? ABC to DEF, and ACB to DFE [C.N. 4].\n',
#  '????? ???? ??? ??? ??? ??? ???? ??????? ????????????, Thus, if two triangles have two sides equal to two\n',
#  '??? ??? ????? ?? ????? ???? ????, ??? ?? ???????? ?? sides, respectively, and have the angle(s) enclosed by the\n',
#  '??????? ???? ?????, ??? ?? ?????? ?????? ???? ??????? equal straight-line equal, then they will also have the base\n',
#  '??????? ???? ??????? ??????? ???????, ??? ?? ?? ???? ??????? equal to the base, and the triangle will be equal to the tri????????????? ???? ???? ??????. angle, and the remaining angles subtended by the equal\n',
#  'sides will be equal to the corresponding remaining angles. (Which is) the very thing it was required to show.\n',
#  'å The application of one figure to another should be counted as an additional postulate.\n',
#  'ç Since Post. 1 implicitly assumes that the straight-line joining two given points is unique.\n',
#  'e■. Proposition 5\n',
#  '??? ????????? ???????? ?? ???? ?? ????? ?????? ???? For isosceles triangles, the angles at the base are equal\n',
#  '???????? ?????, ??? ??????????????? ??? ???? ??????? ?? to one another, and if the equal sides are produced then\n',
#  '??? ??? ????? ?????? ???? ???????? ???????. the angles under the base will be equal to one another.\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  'B\n',
#  'D\n',
#  'F\n',
#  'C\n',
#  'G\n',
#  'A\n',
#  'E\n',
#  '????? ???????? ????????? ?? ??? ???? ???? ??? Let ABC be an isosceles triangle having the side AB\n',
#  '?? ??????? ?? ?? ??????, ??? ????????????????? ??? equal to the side AC, and let the straight-lines BD and\n',
#  '??????? ???? ??, ?? ??????? ?? ??, ??? ????, ??? ? ??? CE have been produced in a straight-line with AB and\n',
#  '??? ??? ????? ?? ??? ??? ??? ?????, ? ?? ??? ??? ?? AC (respectively) [Post. 2]. I say that the angle ABC is\n',
#  '??? ???. equal to ACB, and (angle) CBD to BCE.\n',
#  '??????? ??? ??? ??? ?? ????? ??????? ?? ?, ??? For let the point F have been taken at random on BD,\n',
#  '???????? ??? ??? ???????? ??? ?? ?? ???????? ?? ?? and let AG have been cut off from the greater AE, equal\n',
#  '11\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '??? ? ??, ??? ???????????? ?? ??, ?? ???????. to the lesser AF [Prop. 1.3]. Also, let the straight-lines\n',
#  '????? ??? ??? ????? ? ??? ?? ?? ?? ? ?? ?? ?? ??, FC and GB have been joined [Post. 1].\n',
#  '??? ?? ?? ??, ?? ???? ???? ??, ?? ???? ????? ??????? In fact, since AF is equal to AG, and AB to AC,\n',
#  '???????? ??? ?????? ?????? ?????????? ??? ??? ???? ????? the two (straight-lines) FA, AC are equal to the two\n',
#  '??? ? ?? ????? ?? ?? ??? ?????, ??? ?? ??? ???????? ?? (straight-lines) GA, AB, respectively. They also encom??? ??????? ???? ?????, ??? ?? ?????? ?????? ???? ??????? pass a common angle, FAG. Thus, the base FC is equal\n',
#  '??????? ???? ??????? ??????? ???????, ??? ?? ?? ???? ??????? to the base GB, and the triangle AFC will be equal to the\n',
#  '????????????, ? ??? ??? ??? ?? ??? ???, ? ?? ??? ??? triangle AGB, and the remaining angles subtendend by\n',
#  '?? ??? ???. ??? ???? ??? ? ?? ??? ?? ?? ????? ???, ?? the equal sides will be equal to the corresponding remain? ?? ?? ?? ????? ???, ????? ??? ? ?? ????? ?? ?? ????? ing angles [Prop. 1.4]. (That is) ACF to ABG, and AFC\n',
#  '???. ??????? ?? ??? ? ?? ?? ?? ???? ??? ?? ?? ??, ?? ???? to AGB. And since the whole of AF is equal to the whole\n',
#  '???? ??, ?? ???? ????? ??????? ???????? ??? ????? ? ??? of AG, within which AB is equal to AC, the remainder\n',
#  '??? ????? ?? ??? ??? ???, ??? ????? ????? ????? ? ??? BF is thus equal to the remainder CG [C.N. 3]. But FC\n',
#  '??? ?? ??? ??? ???????? ?? ??? ??????? ???? ?????, ??? was also shown (to be) equal to GB. So the two (straight?? ?????? ?????? ???? ??????? ??????? ???? ??????? ??????? lines) BF, FC are equal to the two (straight-lines) CG,\n',
#  '???????, ??? ?? ?? ???? ??????? ????????????? ??? ??? ????? GB, respectively, and the angle BFC (is) equal to the\n',
#  '? ??? ??? ??? ?? ??? ??? ? ?? ??? ??? ?? ??? ???. angle CGB, and the base BC is common to them. Thus,\n',
#  '???? ??? ??? ? ??? ??? ????? ??? ?? ??? ??? ????? the triangle BFC will be equal to the triangle CGB, and\n',
#  '??????? ???, ?? ? ??? ??? ?? ??? ??? ???, ????? ??? ? the remaining angles subtended by the equal sides will be\n',
#  '??? ??? ????? ?? ??? ??? ????? ???? ??? ???? ???? ?? equal to the corresponding remaining angles [Prop. 1.4].\n',
#  '????? ??? ??? ????????. ??????? ?? ??? ? ??? ??? ?? Thus, FBC is equal to GCB, and BCF to CBG. There??? ??? ???? ??? ????? ??? ??? ?????. fore, since the whole angle ABG was shown (to be) equal\n',
#  '??? ??? ????????? ???????? ?? ???? ?? ????? ?????? to the whole angle ACF, within which CBG is equal to\n',
#  '???? ???????? ?????, ??? ??????????????? ??? ???? ??????? BCF, the remainder ABC is thus equal to the remainder\n',
#  '?? ??? ??? ????? ?????? ???? ???????? ???????? ???? ???? ACB [C.N. 3]. And they are at the base of triangle ABC.\n',
#  '??????. And FBC was also shown (to be) equal to GCB. And\n',
#  'they are under the base.\n',
#  'Thus, for isosceles triangles, the angles at the base are\n',
#  'equal to one another, and if the equal sides are produced\n',
#  'then the angles under the base will be equal to one another. (Which is) the very thing it was required to show.\n',
#  '\x06■. Proposition 6\n',
#  '???? ???????? ?? ??? ?????? ???? ???????? ????, ??? If a triangle has two angles equal to one another then\n',
#  '?? ??? ??? ???? ?????? ???????????? ??????? ???? ???????? the sides subtending the equal angles will also be equal\n',
#  '???????. to one another.\n',
#  '?\n',
#  '? ?\n',
#  '? D\n',
#  'A\n',
#  'B C\n',
#  '????? ???????? ?? ??? ???? ???? ??? ??? ??? ?????? Let ABC be a triangle having the angle ABC equal\n',
#  '?? ??? ??? ?????? ????, ??? ??? ?????? ? ?? ?????? ?? to the angle ACB. I say that side AB is also equal to side\n',
#  '?? ????? ???. AC.\n',
#  '12\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '?? ??? ?????? ????? ? ?? ?? ??, ? ????? ????? ?????? For if AB is unequal to AC then one of them is\n',
#  '?????. ???? ?????? ? ??, ??? ???????? ??? ??? ???????? greater. Let AB be greater. And let DB, equal to\n',
#  '??? ?? ?? ???????? ?? ?? ??? ? ??, ??? ????????? ? ??. the lesser AC, have been cut off from the greater AB\n',
#  '????? ??? ??? ????? ? ?? ?? ?? ????? ?? ? ??, ??? ?? [Prop. 1.3]. And let DC have been joined [Post. 1].\n',
#  '?? ??, ?? ??? ???? ??, ?? ???? ????? ??????? ???????, ??? Therefore, since DB is equal to AC, and BC (is) com????? ? ??? ??? ????? ?? ??? ??? ????? ???? ????? ??? ? mon, the two sides DB, BC are equal to the two sides\n',
#  '?? ????? ?? ?? ??? ?????, ??? ?? ??? ???????? ?? ??? AC, CB, respectively, and the angle DBC is equal to the\n',
#  '??????? ???? ?????, ?? ??????? ?? ???????? ???? ??????? angle ACB. Thus, the base DC is equal to the base AB,\n',
#  '??? ??? ?????? ????? ? ?? ?? ??? ??? ???. and the triangle DBC will be equal to the triangle ACB\n',
#  '???? ??? ???????? ?? ??? ?????? ???? ???????? ????, ??? [Prop. 1.4], the lesser to the greater. The very notion (is)\n',
#  '?? ??? ??? ???? ?????? ???????????? ??????? ???? ???????? absurd [C.N. 5]. Thus, AB is not unequal to AC. Thus,\n',
#  '???????? ???? ???? ??????. (it is) equal.å\n',
#  'Thus, if a triangle has two angles equal to one another\n',
#  'then the sides subtending the equal angles will also be\n',
#  'equal to one another. (Which is) the very thing it was\n',
#  'required to show.\n',
#  'å Here, use is made of the previously unmentioned common notion that if two quantities are not unequal then they must be equal. Later on, use\n',
#  'is made of the closely related common notion that if two quantities are not greater than or less than one another, respectively, then they must be\n',
#  'equal to one another.\n',
#  'z■. Proposition 7\n',
#  '???? ??? ????? ??????? ??? ???? ?????? ???????? ????? On the same straight-line, two other straight-lines\n',
#  '??? ??????? ???? ??????? ??????? ?? ????????????? ???? equal, respectively, to two (given) straight-lines (which\n',
#  '???? ??? ???? ?????? ??? ?? ???? ???? ?? ???? ?????? meet) cannot be constructed (meeting) at a different\n',
#  '??????? ???? ?? ????? ????????. point on the same side (of the straight-line), but having\n',
#  'the same ends as the given straight-lines.\n',
#  '? ?\n',
#  '?\n',
#  '?\n',
#  'A B\n',
#  'C\n',
#  'D\n',
#  '?? ??? ???????, ??? ??? ????? ??????? ??? ?? ??? ???? For, if possible, let the two straight-lines AC, CB,\n',
#  '?????? ???????? ???? ??, ?? ????? ??? ??????? ?? ??, ?? equal to two other straight-lines AD, DB, respectively,\n',
#  '???? ??????? ??????? ???????????? ???? ???? ??? ???? have been constructed on the same straight-line AB,\n',
#  '?????? ?? ?? ? ??? ? ??? ?? ???? ???? ?? ???? ?????? meeting at different points, C and D, on the same side\n',
#  '???????, ???? ???? ????? ??? ??? ?? ?? ?? ?? ???? ????? (of AB), and having the same ends (on AB). So CA is\n',
#  '??????? ???? ?? ?, ??? ?? ?? ?? ?? ?? ???? ????? ????- equal to DA, having the same end A as it, and CB is\n',
#  '??? ???? ?? ?, ??? ????????? ? ??. equal to DB, having the same end B as it. And let CD\n',
#  '????? ??? ??? ????? ? ?? ?? ??, ??? ???? ??? ????? ? have been joined [Post. 1].\n',
#  '??? ??? ?? ??? ???? ?????? ??? ? ??? ??? ??? ??? Therefore, since AC is equal to AD, the angle ACD\n',
#  '???? ????? ??? ? ??? ??? ?????? ???? ??? ??? ???. is also equal to angle ADC [Prop. 1.5]. Thus, ADC (is)\n',
#  '????? ???? ??? ????? ? ?? ?? ??, ??? ???? ??? ????? ? greater than DCB [C.N. 5]. Thus, CDB is much greater\n',
#  '??? ??? ????? ?? ??? ???. ??????? ?? ????? ??? ????? than DCB [C.N. 5]. Again, since CB is equal to DB, the\n',
#  '??????? ???? ????? ????????. angle CDB is also equal to angle DCB [Prop. 1.5]. But\n',
#  '??? ??? ??? ??? ????? ??????? ??? ???? ?????? ???????? it was shown that the former (angle) is also much greater\n',
#  '13\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '????? ??? ??????? ???? ??????? ??????? ????????????? ???? (than the latter). The very thing is impossible.\n',
#  '???? ??? ???? ?????? ??? ?? ???? ???? ?? ???? ?????? Thus, on the same straight-line, two other straight??????? ???? ?? ????? ????????? ???? ???? ??????. lines equal, respectively, to two (given) straight-lines\n',
#  '(which meet) cannot be constructed (meeting) at a different point on the same side (of the straight-line), but\n',
#  'having the same ends as the given straight-lines. (Which\n',
#  'is) the very thing it was required to show.\n',
#  'h■. Proposition 8\n',
#  '???? ??? ??????? ??? ??? ??????? [????] ??? ???????? If two triangles have two sides equal to two sides, re???? ??? ???????? ???????, ??? ?? ??? ??? ????? ?? ????? spectively, and also have the base equal to the base, then\n',
#  '????, ??? ??? ?????? ?? ????? ???? ???? ??? ??? ??? ???? they will also have equal the angles encompassed by the\n',
#  '??????? ????????????. equal straight-lines.\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '? ?\n',
#  '?\n',
#  'D\n',
#  'G\n',
#  'B\n',
#  'E\n',
#  'F\n',
#  'C\n',
#  'A\n',
#  '????? ??? ??????? ?? ???, ??? ??? ??? ??????? Let ABC and DEF be two triangles having the two\n',
#  '??? ??, ?? ???? ??? ???????? ???? ??, ?? ???? ?????? sides AB and AC equal to the two sides DE and DF,\n',
#  '???????? ???????, ??? ??? ?? ?? ?? ??? ?? ?? ?? ??? respectively. (That is) AB to DE, and AC to DF. Let\n',
#  '????? ?? ??? ????? ??? ?? ????? ?? ?? ????? ????, ??? ??? them also have the base BC equal to the base EF. I say\n',
#  '????? ? ??? ??? ????? ?? ??? ??? ????? ???. that the angle BAC is also equal to the angle EDF.\n',
#  '?????????????? ??? ??? ??? ???????? ??? ?? ??? For if triangle ABC is applied to triangle DEF, the\n',
#  '???????? ??? ????????? ??? ??? ? ??????? ??? ?? ? ??????? point B being placed on point E, and the straight-line\n',
#  '??? ?? ?? ??????? ??? ??? ?? ????????? ??? ?? ? ??????? BC on EF, then point C will also coincide with F, on\n',
#  '??? ?? ? ??? ?? ???? ????? ??? ?? ?? ??? ??????????? ?? account of BC being equal to EF. So (because of) BC\n',
#  '??? ?? ??? ??? ?? ??????????? ??? ?? ??, ?? ??? ??? ??, coinciding with EF, (the sides) BA and CA will also co??. ?? ??? ????? ??? ? ?? ??? ????? ??? ?? ?????????, ?? incide with ED and DF (respectively). For if base BC\n',
#  '?? ??, ?? ??????? ??? ??? ??, ?? ??? ???????????? coincides with base EF, but the sides AB and AC do not\n',
#  '???? ????????????? ?? ?? ??, ??, ????????????? ??? ??? coincide with ED and DF (respectively), but miss like\n',
#  '????? ??????? ??? ???? ?????? ???????? ????? ??? ??????? EG and GF (in the above figure), then we will have con???? ??????? ??????? ???? ???? ??? ???? ?????? ??? ?? structed upon the same straight-line, two other straight???? ???? ?? ???? ?????? ???????. ?? ??????????? ??? lines equal, respectively, to two (given) straight-lines,\n',
#  '??? ??? ????????????? ??? ?? ?????? ??? ??? ?? ????? and (meeting) at a different point on the same side (of\n',
#  '??? ??????????? ??? ?? ??, ?? ??????? ??? ??? ??, ??. the straight-line), but having the same ends. But (such\n',
#  '???????????? ???? ???? ??? ????? ? ??? ??? ??? ?????? straight-lines) cannot be constructed [Prop. 1.7]. Thus,\n',
#  '??? ??? ??? ????????? ??? ??? ???? ?????. the base BC being applied to the base EF, the sides BA\n',
#  '???? ??? ??? ??????? ??? ??? ??????? [????] ??? and AC cannot not coincide with ED and DF (respec???????? ???? ??? ???????? ??????? ??? ??? ????? ?? ????? tively). Thus, they will coincide. So the angle BAC will\n',
#  '???? ???, ??? ??? ?????? ?? ????? ???? ???? ??? ??? ??? also coincide with angle EDF, and will be equal to it\n',
#  '???? ??????? ????????????? ???? ???? ??????. [C.N. 4].\n',
#  'Thus, if two triangles have two sides equal to two\n',
#  'side, respectively, and have the base equal to the base,\n',
#  '14\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'then they will also have equal the angles encompassed\n',
#  'by the equal straight-lines. (Which is) the very thing it\n',
#  'was required to show.\n',
#  'j■. Proposition 9\n',
#  '??? ???????? ?????? ??????????? ???? ??????. To cut a given rectilinear angle in half.\n',
#  '?\n',
#  '?\n',
#  '? ?\n',
#  '?\n',
#  '? F\n',
#  'D\n',
#  'B C\n',
#  'E\n',
#  'A\n',
#  '????? ? ??????? ????? ??????????? ? ??? ???. ??? Let BAC be the given rectilinear angle. So it is re?? ????? ???? ??????. quired to cut it in half.\n',
#  '??????? ??? ??? ?? ????? ??????? ?? ?, ??? ???????? Let the point D have been taken at random on AB,\n',
#  '??? ??? ?? ?? ?? ??? ? ??, ??? ????????? ? ??, ??? and let AE, equal to AD, have been cut off from AC\n',
#  '????????? ??? ??? ?? ???????? ?????????? ?? ???, ??? [Prop. 1.3], and let DE have been joined. And let the\n',
#  '????????? ? ??? ????, ??? ? ??? ??? ????? ???? ???????? equilateral triangle DEF have been constructed upon\n',
#  '??? ??? ?? ???????. DE [Prop. 1.1], and let AF have been joined. I say that\n',
#  '????? ??? ??? ????? ? ?? ?? ??, ????? ?? ? ??, ??? ?? the angle BAC has been cut in half by the straight-line\n',
#  '?? ??, ?? ???? ???? ??, ?? ???? ????? ??????? ???????. AF.\n',
#  '??? ????? ? ?? ????? ?? ?? ??? ?????? ????? ??? ? ??? For since AD is equal to AE, and AF is common,\n',
#  '??? ????? ?? ??? ??? ??? ?????. the two (straight-lines) DA, AF are equal to the two\n',
#  '?? ??? ??????? ????? ??????????? ? ??? ??? ???? (straight-lines) EA, AF, respectively. And the base DF\n',
#  '???????? ??? ??? ?? ???????? ???? ???? ???????. is equal to the base EF. Thus, angle DAF is equal to\n',
#  'angle EAF [Prop. 1.8].\n',
#  'Thus, the given rectilinear angle BAC has been cut in\n',
#  'half by the straight-line AF. (Which is) the very thing it\n',
#  'was required to do.\n',
#  'i■. Proposition 10\n',
#  '??? ???????? ??????? ???????????? ???? ??????. To cut a given finite straight-line in half.\n',
#  '????? ? ??????? ?????? ??????????? ? ??? ??? ?? ??? Let AB be the given finite straight-line. So it is re?? ??????? ???????????? ???? ??????. quired to cut the finite straight-line AB in half.\n',
#  '????????? ??? ????? ???????? ?????????? ?? ???, ??? Let the equilateral triangle ABC have been con???????? ? ??? ??? ????? ???? ?? ?? ??????? ????, ??? structed upon (AB) [Prop. 1.1], and let the angle ACB\n',
#  '? ?? ?????? ???? ???????? ???? ?? ? ???????. have been cut in half by the straight-line CD [Prop. 1.9].\n',
#  '????? ??? ??? ????? ? ?? ?? ??, ????? ?? ? ??, ??? ?? I say that the straight-line AB has been cut in half at\n',
#  '?? ??, ?? ??? ???? ??, ?? ???? ????? ??????? ???????? ??? point D.\n',
#  '????? ? ??? ??? ????? ?? ??? ??? ??? ?????? ????? ??? For since AC is equal to CB, and CD (is) common,\n',
#  '15\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '? ?? ????? ?? ?? ??? ?????. the two (straight-lines) AC, CD are equal to the two\n',
#  '(straight-lines) BC, CD, respectively. And the angle\n',
#  'ACD is equal to the angle BCD. Thus, the base AD\n',
#  'is equal to the base BD [Prop. 1.4].\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  'A B\n',
#  'D\n',
#  'C\n',
#  '?? ??? ??????? ?????? ??????????? ? ?? ???? ???????? Thus, the given finite straight-line AB has been cut\n',
#  '???? ?? ?? ???? ???? ???????. in half at (point) D. (Which is) the very thing it was\n',
#  'required to do.\n',
#  'ia■. Proposition 11\n',
#  '?? ??????? ?????? ??? ??? ???? ???? ???????? ??????? To draw a straight-line at right-angles to a given\n',
#  '???? ????? ?????? ??????? ??????? ???????. straight-line from a given point on it.\n',
#  '? ?\n',
#  '? ? ?\n',
#  '?\n',
#  'D\n',
#  'A\n',
#  'F\n',
#  'C E\n',
#  'B\n',
#  '????? ? ??? ??????? ?????? ? ?? ?? ?? ????? ??????? Let AB be the given straight-line, and C the given\n',
#  '??? ????? ?? ?? ??? ?? ??? ??? ? ??????? ?? ?? ?????? point on it. So it is required to draw a straight-line from\n',
#  '???? ????? ?????? ??????? ??????? ???????. the point C at right-angles to the straight-line AB.\n',
#  '??????? ??? ??? ?? ????? ??????? ?? ?, ??? ?????? Let the point D be have been taken at random on AC,\n',
#  '?? ?? ??? ? ??, ??? ????????? ??? ??? ?? ???????? and let CE be made equal to CD [Prop. 1.3], and let the\n',
#  '?????????? ?? ???, ??? ????????? ? ??? ????, ??? ?? equilateral triangle FDE have been constructed on DE\n',
#  '??????? ?????? ?? ?? ??? ??? ???? ???? ???????? ??????? [Prop. 1.1], and let FC have been joined. I say that the\n',
#  '??? ? ???? ????? ?????? ?????? ?????? ????? ? ??. straight-line FC has been drawn at right-angles to the\n',
#  '????? ??? ??? ????? ? ?? ?? ??, ????? ?? ? ??, ??? given straight-line AB from the given point C on it.\n',
#  '?? ?? ??, ?? ???? ???? ??, ?? ???? ????? ??????? ???????? For since DC is equal to CE, and CF is common,\n',
#  '??? ????? ? ?? ????? ?? ?? ??? ?????? ????? ??? ? ??? the two (straight-lines) DC, CF are equal to the two\n',
#  '??? ????? ?? ??? ??? ??? ?????? ??? ????? ??????. ???? (straight-lines), EC, CF, respectively. And the base DF\n',
#  '?? ?????? ??? ??????? ???????? ??? ?????? ?????? ???? is equal to the base FE. Thus, the angle DCF is equal\n',
#  '???????? ????, ???? ??????? ??? ???? ?????? ?????? ???? to the angle ECF [Prop. 1.8], and they are adjacent.\n',
#  '??? ????? ??????? ??? ??? ???, ???. But when a straight-line stood on a(nother) straight-line\n',
#  '16\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '?? ??? ??????? ?????? ?? ?? ??? ??? ???? ???? makes the adjacent angles equal to one another, each of\n',
#  '???????? ??????? ??? ? ???? ????? ?????? ?????? ?????? the equal angles is a right-angle [Def. 1.10]. Thus, each\n',
#  '????? ? ??? ???? ???? ???????. of the (angles) DCF and FCE is a right-angle.\n',
#  'Thus, the straight-line CF has been drawn at rightangles to the given straight-line AB from the given point\n',
#  'C on it. (Which is) the very thing it was required to do.\n',
#  'ib■. Proposition 12\n',
#  '???? ??? ???????? ??????? ??????? ??? ??? ???????? To draw a straight-line perpendicular to a given infi???????, ? ?? ????? ??? ?????, ??????? ??????? ??????? nite straight-line from a given point which is not on it.\n',
#  '???????.\n',
#  '?\n',
#  '? ?\n',
#  '?\n',
#  '? ?\n',
#  '?\n',
#  '?\n',
#  'D\n',
#  'A\n',
#  'G H\n',
#  'F\n',
#  'E\n',
#  'B\n',
#  'C\n',
#  '????? ? ??? ??????? ?????? ??????? ? ?? ?? ?? ????? Let AB be the given infinite straight-line and C the\n',
#  '???????, ? ?? ????? ??? ?????, ?? ?? ??? ?? ??? ??? ???????? given point, which is not on (AB). So it is required to\n',
#  '??????? ??????? ??? ?? ??? ??? ???????? ??????? ??? ?, draw a straight-line perpendicular to the given infinite\n',
#  '? ?? ????? ??? ?????, ??????? ??????? ??????? ???????. straight-line AB from the given point C, which is not on\n',
#  '??????? ??? ??? ?? ????? ???? ??? ?? ??????? ????? (AB).\n',
#  '??????? ?? ?, ??? ?????? ??? ?? ? ?????????? ?? ?? ?? For let point D have been taken at random on the\n',
#  '?????? ???????? ? ???, ??? ???????? ? ?? ?????? ???? other side (to C) of the straight-line AB, and let the\n',
#  '???? ?? ?, ??? ???????????? ?? ??, ??, ?? ???????? circle EFG have been drawn with center C and radius\n',
#  '????, ??? ??? ??? ???????? ??????? ??????? ??? ?? ??? CD [Post. 3], and let the straight-line EG have been cut\n',
#  '??? ???????? ??????? ??? ?, ? ?? ????? ??? ?????, ??????? in half at (point) H [Prop. 1.10], and let the straight????? ? ??. lines CG, CH, and CE have been joined. I say that the\n',
#  '????? ??? ??? ????? ? ?? ?? ??, ????? ?? ? ??, ??? (straight-line) CH has been drawn perpendicular to the\n',
#  '?? ?? ??, ?? ??? ???? ??, ?? ???? ????? ??????? ???????? given infinite straight-line AB from the given point C,\n',
#  '??? ????? ? ?? ????? ?? ?? ????? ???? ????? ??? ? ??? which is not on (AB).\n',
#  '??? ????? ?? ??? ??? ????? ???. ??? ????? ??????. ???? For since GH is equal to HE, and HC (is) common,\n',
#  '?? ?????? ??? ??????? ???????? ??? ?????? ?????? ???? the two (straight-lines) GH, HC are equal to the two\n',
#  '???????? ????, ???? ??????? ??? ???? ?????? ?????, ??? (straight-lines) EH, HC, respectively, and the base CG\n',
#  '? ?????????? ?????? ??????? ???????? ??? ?? ?????????. is equal to the base CE. Thus, the angle CHG is equal\n',
#  '???? ??? ???????? ??? ??????? ??????? ??? ?? ??? ??? to the angle EHC [Prop. 1.8], and they are adjacent.\n',
#  '???????? ??????? ??? ?, ? ?? ????? ??? ?????, ??????? But when a straight-line stood on a(nother) straight-line\n',
#  '????? ? ??? ???? ???? ???????. makes the adjacent angles equal to one another, each of\n',
#  'the equal angles is a right-angle, and the former straightline is called a perpendicular to that upon which it stands\n',
#  '[Def. 1.10].\n',
#  'Thus, the (straight-line) CH has been drawn perpendicular to the given infinite straight-line AB from the\n',
#  '17\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'given point C, which is not on (AB). (Which is) the very\n',
#  'thing it was required to do.\n',
#  'ig■. Proposition 13\n',
#  '???? ?????? ??? ??????? ???????? ?????? ????, ???? ??? If a straight-line stood on a(nother) straight-line\n',
#  '????? ? ????? ?????? ???? ???????. makes angles, it will certainly either make two rightangles, or (angles whose sum is) equal to two rightangles.\n',
#  '?\n',
#  '? ?\n',
#  '? ? C\n',
#  'A\n',
#  'E\n',
#  'D B\n',
#  '?????? ??? ??? ? ?? ??? ??????? ??? ?? ???????? For let some straight-line AB stood on the straight?????? ??????? ??? ??? ???, ???? ????, ??? ?? ??? ???, line CD make the angles CBA and ABD. I say that\n',
# ...
#  '????? ??? ?????? ????? ? ?? ??? ??, ?????? ?? ?? ??? equal to AB [Prop. 1.3], and let BD have been joined.\n',
#  '? ??, ??? ????????? ? ??. And since angle ADB is external to triangle BCD, it\n',
#  '??? ???? ???????? ??? ??? ????? ???? ????? ? ??? is greater than the internal and opposite (angle) DCB\n',
#  '???, ?????? ???? ??? ????? ??? ?????????? ??? ??? ???? [Prop. 1.16]. But ADB (is) equal to ABD, since side\n',
#  '??? ?? ? ??? ??? ?? ??? ???, ???? ??? ?????? ? ?? ?? AB is also equal to side AD [Prop. 1.5]. Thus, ABD is\n',
#  '?? ????? ???? ?????? ??? ??? ? ??? ??? ??? ??? ???? also greater than ACB. Thus, ABC is much greater than\n',
#  '????? ??? ? ??? ??? ?????? ???? ??? ??? ???. ACB.\n',
#  '?????? ??? ???????? ? ?????? ?????? ??? ??????? Thus, in any triangle, the greater side subtends the\n',
#  '?????? ?????????? ???? ???? ??????. greater angle. (Which is) the very thing it was required\n',
#  'to show.\n',
#  'ij■. Proposition 19\n',
#  '?????? ???????? ??? ??? ??????? ?????? ? ?????? In any triangle, the greater angle is subtended by the\n',
#  '?????? ?????????. greater side.\n',
#  '????? ???????? ?? ??? ??????? ???? ??? ??? ??? Let ABC be a triangle having the angle ABC greater\n',
#  '?????? ??? ??? ???? ????, ??? ??? ?????? ? ?? ??????? than BCA. I say that side AC is also greater than side\n',
#  '??? ?? ?????? ?????. AB.\n',
#  '22\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '?? ??? ??, ???? ??? ????? ? ?? ?? ?? ? ???????? ??? For if not, AC is certainly either equal to, or less than,\n',
#  '??? ??? ??? ????? ? ?? ?? ??? ??? ??? ?? ?? ??? ????? ? AB. In fact, AC is not equal to AB. For then angle ABC\n',
#  '??? ??? ?? ??? ???? ??? ???? ??? ??? ??? ??? ????? ? ?? would also have been equal to ACB [Prop. 1.5]. But it\n',
#  '?? ??. ???? ??? ??????? ????? ? ?? ??? ??? ??????? is not. Thus, AC is not equal to AB. Neither, indeed, is\n',
#  '??? ?? ?? ??? ????? ? ??? ??? ??? ??? ???? ??? ???? AC less than AB. For then angle ABC would also have\n',
#  '??? ??? ??? ??????? ????? ? ?? ??? ??. ??????? ??, ??? been less than ACB [Prop. 1.18]. But it is not. Thus, AC\n',
#  '???? ??? ?????. ?????? ??? ????? ? ?? ??? ??. is not less than AB. But it was shown that (AC) is not\n',
#  'equal (to AB) either. Thus, AC is greater than AB.\n',
#  '?\n',
#  '?\n',
#  '? C\n',
#  'B\n',
#  'A\n',
#  '?????? ??? ???????? ??? ??? ??????? ?????? ? ?????? Thus, in any triangle, the greater angle is subtended\n',
#  '?????? ?????????? ???? ???? ??????. by the greater side. (Which is) the very thing it was required to show.\n',
#  'k■. Proposition 20\n',
#  '?????? ???????? ?? ??? ??????? ??? ?????? ???????? In any triangle, (the sum of) two sides taken to???? ????? ????????????????. gether in any (possible way) is greater than the remaining\n',
#  '(side).\n',
#  '? ?\n',
#  '?\n',
#  '?\n',
#  'B\n',
#  'A\n',
#  'D\n',
#  'C\n',
#  '????? ??? ???????? ?? ???? ????, ??? ??? ??? For let ABC be a triangle. I say that in triangle ABC\n',
#  '???????? ?? ??? ??????? ??? ?????? ???????? ???? ????? (the sum of) two sides taken together in any (possible\n',
#  '????????????????, ?? ??? ??, ?? ??? ??, ?? ?? ??, ?? way) is greater than the remaining (side). (So), (the sum\n',
#  '??? ??, ?? ?? ??, ?? ??? ??. of) BA and AC (is greater) than BC, (the sum of) AB\n',
#  '23\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '?????? ??? ? ?? ??? ?? ? ???????, ??? ?????? ?? ?? and BC than AC, and (the sum of) BC and CA than\n',
#  '??? ? ??, ??? ????????? ? ??. AB.\n',
#  '????? ??? ??? ????? ? ?? ?? ??, ??? ???? ??? ????? For let BA have been drawn through to point D, and\n',
#  '? ??? ??? ?? ??? ???? ?????? ??? ? ??? ??? ??? ??? let AD be made equal to CA [Prop. 1.3], and let DC\n',
#  '???? ??? ???? ???????? ???? ?? ??? ??????? ???? ??? ??? have been joined.\n',
#  '??? ?????? ??? ??? ???, ??? ?? ??? ??????? ?????? ? Therefore, since DA is equal to AC, the angle ADC\n',
#  '?????? ?????? ?????????, ? ?? ??? ??? ?? ???? ??????. ??? is also equal to ACD [Prop. 1.5]. Thus, BCD is greater\n',
#  '?? ? ?? ?? ??? ???????? ??? ?? ??, ?? ??? ??? ?????? than ADC. And since DCB is a triangle having the angle\n',
#  '?? ????????, ??? ??? ?? ??? ??, ?? ??? ?? ???????? ?????, BCD greater than BDC, and the greater angle subtends\n',
#  '?? ?? ??, ?? ??? ??. the greater side [Prop. 1.19], DB is thus greater than\n',
#  '?????? ??? ???????? ?? ??? ??????? ??? ?????? BC. But DA is equal to AC. Thus, (the sum of) BA and\n',
#  '???????? ???? ????? ????????????????? ???? ???? ??????. AC is greater than BC. Similarly, we can show that (the\n',
#  'sum of) AB and BC is also greater than CA, and (the\n',
#  'sum of) BC and CA than AB.\n',
#  'Thus, in any triangle, (the sum of) two sides taken together in any (possible way) is greater than the remaining\n',
#  '(side). (Which is) the very thing it was required to show.\n',
#  'ka■. Proposition 21\n',
#  '???? ???????? ??? ???? ??? ??????? ??? ??? ??????? If two internal straight-lines are constructed on one\n',
#  '??? ??????? ????? ??????????, ?? ??????????? ??? ?????? of the sides of a triangle, from its ends, the constructed\n',
#  '??? ???????? ??? ??????? ????????? ??? ???????, ??????? (straight-lines) will be less than the two remaining sides\n',
#  '?? ?????? ???????????. of the triangle, but will encompass a greater angle.\n',
#  '? ?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  'B\n',
#  'A\n',
#  'E\n',
#  'C\n',
#  'D\n',
#  '???????? ??? ??? ??? ??? ???? ??? ??????? ??? ?? For let the two internal straight-lines BD and DC\n',
#  '??? ??? ??????? ??? ?, ? ??? ??????? ????? ???????????? have been constructed on one of the sides BC of the tri?? ??, ??? ????, ??? ?? ??, ?? ??? ?????? ??? ???????? angle ABC, from its ends B and C (respectively). I say\n',
#  '??? ??????? ??? ??, ?? ????????? ??? ?????, ??????? ?? that BD and DC are less than the (sum of the) two re?????? ?????????? ??? ??? ??? ??? ??? ???. maining sides of the triangle BA and AC, but encompass\n',
#  '?????? ??? ? ?? ??? ?? ?. ??? ???? ?????? ???????? an angle BDC greater than BAC.\n',
#  '?? ??? ??????? ??? ?????? ???????? ?????, ??? ??? ??? For let BD have been drawn through to E. And since\n',
#  '???????? ?? ??? ??????? ?? ??, ?? ??? ?? ???????? in any triangle (the sum of any) two sides is greater than\n',
#  '?????? ????? ?????????? ? ??? ?? ??? ??, ?? ??? ??, the remaining (side) [Prop. 1.20], in triangle ABE the\n',
#  '?? ???????? ?????. ?????, ???? ??? ??? ???????? ?? ??? (sum of the) two sides AB and AE is thus greater than\n',
#  '??????? ?? ??, ?? ??? ?? ???????? ?????, ????? ?????????? BE. Let EC have been added to both. Thus, (the sum\n',
#  '? ??? ?? ??, ?? ??? ??? ??, ?? ???????? ?????. ???? of) BA and AC is greater than (the sum of) BE and EC.\n',
#  '??? ??, ?? ???????? ?????????? ?? ??, ??? ????? ??? ?? Again, since in triangle CED the (sum of the) two sides\n',
#  '??, ?? ??? ??, ?? ???????? ?????. CE and ED is greater than CD, let DB have been added\n',
#  '?????, ???? ?????? ???????? ? ????? ????? ??? ????? to both. Thus, (the sum of) CE and EB is greater than\n',
#  '??? ?????????? ?????? ?????, ??? ??? ??? ???????? ? (the sum of) CD and DB. But, (the sum of) BA and\n',
#  '????? ????? ? ??? ??? ?????? ???? ??? ??? ???. ??? AC was shown (to be) greater than (the sum of) BE and\n',
#  '????? ?????? ??? ??? ??? ???????? ? ????? ????? ? ??? EC. Thus, (the sum of) BA and AC is much greater than\n',
#  '24\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '??? ?????? ???? ??? ??? ???. ???? ??? ??? ??? ?????? (the sum of) BD and DC.\n',
#  '??????? ? ??? ???? ????? ??? ? ??? ??? ?????? ???? Again, since in any triangle the external angle is\n',
#  '??? ??? ???. greater than the internal and opposite (angles) [Prop.\n',
#  '???? ??? ???????? ??? ???? ??? ??????? ??? ??? 1.16], in triangle CDE the external angle BDC is thus\n',
#  '??????? ??? ??????? ????? ??????????, ?? ??????????? ??? greater than CED. Accordingly, for the same (reason),\n',
#  '?????? ??? ???????? ??? ??????? ????????? ??? ?????, the external angle CEB of the triangle ABE is also\n',
#  '??????? ?? ?????? ???????????? ???? ???? ??????. greater than BAC. But, BDC was shown (to be) greater\n',
#  'than CEB. Thus, BDC is much greater than BAC.\n',
#  'Thus, if two internal straight-lines are constructed on\n',
#  'one of the sides of a triangle, from its ends, the constructed (straight-lines) are less than the two remaining sides of the triangle, but encompass a greater angle.\n',
#  '(Which is) the very thing it was required to show.\n',
#  'kb■. Proposition 22\n',
#  '??? ????? ???????, ?? ????? ???? ????? ???? ????????? To construct a triangle from three straight-lines which\n',
#  '[????????], ???????? ???????????? ??? ?? ??? ??? ??? ?????? are equal to three given [straight-lines]. It is necessary\n',
#  '???????? ????? ????? ???????????????? [??? ?? ??? ?????? for (the sum of) two (of the straight-lines) taken together\n',
#  '???????? ??? ??? ??????? ??? ?????? ???????? ????? ????? in any (possible way) to be greater than the remaining\n',
#  '????????????????]. (one), [on account of the (fact that) in any triangle (the\n',
#  'sum of) two sides taken together in any (possible way) is\n',
#  'greater than the remaining (one) [Prop. 1.20] ].\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '? ? H\n',
#  'A\n',
#  'B\n',
#  'C\n',
#  'D\n',
#  'F\n',
#  'E\n',
#  'K\n',
#  'L\n',
#  'G\n',
#  '???????? ?? ???????? ????? ??????? ?? ?, ?, ?, ?? ?? Let A, B, and C be the three given straight-lines, of\n',
#  '??? ??? ?????? ???????? ??????? ????? ????????????????, which let (the sum of) two taken together in any (possible\n',
#  '?? ??? ?, ? ??? ?, ?? ?? ?, ? ??? ?, ??? ??? ?? ?, ? ??? ?? way) be greater than the remaining (one). (Thus), (the\n',
#  '??? ?? ?? ??? ???? ???? ?, ?, ? ???????? ???????????. sum of) A and B (is greater) than C, (the sum of) A and\n',
#  '????????? ??? ?????? ? ?? ??????????? ??? ???? ?? C than B, and also (the sum of) B and C than A. So\n',
#  '? ??????? ?? ???? ?? ?, ??? ?????? ?? ??? ? ??? ? ??, it is required to construct a triangle from (straight-lines)\n',
#  '?? ?? ? ??? ? ??, ?? ?? ? ??? ? ??? ??? ?????? ??? ?? equal to A, B, and C.\n',
#  '?, ?????????? ?? ?? ?? ?????? ???????? ? ???? ????? Let some straight-line DE be set out, terminated at D,\n',
#  '?????? ??? ?? ?, ?????????? ?? ?? ?? ?????? ???????? and infinite in the direction of E. And let DF made equal\n',
#  '? ???, ??? ???????????? ?? ??, ??? ????, ??? ?? ????? to A, and FG equal to B, and GH equal to C [Prop. 1.3].\n',
#  '??????? ??? ???? ???? ?, ?, ? ???????? ?????????? ?? And let the circle DKL have been drawn with center F\n',
#  '???. and radius FD. Again, let the circle KLH have been\n',
#  '????? ??? ?? ? ??????? ??????? ???? ??? ??? ??????, drawn with center G and radius GH. And let KF and\n',
#  '??? ????? ? ?? ?? ??? ???? ? ?? ?? ? ????? ???. ??? ? KG have been joined. I say that the triangle KFG has\n',
#  '25\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '?? ??? ?? ? ????? ???. ?????, ???? ?? ? ??????? ??????? been constructed from three straight-lines equal to A, B,\n',
#  '???? ??? ??? ??????, ??? ????? ? ?? ?? ??? ???? ? ?? and C.\n',
#  '?? ? ????? ???? ??? ? ?? ??? ?? ? ????? ???. ???? ?? ??? ? For since point F is the center of the circle DKL, FD\n',
#  '?? ?? ? ???? ?? ????? ??? ??????? ?? ??, ??, ?? ????? ???? is equal to FK. But, FD is equal to A. Thus, KF is also\n',
#  '?, ?, ? ???? ?????. equal to A. Again, since point G is the center of the circle\n',
#  '??? ????? ??? ??????? ??? ??, ??, ??, ?? ????? LKH, GH is equal to GK. But, GH is equal to C. Thus,\n',
#  '???? ????? ???? ????????? ???????? ???? ?, ?, ?, ???????? KG is also equal to C. And FG is also equal to B. Thus,\n',
#  '?????????? ?? ???? ???? ???? ???????. the three straight-lines KF, FG, and GK are equal to A,\n',
#  'B, and C (respectively).\n',
#  'Thus, the triangle KFG has been constructed from\n',
#  'the three straight-lines KF, FG, and GK, which are\n',
#  'equal to the three given straight-lines A, B, and C (respectively). (Which is) the very thing it was required to\n',
#  'do.\n',
#  'kg■. Proposition 23\n',
#  '???? ?? ??????? ?????? ??? ?? ???? ???? ?????? To construct a rectilinear angle equal to a given recti?? ??????? ????? ?????????? ???? ?????? ??????????? linear angle at a (given) point on a given straight-line.\n',
#  '???????????.\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '? ? ?\n',
#  'C\n',
#  'G A\n',
#  'F\n',
#  'B\n',
#  'E\n',
#  'D\n',
#  '????? ? ??? ??????? ?????? ? ??, ?? ?? ???? ???? Let AB be the given straight-line, A the (given) point\n',
#  '??????? ?? ?, ? ?? ??????? ????? ??????????? ? ??? ???? on it, and DCE the given rectilinear angle. So it is re??? ?? ???? ?? ??????? ?????? ?? ?? ??? ?? ???? ???? quired to construct a rectilinear angle equal to the given\n',
#  '?????? ?? ? ?? ??????? ????? ?????????? ?? ??? ??? rectilinear angle DCE at the (given) point A on the given\n',
#  '???? ?????? ??????????? ???????????. straight-line AB.\n',
#  '??????? ??? ???????? ??? ??, ?? ??????? ?????? ?? Let the points D and E have been taken at random\n',
#  '?, ?, ??? ????????? ? ??? ??? ?? ????? ???????, ?? ????? on each of the (straight-lines) CD and CE (respectively),\n',
#  '???? ????? ???? ??, ??, ??, ???????? ????????? ?? ???, and let DE have been joined. And let the triangle AFG\n',
#  '???? ???? ????? ??? ??? ?? ?? ??, ??? ?? ?? ?? ??, ??? have been constructed from three straight-lines which are\n',
#  '??? ??? ?? ?? ??. equal to CD, DE, and CE, such that CD is equal to AF,\n',
#  '????? ??? ??? ?? ??, ?? ??? ???? ??, ?? ???? ????? CE to AG, and further DE to FG [Prop. 1.22].\n',
#  '??????? ???????, ??? ????? ? ?? ????? ?? ?? ???, ????? Therefore, since the two (straight-lines) DC, CE are\n',
#  '??? ? ??? ??? ????? ?? ??? ??? ????? ???. equal to the two (straight-lines) FA, AG, respectively,\n',
#  '???? ??? ?? ??????? ?????? ?? ?? ??? ?? ???? ???? and the base DE is equal to the base FG, the angle DCE\n',
#  '?????? ?? ? ?? ??????? ????? ?????????? ?? ??? ??? is thus equal to the angle FAG [Prop. 1.8].\n',
#  '??? ????? ??????????? ?????????? ? ??? ???? ???? ???? Thus, the rectilinear angle FAG, equal to the given\n',
#  '???????. rectilinear angle DCE, has been constructed at the\n',
#  '(given) point A on the given straight-line AB. (Which\n',
#  '26\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'is) the very thing it was required to do.\n',
#  'kd■. Proposition 24\n',
#  '???? ??? ??????? ??? ??? ??????? [????] ??? ???????? If two triangles have two sides equal to two sides, re???? ??? ???????? ???????, ??? ?? ?????? ??? ?????? spectively, but (one) has the angle encompassed by the\n',
#  '??????? ??? ??? ??? ??? ???? ??????? ????????????, ??? equal straight-lines greater than the (corresponding) an??? ????? ??? ?????? ??????? ????. gle (in the other), then (the former triangle) will also\n',
#  'have a base greater than the base (of the latter).\n',
#  '?\n',
#  '?\n',
#  '?\n',
#  '? ?\n',
#  '? ? F\n',
#  'A\n',
#  'C\n',
#  'B\n',
#  'D\n',
#  'E\n',
#  'G\n',
#  '????? ??? ??????? ?? ???, ??? ??? ??? ??????? Let ABC and DEF be two triangles having the two\n',
#  '??? ??, ?? ???? ??? ???????? ???? ??, ?? ???? ?????? sides AB and AC equal to the two sides DE and DF,\n',
#  '???????? ???????, ??? ??? ?? ?? ?? ??? ?? ?? ?? ??, ? respectively. (That is), AB (equal) to DE, and AC to\n',
#  '?? ???? ?? ? ????? ??? ???? ?? ? ?????? ?????? ????? DF. Let them also have the angle at A greater than the\n',
#  '????, ??? ??? ????? ? ?? ?????? ??? ?? ?????? ?????. angle at D. I say that the base BC is also greater than\n',
#  '????? ??? ?????? ? ??? ??? ????? ??? ??? ??? the base EF.\n',
#  '??????, ????????? ???? ?? ?? ?????? ??? ?? ???? ???? For since angle BAC is greater than angle EDF,\n',
#  '?????? ?? ? ?? ??? ??? ????? ??? ? ??? ???, ??? ?????? let (angle) EDG, equal to angle BAC, have been\n',
#  '??????? ??? ??, ?? ??? ? ??, ??? ???????????? ?? ??, constructed at the point D on the straight-line DE\n',
#  '??. [Prop. 1.23]. And let DG be made equal to either of\n',
#  '????? ??? ??? ????? ? ??? ?? ?? ??, ? ?? ?? ?? ??, AC or DF [Prop. 1.3], and let EG and FG have been\n',
#  '??? ?? ?? ??, ?? ???? ???? ??, ?? ???? ????? ??????? joined.\n',
#  ...]

# %% [markdown]
# # Cleaning the text from greek letters

# %%
for i in range(len(text_file_lines)):
    text_file_lines[i] = text_file_lines[i].replace('?','')
    text_file_lines[i] = text_file_lines[i].replace('  ','')

while '\n' in text_file_lines:
    text_file_lines.remove('\n')
text_file_lines
# Out:
# ['EUCLIDÆS ELEMENTS OF GEOMETRY\n',
#  'The Greek text of J.L. Heiberg (1883û1885)\n',
#  'from Euclidis Elementa, edidit et Latine interpretatus est I.L. Heiberg, in aedibus\n',
#  'B.G. Teubneri, 1883û1885\n',
#  'edited, and provided with a modern English translation, by\n',
#  'Richard Fitzpatrick\n',
#  'First edition - 2007\n',
#  'Revised and corrected - 2008\n',
#  'ISBN 978-0-6151-7984-1\n',
#  'Contents\n',
#  'Introduction 4\n',
#  'Book 1 5\n',
#  'Book 2 49\n',
#  'Book 3 69\n',
#  'Book 4 109\n',
#  'Book 5 129\n',
#  'Book 6 155\n',
#  'Book 7 193\n',
#  'Book 8 227\n',
#  'Book 9 253\n',
#  'Book 10 281\n',
#  'Book 11 423\n',
#  'Book 12 471\n',
#  'Book 13 505\n',
#  'Greek-English Lexicon 539\n',
#  'Introduction\n',
#  'EuclidÆs Elements is by far the most famous mathematical work of classical antiquity, and also has the distinction\n',
#  'of being the worldÆs oldest continuously used mathematical textbook. Little is known about the author, beyond\n',
#  'the fact that he lived in Alexandria around 300 BCE. The main subjects of the work are geometry, proportion, and\n',
#  'number theory.\n',
#  'Most of the theorems appearing in the Elements were not discovered by Euclid himself, but were the work of\n',
#  'earlier Greek mathematicians such as Pythagoras (and his school), Hippocrates of Chios, Theaetetus of Athens, and\n',
#  'Eudoxus of Cnidos. However, Euclid is generally credited with arranging these theorems in a logical manner, so as to\n',
#  'demonstrate (admittedly, not always with the rigour demanded by modern mathematics) that they necessarily follow\n',
#  'from five simple axioms. Euclid is also credited with devising a number of particularly ingenious proofs of previously\n',
#  'discovered theorems: e.g., Theorem 48 in Book 1.\n',
#  'The geometrical constructions employed in the Elements are restricted to those which can be achieved using a\n',
#  'straight-rule and a compass. Furthermore, empirical proofs by means of measurement are strictly forbidden: i.e.,\n',
#  'any comparison of two magnitudes is restricted to saying that the magnitudes are either equal, or that one is greater\n',
#  'than the other.\n',
#  'The Elements consists of thirteen books. Book 1 outlines the fundamental propositions of plane geometry, including the three cases in which triangles are congruent, various theorems involving parallel lines, the theorem regarding\n',
#  'the sum of the angles in a triangle, and the Pythagorean theorem. Book 2 is commonly said to deal with ôgeometric\n',
#  'algebraö, since most of the theorems contained within it have simple algebraic interpretations. Book 3 investigates\n',
#  'circles and their properties, and includes theorems on tangents and inscribed angles. Book 4 is concerned with regular polygons inscribed in, and circumscribed around, circles. Book 5 develops the arithmetic theory of proportion.\n',
#  'Book 6 applies the theory of proportion to plane geometry, and contains theorems on similar figures. Book 7 deals\n',
#  'with elementary number theory: e.g., prime numbers, greatest common denominators, etc. Book 8 is concerned with\n',
#  'geometric series. Book 9 contains various applications of results in the previous two books, and includes theorems\n',
#  'on the infinitude of prime numbers, as well as the sum of a geometric series. Book 10 attempts to classify incommensurable (i.e., irrational) magnitudes using the so-called ômethod of exhaustionö, an ancient precursor to integration.\n',
#  'Book 11 deals with the fundamental propositions of three-dimensional geometry. Book 12 calculates the relative\n',
#  'volumes of cones, pyramids, cylinders, and spheres using the method of exhaustion. Finally, Book 13 investigates the\n',
#  'five so-called Platonic solids.\n',
#  'This edition of EuclidÆs Elements presents the definitive Greek textùi.e., that edited by J.L. Heiberg (1883û\n',
#  '1885)ùaccompanied by a modern English translation, as well as a Greek-English lexicon. Neither the spurious\n',
#  'books 14 and 15, nor the extensive scholia which have been added to the Elements over the centuries, are included.\n',
#  'The aim of the translation is to make the mathematical argument as clear and unambiguous as possible, whilst still\n',
#  'adhering closely to the meaning of the original Greek. Text within square parenthesis (in both Greek and English)\n',
#  'indicates material identified by Heiberg as being later interpolations to the original text (some particularly obvious or\n',
#  'unhelpful interpolations have been omitted altogether). Text within round parenthesis (in English) indicates material\n',
#  'which is implied, but not actually present, in the Greek text.\n',
#  'My thanks to Mariusz Wodzicki (Berkeley) for typesetting advice, and to Sam Watson & Jonathan Fenno (U.\n',
#  'Mississippi), and Gregory Wong (UCSD) for pointing out a number of errors in Book 1.\n',
#  '4\n',
#  'ELEMENTS BOOK 1\n',
#  'Fundamentals of Plane Geometry Involving\n',
#  'Straight-Lines\n',
#  '5\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'VOroi. Definitions\n',
#  '., . 1. A point is that of which there is no part.\n',
#  '.. 2. And a line is a length without breadth.\n',
#  '.. 3. And the extremities of a line are points.\n',
#  '. , 4. A straight-line is (any) one which lies evenly with\n',
#  ' . points on itself.\n',
#  '. ,. 5. And a surface is that which has length and breadth\n',
#  '.. only.\n',
#  '. ,6. And the extremities of a surface are lines.\n',
#  '. 7. A plane surface is (any) one which lies evenly with\n',
#  '.the straight-lines on itself.\n',
#  '8. And a plane angle is the inclination of the lines to\n',
#  ' . one another, when two lines in a plane meet one another,\n',
#  '. and are not lying in a straight-line.\n',
#  ',. 9. And when the lines containing the angle are\n',
#  '. straight then the angle is called rectilinear.\n',
#  ' ,10. And when a straight-line stood upon (another)\n',
#  ',, straight-line makes adjacent angles (which are) equal to\n',
#  '. one another, each of the equal angles is a right-angle, and\n',
#  '.. the former straight-line is called a perpendicular to that\n',
#  '. . upon which it stands.\n',
#  '.,. 11. An obtuse angle is one greater than a right-angle.\n',
#  '. . 12. And an acute angle (is) one less than a right-angle.\n',
#  '.13. A boundary is that which is the extremity of some [], thing.\n',
#  '14. A figure is that which is contained by some bound[] ary or boundaries.\n',
#  '. 15. A circle is a plane figure contained by a single line\n',
#  '. . [which is called a circumference], (such that) all of the\n',
#  '.straight-lines radiating towards [the circumference] from\n',
#  'one point amongst those lying inside the figure are equal\n',
#  ',to one another.\n',
#  '. 16. And the point is called the center of the circle.\n',
#  '. 17. And a diameter of the circle is any straight-line,\n',
#  ' - being drawn through the center, and terminated in each\n',
#  '.,direction by the circumference of the circle. (And) any\n',
#  ' . such (straight-line) also cuts the circle in half.å\n',
#  '. - 18. And a semi-circle is the figure contained by the\n',
#  ', ,diameter and the circumference cuts off by it. And the\n',
#  ' ,center of the semi-circle is the same (point) as (the center\n',
#  ' . of) the circle.\n',
#  '. 19. Rectilinear figures are those (figures) contained\n',
#  ' ,by straight-lines: trilateral figures being those contained\n',
#  ' ,by three straight-lines, quadrilateral by four, and multi. lateral by more than four.\n',
#  '20. And of the trilateral figures: an equilateral trian ,gle is that having three equal sides, an isosceles (triangle)\n',
#  ', that having only two equal sides, and a scalene (triangle)\n',
#  ' . that having three unequal sides.\n',
#  '6\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '. 21. And further of the trilateral figures: a right-angled\n',
#  ',,triangle is that having a right-angle, an obtuse-angled\n',
#  ', , ,,(triangle) that having an obtuse angle, and an acute , , angled (triangle) that having three acute angles.\n',
#  ' ,22. And of the quadrilateral figures: a square is that\n',
#  ' which is right-angled and equilateral, a rectangle that\n',
#  '. which is right-angled but not equilateral, a rhombus that\n',
#  '. , which is equilateral but not right-angled, and a rhomboid\n',
#  'that having opposite sides and angles equal to one an . other which is neither right-angled nor equilateral. And\n',
#  'let quadrilateral figures besides these be called trapezia.\n',
#  '23. Parallel lines are straight-lines which, being in the\n',
#  'same plane, and being produced to infinity in each direction, meet with one another in neither (of these directions).\n',
#  'å This should really be counted as a postulate, rather than as part of a definition.\n',
#  'A╩t mata. Postulates\n',
#  '.1. Let it have been postulatedå\n',
#  'to draw a straight-line\n',
#  '. from any point to any point.\n',
#  '.2. And to produce a finite straight-line continuously\n',
#  ' . in a straight-line.\n',
#  '. . 3. And to draw a circle with any center and radius.\n',
#  '.. 4. And that all right-angles are equal to one another.\n',
#  '.5. And that if a straight-line falling across two (other)\n',
#  ' , straight-lines makes internal angles on the same side\n',
#  ',(of itself whose sum is) less than two right-angles, then\n',
#  ' . the two (other) straight-lines, being produced to infinity,\n',
#  'meet on that side (of the original straight-line) that the\n',
#  '(sum of the internal angles) is less than two right-angles\n',
#  '(and do not meet on the other side).ç\n',
#  'å The Greek present perfect tense indicates a past action with present significance. Hence, the 3rd-person present perfect imperative >Hit sjw\n',
#  'could be translated as ôlet it be postulatedö, in the sense ôlet it stand as postulatedö, but not ôlet the postulate be now brought forwardö. The\n',
#  'literal translation ôlet it have been postulatedö sounds awkward in English, but more accurately captures the meaning of the Greek.\n',
#  'ç This postulate effectively specifies that we are dealing with the geometry of flat, rather than curved, space.\n',
#  'Koina╚ Ωnnoiai. Common Notions\n',
#  '.. 1. Things equal to the same thing are also equal to\n',
#  '. ,. one another.\n',
#  '., 2. And if equal things are added to equal things then\n',
#  ' . the wholes are equal.\n',
#  '.. 3. And if equal things are subtracted from equal things\n',
#  '. []. then the remainders are equal.å\n',
#  '4. And things coinciding with one another are equal\n',
#  'to one another.\n',
#  '5. And the whole [is] greater than the part.\n',
#  'å As an obvious extension of C.N.s 2 & 3ùif equal things are added or subtracted from the two sides of an inequality then the inequality remains\n',
#  '7\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'an inequality of the same type.\n',
#  'a■. Proposition 1\n',
#  'To construct an equilateral triangle on a given finite\n',
#  ' . straight-line.\n',
#  ' \n',
#  'D A E B\n',
#  'C\n',
#  '. Let AB be the given finite straight-line.\n',
#  'So it is required to construct an equilateral triangle on\n',
#  '. the straight-line AB.\n',
#  ' Let the circle BCD with center A and radius AB have\n',
#  ', been drawn [Post. 3], and again let the circle ACE with\n',
#  ' , , center B and radius BA have been drawn [Post. 3]. And\n',
#  ' , , let the straight-lines CA and CB have been joined from\n',
#  ' , . the point C, where the circles cut one another,å\n',
#  'to the\n',
#  ' , points A and B (respectively) [Post. 1].\n',
#  ',And since the point A is the center of the circle CDB,\n',
#  ' ,. AC is equal to AB [Def. 1.15]. Again, since the point\n',
#  ' , B is the center of the circle CAE, BC is equal to BA\n',
#  '.[Def. 1.15]. But CA was also shown (to be) equal to AB.\n',
#  ', ,Thus, CA and CB are each equal to AB. But things equal\n',
#  '. to the same thing are also equal to one another [C.N. 1].\n',
#  ' . Thus, CA is also equal to CB. Thus, the three (straight. lines) CA, AB, and BC are equal to one another.\n',
#  '. Thus, the triangle ABC is equilateral, and has been\n',
#  'constructed on the given finite straight-line AB. (Which\n',
#  'is) the very thing it was required to do.\n',
#  'å The assumption that the circles do indeed cut one another should be counted as an additional postulate. There is also an implicit assumption\n',
#  'that two straight-lines cannot share a common segment.\n',
#  'b■. Proposition 2å\n',
#  ' To place a straight-line equal to a given straight-line\n',
#  '. at a given point (as an extremity).\n',
#  ', Let A be the given point, and BC the given straight line. So it is required to place a straight-line at point A\n',
#  '. equal to the given straight-line BC.\n',
#  'For let the straight-line AB have been joined from\n',
#  ', point A to point B [Post. 1], and let the equilateral trian ,,gle DAB have been been constructed upon it [Prop. 1.1].\n',
#  '8\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ', , And let the straight-lines AE and BF have been pro, duced in a straight-line with DA and DB (respectively)\n',
#  '. [Post. 2]. And let the circle CGH with center B and radius BC have been drawn [Post. 3], and again let the circle GKL with center D and radius DG have been drawn\n',
#  '[Post. 3].\n',
#  'L\n',
#  'K\n',
#  'H\n',
#  'C\n',
#  'D\n',
#  'B\n',
#  'A\n',
#  'G\n',
#  'F\n',
#  'E\n',
#  ', Therefore, since the point B is the center of (the cir . ,cle) CGH, BC is equal to BG [Def. 1.15]. Again, since\n',
#  ' ,, the point D is the center of the circle GKL, DL is equal\n',
#  '. . to DG [Def. 1.15]. And within these, DA is equal to DB.\n',
#  ' , Thus, the remainder AL is equal to the remainder BG\n',
#  '. [C.N. 3]. But BC was also shown (to be) equal to BG.\n',
#  '. Thus, AL and BC are each equal to BG. But things equal\n',
#  'to the same thing are also equal to one another [C.N. 1].\n',
#  ' . Thus, AL is also equal to BC.\n',
#  'Thus, the straight-line AL, equal to the given straightline BC, has been placed at the given point A. (Which\n',
#  'is) the very thing it was required to do.\n',
#  'å This proposition admits of a number of different cases, depending on the relative positions of the point A and the line BC. In such situations,\n',
#  'Euclid invariably only considers one particular caseùusually, the most difficultùand leaves the remaining cases as exercises for the reader.\n',
#  'g■. Proposition 3\n',
#  'For two given unequal straight-lines, to cut off from\n',
#  ' . the greater a straight-line equal to the lesser.\n',
#  ' , ,Let AB and C be the two given unequal straight-lines,\n',
#  'of which let the greater be AB. So it is required to cut off\n',
#  ' . a straight-line equal to the lesser C from the greater AB.\n',
#  'Let the line AD, equal to the straight-line C, have\n',
#  'been placed at point A [Prop. 1.2]. And let the circle\n',
#  ' . DEF have been drawn with center A and radius AD\n',
#  ' , [Post. 3].\n',
#  '9\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' . And since point A is the center of circle DEF, AE\n',
#  ' ,is equal to AD [Def. 1.15]. But, C is also equal to AD.\n',
#  ' . Thus, AE and C are each equal to AD. So AE is also\n',
#  'equal to C [C.N. 1].\n',
#  'E\n',
#  'D\n',
#  'C\n',
#  'A\n',
#  'F\n',
#  'B\n',
#  ',Thus, for two given unequal straight-lines, AB and C,\n',
#  'the (straight-line) AE, equal to the lesser C, has been cut\n',
#  ' . off from the greater AB. (Which is) the very thing it was\n',
#  'required to do.\n',
#  'd■. Proposition 4\n',
#  '[] If two triangles have two sides equal to two sides, respectively, and have the angle(s) enclosed by the equal\n',
#  ', straight-lines equal, then they will also have the base\n',
#  ', equal to the base, and the triangle will be equal to the tri,angle, and the remaining angles subtended by the equal\n',
#  ' ,. sides will be equal to the corresponding remaining angles.\n',
#  ' B F\n',
#  'A\n',
#  'C E\n',
#  'D\n',
#  ', Let ABC and DEF be two triangles having the two\n',
#  ' ,,sides AB and AC equal to the two sides DE and DF, respectively. (That is) AB to DE, and AC to DF. And (let)\n',
#  ' . , the angle BAC (be) equal to the angle EDF. I say that\n',
#  ' ,the base BC is also equal to the base EF, and triangle\n',
#  ' , ABC will be equal to triangle DEF, and the remaining\n',
#  ', angles subtended by the equal sides will be equal to the\n',
#  ' , , corresponding remaining angles. (That is) ABC to DEF,\n',
#  '. and ACB to DFE.\n',
#  'For if triangle ABC is applied to triangle DEF,\n',
#  'å\n',
#  'the\n',
#  ' point A being placed on the point D, and the straight-line\n',
#  '10\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ',AB on DE, then the point B will also coincide with E,\n',
#  ' on account of AB being equal to DE. So (because of)\n',
#  ' AB coinciding with DE, the straight-line AC will also\n',
#  ' coincide with DF, on account of the angle BAC being\n',
#  'equal to EDF. So the point C will also coincide with the\n',
#  '.point F, again on account of AC being equal to DF. But,\n',
#  '.point B certainly also coincided with point E, so that the\n',
#  ' base BC will coincide with the base EF. For if B coin, cides with E, and C with F, and the base BC does not\n',
#  '.coincide with EF, then two straight-lines will encompass\n',
#  ' an area. The very thing is impossible [Post. 1].ç Thus,\n',
#  ' , the base BC will coincide with EF, and will be equal to\n',
#  'it [C.N. 4]. So the whole triangle ABC will coincide with\n',
#  ', the whole triangle DEF, and will be equal to it [C.N. 4].\n',
#  ' . And the remaining angles will coincide with the remain-\n',
#  ' []ing angles, and will be equal to them [C.N. 4]. (That is)\n',
#  ' ABC to DEF, and ACB to DFE [C.N. 4].\n',
#  ', Thus, if two triangles have two sides equal to two\n',
#  ', sides, respectively, and have the angle(s) enclosed by the\n',
#  ', equal straight-line equal, then they will also have the base\n',
#  ',equal to the base, and the triangle will be equal to the tri . angle, and the remaining angles subtended by the equal\n',
#  'sides will be equal to the corresponding remaining angles. (Which is) the very thing it was required to show.\n',
#  'å The application of one figure to another should be counted as an additional postulate.\n',
#  'ç Since Post. 1 implicitly assumes that the straight-line joining two given points is unique.\n',
#  'e■. Proposition 5\n',
#  ' For isosceles triangles, the angles at the base are equal\n',
#  ' , to one another, and if the equal sides are produced then\n',
#  '. the angles under the base will be equal to one another.\n',
#  'B\n',
#  'D\n',
#  'F\n',
#  'C\n',
#  'G\n',
#  'A\n',
#  'E\n',
#  'Let ABC be an isosceles triangle having the side AB\n',
#  ',equal to the side AC, and let the straight-lines BD and\n',
#  ',,,CE have been produced in a straight-line with AB and\n',
#  ' ,AC (respectively) [Post. 2]. I say that the angle ABC is\n',
#  ' . equal to ACB, and (angle) CBD to BCE.\n',
#  ',For let the point F have been taken at random on BD,\n',
#  'and let AG have been cut off from the greater AE, equal\n',
#  '11\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ',,. to the lesser AF [Prop. 1.3]. Also, let the straight-lines\n',
#  ' , FC and GB have been joined [Post. 1].\n',
#  ' ,, In fact, since AF is equal to AG, and AB to AC,\n',
#  ' the two (straight-lines) FA, AC are equal to the two\n',
#  ' ,(straight-lines) GA, AB, respectively. They also encom , pass a common angle, FAG. Thus, the base FC is equal\n',
#  ',to the base GB, and the triangle AFC will be equal to the\n',
#  ', , triangle AGB, and the remaining angles subtendend by\n',
#  '.,the equal sides will be equal to the corresponding remain , ing angles [Prop. 1.4]. (That is) ACF to ABG, and AFC\n',
#  '., to AGB. And since the whole of AF is equal to the whole\n',
#  ' ,of AG, within which AB is equal to AC, the remainder\n',
#  ' , BF is thus equal to the remainder CG [C.N. 3]. But FC\n',
#  ' ,was also shown (to be) equal to GB. So the two (straight lines) BF, FC are equal to the two (straight-lines) CG,\n',
#  ',GB, respectively, and the angle BFC (is) equal to the\n',
#  ' . angle CGB, and the base BC is common to them. Thus,\n',
#  'the triangle BFC will be equal to the triangle CGB, and\n',
#  ' ,,the remaining angles subtended by the equal sides will be\n',
#  'equal to the corresponding remaining angles [Prop. 1.4].\n',
#  ' .Thus, FBC is equal to GCB, and BCF to CBG. There . fore, since the whole angle ABG was shown (to be) equal\n',
#  ' to the whole angle ACF, within which CBG is equal to\n',
#  ',BCF, the remainder ABC is thus equal to the remainder\n',
#  'ACB [C.N. 3]. And they are at the base of triangle ABC.\n',
#  '. And FBC was also shown (to be) equal to GCB. And\n',
#  'they are under the base.\n',
#  'Thus, for isosceles triangles, the angles at the base are\n',
#  'equal to one another, and if the equal sides are produced\n',
#  'then the angles under the base will be equal to one another. (Which is) the very thing it was required to show.\n',
#  '\x06■. Proposition 6\n',
#  ' ,If a triangle has two angles equal to one another then\n',
#  ' the sides subtending the equal angles will also be equal\n',
#  '. to one another.\n',
#  ' \n',
#  ' D\n',
#  'A\n',
#  'B C\n',
#  'Let ABC be a triangle having the angle ABC equal\n',
#  ',to the angle ACB. I say that side AB is also equal to side\n',
#  '. AC.\n',
#  '12\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' , For if AB is unequal to AC then one of them is\n',
#  '.,greater. Let AB be greater. And let DB, equal to\n',
#  ',. the lesser AC, have been cut off from the greater AB\n',
#  ' , [Prop. 1.3]. And let DC have been joined [Post. 1].\n',
#  ' ,, ,Therefore, since DB is equal to AC, and BC (is) com mon, the two sides DB, BC are equal to the two sides\n',
#  ' , AC, CB, respectively, and the angle DBC is equal to the\n',
#  ', angle ACB. Thus, the base DC is equal to the base AB,\n',
#  ' . and the triangle DBC will be equal to the triangle ACB\n',
#  ',[Prop. 1.4], the lesser to the greater. The very notion (is)\n',
#  ' absurd [C.N. 5]. Thus, AB is not unequal to AC. Thus,\n',
#  ' . (it is) equal.å\n',
#  'Thus, if a triangle has two angles equal to one another\n',
#  'then the sides subtending the equal angles will also be\n',
#  'equal to one another. (Which is) the very thing it was\n',
#  'required to show.\n',
#  'å Here, use is made of the previously unmentioned common notion that if two quantities are not unequal then they must be equal. Later on, use\n',
#  'is made of the closely related common notion that if two quantities are not greater than or less than one another, respectively, then they must be\n',
#  'equal to one another.\n',
#  'z■. Proposition 7\n',
#  ' On the same straight-line, two other straight-lines\n',
#  'equal, respectively, to two (given) straight-lines (which\n',
#  ' meet) cannot be constructed (meeting) at a different\n',
#  '. point on the same side (of the straight-line), but having\n',
#  'the same ends as the given straight-lines.\n',
#  ' \n',
#  'A B\n',
#  'C\n',
#  'D\n',
#  ', For, if possible, let the two straight-lines AC, CB,\n',
#  ' ,,equal to two other straight-lines AD, DB, respectively,\n',
#  'have been constructed on the same straight-line AB,\n',
#  ' meeting at different points, C and D, on the same side\n',
#  ',(of AB), and having the same ends (on AB). So CA is\n',
#  ' , - equal to DA, having the same end A as it, and CB is\n',
#  ' ,. equal to DB, having the same end B as it. And let CD\n',
#  ' ,have been joined [Post. 1].\n',
#  'Therefore, since AC is equal to AD, the angle ACD\n',
#  '. is also equal to angle ADC [Prop. 1.5]. Thus, ADC (is)\n',
#  ' ,greater than DCB [C.N. 5]. Thus, CDB is much greater\n',
#  ' .than DCB [C.N. 5]. Again, since CB is equal to DB, the\n',
#  ' . angle CDB is also equal to angle DCB [Prop. 1.5]. But\n',
#  'it was shown that the former (angle) is also much greater\n',
#  '13\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '(than the latter). The very thing is impossible.\n',
#  ' Thus, on the same straight-line, two other straight . lines equal, respectively, to two (given) straight-lines\n',
#  '(which meet) cannot be constructed (meeting) at a different point on the same side (of the straight-line), but\n',
#  'having the same ends as the given straight-lines. (Which\n',
#  'is) the very thing it was required to show.\n',
#  'h■. Proposition 8\n',
#  '[] If two triangles have two sides equal to two sides, re ,spectively, and also have the base equal to the base, then\n',
#  ',they will also have equal the angles encompassed by the\n',
#  ' . equal straight-lines.\n',
#  ' \n',
#  'D\n',
#  'G\n',
#  'B\n',
#  'E\n',
#  'F\n',
#  'C\n',
#  'A\n',
#  ', Let ABC and DEF be two triangles having the two\n',
#  ' ,,sides AB and AC equal to the two sides DE and DF,\n',
#  ' , respectively. (That is) AB to DE, and AC to DF. Let\n',
#  ', them also have the base BC equal to the base EF. I say\n',
#  ' . that the angle BAC is also equal to the angle EDF.\n',
#  'For if triangle ABC is applied to triangle DEF, the\n',
#  ' point B being placed on point E, and the straight-line\n',
#  'BC on EF, then point C will also coincide with F, on\n',
#  ' account of BC being equal to EF. So (because of) BC\n',
#  ',, coinciding with EF, (the sides) BA and CA will also co. ,incide with ED and DF (respectively). For if base BC\n',
#  ' , ,coincides with base EF, but the sides AB and AC do not\n',
#  ', ,coincide with ED and DF (respectively), but miss like\n',
#  ' EG and GF (in the above figure), then we will have constructed upon the same straight-line, two other straight .lines equal, respectively, to two (given) straight-lines,\n',
#  'and (meeting) at a different point on the same side (of\n',
#  ', , . the straight-line), but having the same ends. But (such\n',
#  'straight-lines) cannot be constructed [Prop. 1.7]. Thus,\n',
#  ' . the base BC being applied to the base EF, the sides BA\n',
#  ' []and AC cannot not coincide with ED and DF (respectively). Thus, they will coincide. So the angle BAC will\n',
#  ' , also coincide with angle EDF, and will be equal to it\n',
#  ' . [C.N. 4].\n',
#  'Thus, if two triangles have two sides equal to two\n',
#  'side, respectively, and have the base equal to the base,\n',
#  '14\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'then they will also have equal the angles encompassed\n',
#  'by the equal straight-lines. (Which is) the very thing it\n',
#  'was required to show.\n',
#  'j■. Proposition 9\n',
#  ' . To cut a given rectilinear angle in half.\n',
#  ' \n',
#  ' F\n',
#  'D\n',
#  'B C\n',
#  'E\n',
#  'A\n',
#  ' .Let BAC be the given rectilinear angle. So it is re . quired to cut it in half.\n',
#  ' , Let the point D have been taken at random on AB,\n',
#  ' ,,and let AE, equal to AD, have been cut off from AC\n',
#  ' ,[Prop. 1.3], and let DE have been joined. And let the\n',
#  ' ,equilateral triangle DEF have been constructed upon\n',
#  ' . DE [Prop. 1.1], and let AF have been joined. I say that\n',
#  ' ,, the angle BAC has been cut in half by the straight-line\n',
#  ' ,, . AF.\n',
#  ' For since AD is equal to AE, and AF is common,\n',
#  '. the two (straight-lines) DA, AF are equal to the two\n',
#  ' (straight-lines) EA, AF, respectively. And the base DF\n',
#  ' . is equal to the base EF. Thus, angle DAF is equal to\n',
#  'angle EAF [Prop. 1.8].\n',
#  'Thus, the given rectilinear angle BAC has been cut in\n',
#  'half by the straight-line AF. (Which is) the very thing it\n',
#  'was required to do.\n',
#  'i■. Proposition 10\n',
#  ' . To cut a given finite straight-line in half.\n',
#  'Let AB be the given finite straight-line. So it is re. quired to cut the finite straight-line AB in half.\n',
#  ',Let the equilateral triangle ABC have been con ,structed upon (AB) [Prop. 1.1], and let the angle ACB\n',
#  '. have been cut in half by the straight-line CD [Prop. 1.9].\n',
#  ' ,, I say that the straight-line AB has been cut in half at\n',
#  ' ,, point D.\n',
#  'For since AC is equal to CB, and CD (is) common,\n',
#  '15\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '. the two (straight-lines) AC, CD are equal to the two\n',
#  '(straight-lines) BC, CD, respectively. And the angle\n',
#  'ACD is equal to the angle BCD. Thus, the base AD\n',
#  'is equal to the base BD [Prop. 1.4].\n',
#  'A B\n',
#  'D\n',
#  'C\n',
#  ' Thus, the given finite straight-line AB has been cut\n',
#  ' . in half at (point) D. (Which is) the very thing it was\n',
#  'required to do.\n',
#  'ia■. Proposition 11\n',
#  ' To draw a straight-line at right-angles to a given\n',
#  ' . straight-line from a given point on it.\n',
#  ' \n',
#  'D\n',
#  'A\n',
#  'F\n',
#  'C E\n',
#  'B\n',
#  ' Let AB be the given straight-line, and C the given\n',
#  ' point on it. So it is required to draw a straight-line from\n',
#  ' . the point C at right-angles to the straight-line AB.\n',
#  ' , Let the point D be have been taken at random on AC,\n',
#  ', and let CE be made equal to CD [Prop. 1.3], and let the\n',
#  ', , equilateral triangle FDE have been constructed on DE\n',
#  '[Prop. 1.1], and let FC have been joined. I say that the\n',
#  ' . straight-line FC has been drawn at right-angles to the\n',
#  ' ,,given straight-line AB from the given point C on it.\n',
#  ',,For since DC is equal to CE, and CF is common,\n',
#  ' the two (straight-lines) DC, CF are equal to the two\n',
#  ' .(straight-lines), EC, CF, respectively. And the base DF\n',
#  ' is equal to the base FE. Thus, the angle DCF is equal\n',
#  ' ,to the angle ECF [Prop. 1.8], and they are adjacent.\n',
#  ' , . But when a straight-line stood on a(nother) straight-line\n',
#  '16\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'makes the adjacent angles equal to one another, each of\n',
#  ' the equal angles is a right-angle [Def. 1.10]. Thus, each\n',
#  ' . of the (angles) DCF and FCE is a right-angle.\n',
#  'Thus, the straight-line CF has been drawn at rightangles to the given straight-line AB from the given point\n',
#  'C on it. (Which is) the very thing it was required to do.\n',
#  'ib■. Proposition 12\n',
#  'To draw a straight-line perpendicular to a given infi, ,nite straight-line from a given point which is not on it.\n',
#  '.\n',
#  ' \n',
#  ' \n',
#  'D\n',
#  'A\n',
#  'G H\n',
#  'F\n',
#  'E\n',
#  'B\n',
#  'C\n',
#  ' Let AB be the given infinite straight-line and C the\n',
#  ', ,given point, which is not on (AB). So it is required to\n',
#  ' , draw a straight-line perpendicular to the given infinite\n',
#  ',. straight-line AB from the given point C, which is not on\n',
#  '(AB).\n',
#  ',For let point D have been taken at random on the\n',
#  ' , other side (to C) of the straight-line AB, and let the\n',
#  ',, , circle EFG have been drawn with center C and radius\n',
#  ',CD [Post. 3], and let the straight-line EG have been cut\n',
#  ', ,in half at (point) H [Prop. 1.10], and let the straight. lines CG, CH, and CE have been joined. I say that the\n',
#  ' ,,(straight-line) CH has been drawn perpendicular to the\n',
#  ',,given infinite straight-line AB from the given point C,\n',
#  ' which is not on (AB).\n',
#  '. .For since GH is equal to HE, and HC (is) common,\n',
#  ' the two (straight-lines) GH, HC are equal to the two\n',
#  ' ,,(straight-lines) EH, HC, respectively, and the base CG\n',
#  ' . is equal to the base CE. Thus, the angle CHG is equal\n',
#  'to the angle EHC [Prop. 1.8], and they are adjacent.\n',
#  ' , ,But when a straight-line stood on a(nother) straight-line\n',
#  ' . makes the adjacent angles equal to one another, each of\n',
#  'the equal angles is a right-angle, and the former straightline is called a perpendicular to that upon which it stands\n',
#  '[Def. 1.10].\n',
#  'Thus, the (straight-line) CH has been drawn perpendicular to the given infinite straight-line AB from the\n',
#  '17\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'given point C, which is not on (AB). (Which is) the very\n',
#  'thing it was required to do.\n',
#  'ig■. Proposition 13\n',
#  ', If a straight-line stood on a(nother) straight-line\n',
#  ' . makes angles, it will certainly either make two rightangles, or (angles whose sum is) equal to two rightangles.\n',
#  ' \n',
#  'C\n',
#  'A\n',
#  'E\n',
#  'D B\n',
#  'For let some straight-line AB stood on the straight,,, line CD make the angles CBA and ABD. I say that\n',
#  ' . the angles CBA and ABD are certainly either two right, angles, or (have a sum) equal to two right-angles.\n',
#  '. ,[]In fact, if CBA is equal to ABD then they are two\n',
#  ',right-angles [Def. 1.10]. But, if not, let BE have been\n',
#  ' , ,drawn from the point B at right-angles to [the straight ,line] CD [Prop. 1.11]. Thus, CBE and EBD are two\n',
#  ' , , . , right-angles. And since CBE is equal to the two (an , ,gles) CBA and ABE, let EBD have been added to both.\n',
#  ' , , , Thus, the (sum of the angles) CBE and EBD is equal to\n',
#  '., the (sum of the) three (angles) CBA, ABE, and EBD\n',
#  '[C.N. 2]. Again, since DBA is equal to the two (an , ,gles) DBE and EBA, let ABC have been added to both.\n',
#  ' ,, Thus, the (sum of the angles) DBA and ABC is equal to\n',
#  ' . the (sum of the) three (angles) DBE, EBA, and ABC\n',
#  ' ,[C.N. 2]. But (the sum of) CBE and EBD was also\n',
#  ' . shown (to be) equal to the (sum of the) same three (angles). And things equal to the same thing are also equal\n',
#  'to one another [C.N. 1]. Therefore, (the sum of) CBE\n',
#  'and EBD is also equal to (the sum of) DBA and ABC.\n',
#  'But, (the sum of) CBE and EBD is two right-angles.\n',
#  'Thus, (the sum of) ABD and ABC is also equal to two\n',
#  'right-angles.\n',
#  'Thus, if a straight-line stood on a(nother) straightline makes angles, it will certainly either make two rightangles, or (angles whose sum is) equal to two rightangles. (Which is) the very thing it was required to show.\n',
#  '18\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'id■. Proposition 14\n',
#  'If two straight-lines, not lying on the same side, make\n',
#  'adjacent angles (whose sum is) equal to two right-angles\n',
#  ' ,with some straight-line, at a point on it, then the two\n',
#  '. straight-lines will be straight-on (with respect) to one another.\n',
#  ' \n',
#  'C D B\n',
#  'A E\n',
#  ' For let two straight-lines BC and BD, not lying on the\n',
#  ' ,same side, make adjacent angles ABC and ABD (whose\n',
#  ' , sum is) equal to two right-angles with some straight-line\n',
#  ' ,. AB, at the point B on it. I say that BD is straight-on with\n',
#  ' ,respect to CB.\n',
#  ' . For if BD is not straight-on to BC then let BE be\n',
#  ' , straight-on to CB.\n',
#  ' , Therefore, since the straight-line AB stands on the\n',
#  ' ,, straight-line CBE, the (sum of the) angles ABC and\n',
#  ' , .ABE is thus equal to two right-angles [Prop. 1.13]. But\n',
#  '(the sum of) ABC and ABD is also equal to two right, . angles. Thus, (the sum of angles) CBA and ABE is equal\n',
#  '. , to (the sum of angles) CBA and ABD [C.N. 1]. Let (an. gle) CBA have been subtracted from both. Thus, the re-\n',
#  'mainder ABE is equal to the remainder ABD [C.N. 3],\n',
#  'the lesser to the greater. The very thing is impossible.\n',
#  ' ,Thus, BE is not straight-on with respect to CB. Simi . larly, we can show that neither (is) any other (straightline) than BD. Thus, CB is straight-on with respect to\n',
#  'BD.\n',
#  'Thus, if two straight-lines, not lying on the same side,\n',
#  'make adjacent angles (whose sum is) equal to two rightangles with some straight-line, at a point on it, then the\n',
#  'two straight-lines will be straight-on (with respect) to\n',
#  'one another. (Which is) the very thing it was required\n',
#  'to show.\n',
#  'ie■. Proposition 15\n',
#  ',If two straight-lines cut one another then they make\n',
#  ' . the vertically opposite angles equal to one another.\n',
#  '19\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ', For let the two straight-lines AB and CD cut one an ,other at the point E. I say that angle AEC is equal to\n',
#  ' , . (angle) DEB, and (angle) CEB to (angle) AED.\n',
#  ' D\n',
#  'A\n',
#  'E\n',
#  'B\n',
#  'C\n',
#  'For since the straight-line AE stands on the straight, ,,line CD, making the angles CEA and AED, the (sum\n',
#  '. ,of the) angles CEA and AED is thus equal to two right, angles [Prop. 1.13]. Again, since the straight-line DE\n',
#  ',,. stands on the straight-line AB, making the angles AED\n',
#  ' ,and DEB, the (sum of the) angles AED and DEB is\n',
#  ',, .thus equal to two right-angles [Prop. 1.13]. But (the sum\n',
#  'of) CEA and AED was also shown (to be) equal to two\n',
#  ' , , right-angles. Thus, (the sum of) CEA and AED is equal\n',
#  '. to (the sum of) AED and DEB [C.N. 1]. Let AED have\n',
#  ' , - been subtracted from both. Thus, the remainder CEA is\n',
#  ' . equal to the remainder BED [C.N. 3]. Similarly, it can\n',
#  'be shown that CEB and DEA are also equal.\n',
#  'Thus, if two straight-lines cut one another then they\n',
#  'make the vertically opposite angles equal to one another.\n',
#  '(Which is) the very thing it was required to show.\n',
#  'i\x06■. Proposition 16\n',
#  'For any triangle, when one of the sides is produced,\n',
#  ' the external angle is greater than each of the internal and\n',
#  ' . opposite angles.\n',
#  ' ,Let ABC be a triangle, and let one of its sides BC\n',
#  ' , have been produced to D. I say that the external angle\n',
#  ' ACD is greater than each of the internal and opposite\n',
#  ' ,. angles, CBA and BAC.\n',
#  ', Let the (straight-line) AC have been cut in half at\n',
#  ' , (point) E [Prop. 1.10]. And BE being joined, let it have\n',
#  ',, . been produced in a straight-line to (point) F.\n',
#  'å And let\n',
#  ', ,EF be made equal to BE [Prop. 1.3], and let FC have\n',
#  ',,been joined, and let AC have been drawn through to\n',
#  '(point) G.\n',
#  ', Therefore, since AE is equal to EC, and BE to EF,\n',
#  ',the two (straight-lines) AE, EB are equal to the two\n',
#  '20\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' ,(straight-lines) CE, EF, respectively. Also, angle AEB\n',
#  ' is equal to angle FEC, for (they are) vertically opposite\n',
#  '.[Prop. 1.15]. Thus, the base AB is equal to the base FC,\n',
#  ' . and the triangle ABE is equal to the triangle FEC, and\n',
#  ', the remaining angles subtended by the equal sides are\n',
#  ' , . equal to the corresponding remaining angles [Prop. 1.4].\n',
#  'Thus, BAE is equal to ECF. But ECD is greater than\n',
#  'ECF. Thus, ACD is greater than BAE. Similarly, by\n',
#  'having cut BC in half, it can be shown (that) BCGùthat\n',
#  'is to say, ACDù(is) also greater than ABC.\n',
#  ' \n',
#  ' \n',
#  'E\n',
#  'B\n',
#  'A\n',
#  'C\n',
#  'G\n',
#  'F\n',
#  'D\n',
#  '- Thus, for any triangle, when one of the sides is pro- duced, the external angle is greater than each of the in. ternal and opposite angles. (Which is) the very thing it\n',
#  'was required to show.\n',
#  'å The implicit assumption that the point F lies in the interior of the angle ABC should be counted as an additional postulate.\n',
#  'iz■. Proposition 17\n',
#  'vFor any triangle, (the sum of) two angles taken to. gether in any (possible way) is less than two right-angles.\n',
#  ' \n',
#  ' B\n',
#  'A\n',
#  'C D\n',
#  ', Let ABC be a triangle. I say that (the sum of) two\n',
#  '- angles of triangle ABC taken together in any (possible\n',
#  '. way) is less than two right-angles.\n',
#  '21\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '. For let BC have been produced to D.\n',
#  'And since the angle ACD is external to triangle ABC,\n',
#  ', . it is greater than the internal and opposite angle ABC\n',
#  ', [Prop. 1.16]. Let ACB have been added to both. Thus,\n',
#  ' , .,the (sum of the angles) ACD and ACB is greater than\n',
#  ' ,the (sum of the angles) ABC and BCA. But, (the sum of)\n',
#  ' . , , ACD and ACB is equal to two right-angles [Prop. 1.13].\n',
#  ' , . Thus, (the sum of) ABC and BCA is less than two rightv- angles. Similarly, we can show that (the sum of) BAC\n',
#  '. and ACB is also less than two right-angles, and further\n',
#  '(that the sum of) CAB and ABC (is less than two rightangles).\n',
#  'Thus, for any triangle, (the sum of) two angles taken\n',
#  'together in any (possible way) is less than two rightangles. (Which is) the very thing it was required to show.\n',
#  'ih■. Proposition 18\n',
#  'In any triangle, the greater side subtends the greater\n',
#  '. angle.\n',
#  'A\n',
#  'D\n',
#  'B\n',
#  'C\n',
#  ' For let ABC be a triangle having side AC greater than\n',
#  ' ,AB. I say that angle ABC is also greater than BCA.\n',
#  'For since AC is greater than AB, let AD be made\n',
#  ' , equal to AB [Prop. 1.3], and let BD have been joined.\n',
#  ' ,. And since angle ADB is external to triangle BCD, it\n',
#  'is greater than the internal and opposite (angle) DCB\n',
#  ',[Prop. 1.16]. But ADB (is) equal to ABD, since side\n',
#  ' , AB is also equal to side AD [Prop. 1.5]. Thus, ABD is\n',
#  'also greater than ACB. Thus, ABC is much greater than\n',
#  ' . ACB.\n',
#  'Thus, in any triangle, the greater side subtends the\n',
#  '. greater angle. (Which is) the very thing it was required\n',
#  'to show.\n',
#  'ij■. Proposition 19\n',
#  'In any triangle, the greater angle is subtended by the\n',
#  ' . greater side.\n',
#  ' Let ABC be a triangle having the angle ABC greater\n',
#  ', than BCA. I say that side AC is also greater than side\n',
#  ' . AB.\n',
#  '22\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ', For if not, AC is certainly either equal to, or less than,\n',
#  ' AB. In fact, AC is not equal to AB. For then angle ABC\n',
#  'would also have been equal to ACB [Prop. 1.5]. But it\n',
#  ' .is not. Thus, AC is not equal to AB. Neither, indeed, is\n',
#  ' AC less than AB. For then angle ABC would also have\n',
#  '.,been less than ACB [Prop. 1.18]. But it is not. Thus, AC\n',
#  '. . is not less than AB. But it was shown that (AC) is not\n',
#  'equal (to AB) either. Thus, AC is greater than AB.\n',
#  ' C\n',
#  'B\n',
#  'A\n',
#  ' Thus, in any triangle, the greater angle is subtended\n',
#  '. by the greater side. (Which is) the very thing it was required to show.\n',
#  'k■. Proposition 20\n',
#  'In any triangle, (the sum of) two sides taken to. gether in any (possible way) is greater than the remaining\n',
#  '(side).\n',
#  ' \n',
#  'B\n',
#  'A\n',
#  'D\n',
#  'C\n',
#  ' ,For let ABC be a triangle. I say that in triangle ABC\n',
#  ' (the sum of) two sides taken together in any (possible\n',
#  ', , , ,way) is greater than the remaining (side). (So), (the sum\n',
#  ' , , . of) BA and AC (is greater) than BC, (the sum of) AB\n',
#  '23\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' , and BC than AC, and (the sum of) BC and CA than\n',
#  ',. AB.\n',
#  ' , For let BA have been drawn through to point D, and\n',
#  ' let AD be made equal to CA [Prop. 1.3], and let DC\n',
#  ' have been joined.\n',
#  ', Therefore, since DA is equal to AC, the angle ADC\n',
#  ', .is also equal to ACD [Prop. 1.5]. Thus, BCD is greater\n',
#  ', than ADC. And since DCB is a triangle having the angle\n',
#  ' , , , BCD greater than BDC, and the greater angle subtends\n',
#  ', . the greater side [Prop. 1.19], DB is thus greater than\n',
#  'BC. But DA is equal to AC. Thus, (the sum of) BA and\n',
#  '. AC is greater than BC. Similarly, we can show that (the\n',
#  'sum of) AB and BC is also greater than CA, and (the\n',
#  'sum of) BC and CA than AB.\n',
#  'Thus, in any triangle, (the sum of) two sides taken together in any (possible way) is greater than the remaining\n',
#  '(side). (Which is) the very thing it was required to show.\n',
#  'ka■. Proposition 21\n',
#  ' If two internal straight-lines are constructed on one\n',
#  ' , of the sides of a triangle, from its ends, the constructed\n',
#  ',(straight-lines) will be less than the two remaining sides\n',
#  '. of the triangle, but will encompass a greater angle.\n',
#  ' \n',
#  'B\n',
#  'A\n',
#  'E\n',
#  'C\n',
#  'D\n',
#  'For let the two internal straight-lines BD and DC\n',
#  ',have been constructed on one of the sides BC of the tri ,, ,angle ABC, from its ends B and C (respectively). I say\n',
#  ' ,, that BD and DC are less than the (sum of the) two re . maining sides of the triangle BA and AC, but encompass\n',
#  '. an angle BDC greater than BAC.\n',
#  ',For let BD have been drawn through to E. And since\n',
#  ' , in any triangle (the sum of any) two sides is greater than\n',
#  ' , , the remaining (side) [Prop. 1.20], in triangle ABE the\n',
#  '. , (sum of the) two sides AB and AE is thus greater than\n',
#  ', , BE. Let EC have been added to both. Thus, (the sum\n',
#  ' ,, .of) BA and AC is greater than (the sum of) BE and EC.\n',
#  ' , , Again, since in triangle CED the (sum of the) two sides\n',
#  ', , . CE and ED is greater than CD, let DB have been added\n',
#  ', to both. Thus, (the sum of) CE and EB is greater than\n',
#  ' ,(the sum of) CD and DB. But, (the sum of) BA and\n',
#  ' .AC was shown (to be) greater than (the sum of) BE and\n',
#  ' EC. Thus, (the sum of) BA and AC is much greater than\n',
#  '24\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' .(the sum of) BD and DC.\n',
#  ' Again, since in any triangle the external angle is\n',
#  '. greater than the internal and opposite (angles) [Prop.\n',
#  ' 1.16], in triangle CDE the external angle BDC is thus\n',
#  ',greater than CED. Accordingly, for the same (reason),\n',
#  ' , the external angle CEB of the triangle ABE is also\n',
#  '. greater than BAC. But, BDC was shown (to be) greater\n',
#  'than CEB. Thus, BDC is much greater than BAC.\n',
#  'Thus, if two internal straight-lines are constructed on\n',
#  'one of the sides of a triangle, from its ends, the constructed (straight-lines) are less than the two remaining sides of the triangle, but encompass a greater angle.\n',
#  '(Which is) the very thing it was required to show.\n',
#  'kb■. Proposition 22\n',
#  ', To construct a triangle from three straight-lines which\n',
#  '[], are equal to three given [straight-lines]. It is necessary\n',
#  '[for (the sum of) two (of the straight-lines) taken together\n',
#  ' in any (possible way) to be greater than the remaining\n',
#  ']. (one), [on account of the (fact that) in any triangle (the\n',
#  'sum of) two sides taken together in any (possible way) is\n',
#  'greater than the remaining (one) [Prop. 1.20] ].\n',
#  'H\n',
#  'A\n',
#  'B\n',
#  'C\n',
#  'D\n',
#  'F\n',
#  'E\n',
#  'K\n',
#  'L\n',
#  'G\n',
#  ', , , Let A, B, and C be the three given straight-lines, of\n',
#  ', which let (the sum of) two taken together in any (possible\n',
#  ', , , ,,way) be greater than the remaining (one). (Thus), (the\n',
#  ', , . sum of) A and B (is greater) than C, (the sum of) A and\n',
#  ' C than B, and also (the sum of) B and C than A. So\n',
#  ' ,, it is required to construct a triangle from (straight-lines)\n',
#  ' , equal to A, B, and C.\n',
#  ',Let some straight-line DE be set out, terminated at D,\n',
#  ' , and infinite in the direction of E. And let DF made equal\n',
#  ' ,,,to A, and FG equal to B, and GH equal to C [Prop. 1.3].\n',
#  ', , And let the circle DKL have been drawn with center F\n',
#  '. and radius FD. Again, let the circle KLH have been\n',
#  ' , drawn with center G and radius GH. And let KF and\n',
#  '. KG have been joined. I say that the triangle KFG has\n',
#  '25\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' . ,been constructed from three straight-lines equal to A, B,\n',
#  ' ,and C.\n',
#  ' . For since point F is the center of the circle DKL, FD\n',
#  ' , ,is equal to FK. But, FD is equal to A. Thus, KF is also\n',
#  ', , . equal to A. Again, since point G is the center of the circle\n',
#  ' , , , LKH, GH is equal to GK. But, GH is equal to C. Thus,\n',
#  ', , ,KG is also equal to C. And FG is also equal to B. Thus,\n',
#  ' . the three straight-lines KF, FG, and GK are equal to A,\n',
#  'B, and C (respectively).\n',
#  'Thus, the triangle KFG has been constructed from\n',
#  'the three straight-lines KF, FG, and GK, which are\n',
#  'equal to the three given straight-lines A, B, and C (respectively). (Which is) the very thing it was required to\n',
#  'do.\n',
#  'kg■. Proposition 23\n',
#  ' To construct a rectilinear angle equal to a given recti linear angle at a (given) point on a given straight-line.\n',
#  '.\n',
#  'C\n',
#  'G A\n',
#  'F\n',
#  'B\n',
#  'E\n',
#  'D\n',
#  ', Let AB be the given straight-line, A the (given) point\n',
#  ', on it, and DCE the given rectilinear angle. So it is required to construct a rectilinear angle equal to the given\n',
#  'rectilinear angle DCE at the (given) point A on the given\n',
#  ' . straight-line AB.\n',
#  ', Let the points D and E have been taken at random\n',
#  ', ,, on each of the (straight-lines) CD and CE (respectively),\n',
#  ' , , ,, and let DE have been joined. And let the triangle AFG\n',
#  ' , ,have been constructed from three straight-lines which are\n',
#  '. equal to CD, DE, and CE, such that CD is equal to AF,\n',
#  ',,CE to AG, and further DE to FG [Prop. 1.22].\n',
#  ' ,,Therefore, since the two (straight-lines) DC, CE are\n',
#  ' . equal to the two (straight-lines) FA, AG, respectively,\n',
#  ' and the base DE is equal to the base FG, the angle DCE\n',
#  'is thus equal to the angle FAG [Prop. 1.8].\n',
#  ' Thus, the rectilinear angle FAG, equal to the given\n',
#  '. rectilinear angle DCE, has been constructed at the\n',
#  '(given) point A on the given straight-line AB. (Which\n',
#  '26\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  'is) the very thing it was required to do.\n',
#  'kd■. Proposition 24\n',
#  '[] If two triangles have two sides equal to two sides, re ,spectively, but (one) has the angle encompassed by the\n',
#  ' ,equal straight-lines greater than the (corresponding) an . gle (in the other), then (the former triangle) will also\n',
#  'have a base greater than the base (of the latter).\n',
#  ' \n',
#  'F\n',
#  'A\n',
#  'C\n',
#  'B\n',
#  'D\n',
#  'E\n',
#  'G\n',
#  ', Let ABC and DEF be two triangles having the two\n',
#  ' ,,sides AB and AC equal to the two sides DE and DF,\n',
#  ' ,,respectively. (That is), AB (equal) to DE, and AC to\n',
#  'DF. Let them also have the angle at A greater than the\n',
#  ',. angle at D. I say that the base BC is also greater than\n',
#  'the base EF.\n',
#  ',For since angle BAC is greater than angle EDF,\n',
#  ', let (angle) EDG, equal to angle BAC, have been\n',
#  ',,, constructed at the point D on the straight-line DE\n',
#  '. [Prop. 1.23]. And let DG be made equal to either of\n',
#  ', , AC or DF [Prop. 1.3], and let EG and FG have been\n',
#  ' ,, joined.\n',
#  ' Therefore, since AB is equal to DE and AC to DG,\n',
#  '. , the two (straight-lines) BA, AC are equal to the two\n',
#  ',(straight-lines) ED, DG, respectively. Also the angle\n',
#  ' BAC is equal to the angle EDG. Thus, the base BC\n',
#  ' .is equal to the base EG [Prop. 1.4]. Again, since DF\n',
#  ' is equal to DG, angle DGF is also equal to angle DFG\n',
#  ', , [Prop. 1.5]. Thus, DFG (is) greater than EGF. Thus,\n',
#  ' . EFG is much greater than EGF. And since triangle\n',
#  '. EFG has angle EFG greater than EGF, and the greater\n',
#  ' angle is subtended by the greater side [Prop. 1.19], side\n',
#  ' ,EG (is) thus also greater than EF. But EG (is) equal to\n',
#  ' ,BC. Thus, BC (is) also greater than EF.\n',
#  '. Thus, if two triangles have two sides equal to two\n',
#  'sides, respectively, but (one) has the angle encompassed\n',
#  'by the equal straight-lines greater than the (corresponding) angle (in the other), then (the former triangle) will\n',
#  'also have a base greater than the base (of the latter).\n',
#  '27\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  '(Which is) the very thing it was required to show.\n',
#  'ke■. Proposition 25\n',
#  ' If two triangles have two sides equal to two sides,\n',
#  ', respectively, but (one) has a base greater than the base\n',
#  ', (of the other), then (the former triangle) will also have\n',
#  '. the angle encompassed by the equal straight-lines greater\n',
#  'than the (corresponding) angle (in the latter).\n',
#  ' \n',
#  'F\n',
#  'B\n',
#  'A\n',
#  'C\n',
#  'D\n',
#  'E\n',
#  ', Let ABC and DEF be two triangles having the two\n',
#  ' ,,sides AB and AC equal to the two sides DE and DF,\n',
#  ' , ,respectively (That is), AB (equal) to DE, and AC to DF.\n',
#  ' , And let the base BC be greater than the base EF. I say\n',
#  ' . that angle BAC is also greater than EDF.\n',
#  ',For if not, (BAC) is certainly either equal to, or less\n',
#  'than, (EDF). In fact, BAC is not equal to EDF. For\n',
#  ' . then the base BC would also have been equal to the base\n',
#  'EF [Prop. 1.4]. But it is not. Thus, angle BAC is not\n',
#  'equal to EDF. Neither, indeed, is BAC less than EDF.\n',
#  'For then the base BC would also have been less than the\n',
#  ' .,base EF [Prop. 1.24]. But it is not. Thus, angle BAC is\n',
#  '. not less than EDF. But it was shown that (BAC is) not\n',
#  ' equal (to EDF) either. Thus, BAC is greater than EDF.\n',
#  ' ,Thus, if two triangles have two sides equal to two\n',
#  ' , sides, respectively, but (one) has a base greater than the\n',
#  ' . base (of the other), then (the former triangle) will also\n',
#  'have the angle encompassed by the equal straight-lines\n',
#  'greater than the (corresponding) angle (in the latter).\n',
#  '(Which is) the very thing it was required to show.\n',
#  'k\x06■. Proposition 26\n',
#  'If two triangles have two angles equal to two angles,\n',
#  'respectively, and one side equal to one sideùin fact, either that by the equal angles, or that subtending one of\n',
#  ' ,the equal anglesùthen (the triangles) will also have the\n',
#  '[ ] remaining sides equal to the [corresponding] remaining\n',
#  '. sides, and the remaining angle (equal) to the remaining\n',
#  ',angle.\n',
#  '28\n',
#  'STOIQEIWN a■. ELEMENTS BOOK 1\n',
#  ' , ,Let ABC and DEF be two triangles having the two\n',
#  ' , ,angles ABC and BCA equal to the two (angles) DEF\n',
#  'and EFD, respectively. (That is) ABC (equal) to DEF,\n',
#  ' ,and BCA to EFD. And let them also have one side equal\n',
#  ' ,to one side. First of all, the (side) by the equal angles.\n',
#  ',(That is) BC (equal) to EF. I say that they will have\n',
#  ', , the remaining sides equal to the corresponding remain . ing sides. (That is) AB (equal) to DE, and AC to DF.\n',
#  'And (they will have) the remaining angle (equal) to the\n',
#  'remaining angle. (That is) BAC (equal) to EDF.\n',
#  ' \n',
#  ' \n',
#  'A\n',
#  'G\n',
#  'B H C\n',
#  'D\n',
#  'E F\n',
#  ' ,For if AB is unequal to DE then one of them is\n',
#  '., ,greater. Let AB be greater, and let BG be made equal\n',
#  '. to DE [Prop. 1.3], and let GC have been joined.\n',
#  ', ,Therefore, since BG is equal to DE, and BC to EF,\n',
#  ',,the two (straight-lines) GB, BCå are equal to the two\n',
#  '(straight-lines) DE, EF, respectively. And angle GBC is\n',
#  ' ,equal to angle DEF. Thus, the base GC is equal to the\n',
#  ' , base DF, and triangle GBC is equal to triangle DEF,\n',
#  ', and the remaining angles subtended by the equal sides\n',
#  '. will be equal to the (corresponding) remaining angles\n',
#  ...]

# %%
len(text_file_lines)
# Out:
# 24536

# %% [markdown]
# # Book speration

# %%
books_headings = ['ELEMENTS BOOK ' + str(x) + '\n' for x in range(1,14)]
headings_index = []
for i in range(len(text_file_lines)):
    if text_file_lines[i] in books_headings:
        headings_index.append(i)

# %%
book_glossary = {}
headings_index.append(-1)
for i in range(len(books_headings)):
    book_glossary[books_headings[i]] = np.array(text_file_lines[headings_index[i]:headings_index[i+1]])

# %% [markdown]
# cleaning one sample book

# %%
desired_book = book_glossary['ELEMENTS BOOK 10\n']
lines_mask = [False]*len(desired_book)
for i in range(len(desired_book)):
    lines_mask[i] = '[P' in desired_book[i] or '[C' in desired_book[i] or 'Proposition' in desired_book[i]
desired_book = desired_book[lines_mask]

# %% [markdown]
# Propositions separation into dictionary

# %%
props_num = 1
props_index = []
for i in range(len(desired_book)):
    if 'Proposition' in desired_book[i]:
        props_index.append(i)
        desired_book[i] = 'Proposition '+ str(props_num)
        props_num+=1

# %%
desired_book_propos_dict = {}
props_titles = [ '[Prop 10.{}]'.format(i) for i in range(1,len(props_index)+1) ]
desired_book_propos_dict = { x:[] for x in props_titles }

# %%
props_index.append(-1)

# %%
for i in range(len(props_index)-1):
    desired_book_propos_dict[props_titles[i]] = desired_book[ props_index[i]+1:props_index[i+1] ]
# props_index
desired_book_propos_dict
# Out:
# {'[Prop 10.1]': array([], dtype='<U276'),
#  '[Prop 10.2]': array([], dtype='<U276'),
#  '[Prop 10.3]': array([',, ing incommensurable [Prop. 10.2]. And let AB leave EC\n'],
#        dtype='<U276'),
#  '[Prop 10.4]': array([' []. For let the greatest common measure of the two (mag . , nitudes) A and B have been taken [Prop. 10.3], and let it\n',
#         '. . , , greatest common measure of A and B [Prop. 10.3 corr.].\n',
#         ', , , common measure have been taken [Prop. 10.3], and let\n',
#         ' common measure of A and B [Prop. 10.3 corr.]. And D\n',
#         'common measure of C and D [Prop. 10.3 corr.]. And it is\n'],
#        dtype='<U276'),
#  '[Prop 10.5]': array([', to C, so D (is) to a unit [Prop. 5.7 corr.]. Again, since\n',
#         'the (number) E [Prop. 5.22].\n'], dtype='<U276'),
#  '[Prop 10.6]': array(['[]. to a unit [Prop. 5.7 corr.]. Again, since as many units as\n',
#         ' ,. (is) to E [Prop. 5.22]. But, as D (is) to E, so A is to B.\n',
#         '. And thus as A (is) to B, so (it) also is to F [Prop. 5.11].\n',
#         '. equal to F [Prop. 5.9]. And C measures F. Thus, it also\n',
#         ' described, (figure) on the second [Prop. 6.19 corr.]. But,\n'],
#        dtype='<U276'),
#  '[Prop 10.7]': array([',. [Prop. 10.6]. But it is not. Thus, A does not have to B\n'],
#        dtype='<U276'),
#  '[Prop 10.8]': array([' , . [Prop. 10.5]. But it does not have (such a ratio). Thus,\n'],
#        dtype='<U276'),
#  '[Prop 10.9]': array([' . , (some) number [Prop. 10.5]. Let it have (that) which\n',
#         '[] sides [Prop. 6.20 corr.]. And the (ratio) of the square\n',
#         ', []former has) to the side (of the latter) [Prop. 8.11]. And,\n',
#         ', on B is the square of the (ratio) of A to B [Prop. 6.20\n',
#         ',[]D [Prop. 8.11]. Thus, as A is to B, so the [number] C\n',
#         ' ,commensurable in length with B [Prop. 10.6].ç\n'], dtype='<U276'),
#  '[Prop 10.10]': array([',square on D. For we learned (how to do this) [Prop. 10.6\n',
#         ', the (square) on D [Prop. 10.6]. And since B does not\n',
#         ' is incommensurable in length with D [Prop. 10.9]. Let\n',
#         'and D have been taken [Prop. 6.13]. Thus, as A is to D,\n',
#         'E [Prop. 10.11]. Thus, A is incommensurable in square\n'],
#        dtype='<U276'),
#  '[Prop 10.11]': array([',[Prop. 10.5]. And as A is to B, so C (is) to D. Thus,\n',
#         ',[Prop. 10.6].\n',
#         ' . [Prop. 10.7]. And as A is to B, so C (is) to D. Thus, C\n',
#         'with D [Prop. 10.8].\n'], dtype='<U276'),
#  '[Prop 10.12]': array(['. , ,number [Prop. 10.5]. Let it have (the ratio) which D\n',
#         ',to (some) number [Prop. 10.5]. Let it have (the ratio)\n',
#         'taken [Prop. 8.4]. Hence, as D is to E, so H (is) to K,\n',
#         ',. (is) to K [Prop. 5.11]. Again, since as C is to B, so F\n',
#         ', , [] ,as C (is) to B, so K (is) to L [Prop. 5.11]. And also as A\n',
#         ' ,so H (is) to L [Prop. 5.22]. Thus, A has to B the ratio\n',
#         ', commensurable with B [Prop. 10.6].\n'], dtype='<U276'),
#  '[Prop 10.13]': array(['. C [Prop. 10.12]. But, (it is) also incommensurable (with\n',
#         ', ,. [Prop. 4.1]. And let DB have been joined. So (it is) clear\n',
#         ' that the angle ADB is a right-angle [Prop. 3.31], and\n',
#         '.,on) DB [Prop. 1.47].\n',
#         'of (the sum of the squares on) AD and DB [Prop. 1.47].\n'],
#        dtype='<U276'),
#  '[Prop 10.14]': array(['. C (is) to the (square) on D [Prop. 6.22]. But the (sum\n',
#         ', [Prop. 5.17]. Thus, also, as E is to B, so F (is) to D\n',
#         ' ,. [Prop. 6.22]. Thus, inversely, as B is to E, so D (is)\n',
#         ' , ,to F [Prop. 5.7 corr.]. But, as A is to B, so C also (is)\n',
#         ' , . [Prop. 5.22]. Therefore, A is either commensurable (in\n',
#         'incommensurable with F [Prop. 10.11].\n'], dtype='<U276'),
#  '[Prop 10.15]': array([], dtype='<U276'),
#  '[Prop 10.16]': array([], dtype='<U276'),
#  '[Prop 10.17]': array([', For let BC have been cut in half at the point E [Prop.\n',
#         '.. 1.10]. And let EF be made equal to DE [Prop. 1.3].\n',
#         ' ,the square on EC [Prop. 2.5]. (The same) also (for) the\n',
#         '. CD [Prop. 10.15]. But, CD is commensurable in length\n',
#         ' with CD plus BF. For CD is equal to BF [Prop. 10.6].\n',
#         ' , CD [Prop. 10.12]. Hence, BC is also commensurable\n',
#         ' , . ,in length with the remainder FD [Prop. 10.15]. Thus,\n',
#         'of BF and DC [Prop. 10.15]. But, the sum of BF and\n',
#         'DC is commensurable [in length] with DC [Prop. 10.6].\n',
#         '[Prop. 10.12]. Thus, via separation, BD is also commensurable in length with DC [Prop. 10.15].\n'],
#        dtype='<U276'),
#  '[Prop 10.18]': array([' , .with CD [Prop. 10.16]. But, DC is commensurable (in\n',
#         '. length) with the sum of BF and DC [Prop. 10.6]. And,\n',
#         '. BF and DC [Prop. 10.13]. Hence, BC is also incommen- surable in length with the remainder FD [Prop. 10.16].\n',
#         'BC is also incommensurable (in length) with the remaining sum of BF and DC [Prop. 10.16]. But, the\n',
#         'DC [Prop. 10.6]. Thus, BC is also incommensurable\n',
#         'in length with DC [Prop. 10.13]. Hence, via separation, BD is also incommensurable in length with DC\n',
#         '[Prop. 10.16].\n'], dtype='<U276'),
#  '[Prop 10.19]': array(['. . BD is to BC, so DA (is) to AC [Prop. 6.1]. Thus, DA\n',
#         ' . is commensurable with AC [Prop. 10.11]. And DA (is)\n'],
#        dtype='<U276'),
#  '[Prop 10.20]': array(['.is to AC, so DB (is) to BC [Prop. 6.1]. Thus, DB is\n',
#         ' also commensurable (in length) with BC [Prop. 10.11].\n'],
#        dtype='<U276'),
#  '[Prop 10.21]': array([' [].BC. And as DB is to BC, so AD (is) to AC [Prop. 6.1].\n',
#         ' Thus, DA [is] incommensurable with AC [Prop. 10.11].\n',
#         ',,FE is to EG, so FD (is) to DG [Prop. 6.1], and FD is\n'],
#        dtype='<U276'),
#  '[Prop 10.22]': array([' - which are) commensurable in square only [Prop. 10.21].\n',
#         ' ,. equiangular parallelograms, the sides about the equal an gles are reciprocally proportional [Prop. 6.14]. Thus, proportionally, as BC is to EG, so EF (is) to CD. And, also,\n',
#         ' . (square) on EF (is) to the (square) on CD [Prop. 6.22].\n',
#         ' , .on CD [Prop. 10.11]. And the (square) on EF is ratio nal. Thus, the (square) on CD is also rational [Def. 10.4].\n',
#         '[Prop. 10.11]. But, the (square) on CD is commensurable with the (square) on EF. For they are rational in\n',
#         'the (rectangle contained) by DC and CB [Prop. 10.13].\n',
#         'CB [Prop. 10.11]. Thus, CD is rational, and incommensurable in length with CB. (Which is) the very thing it\n'],
#        dtype='<U276'),
#  '[Prop 10.23]': array(['.[Prop. 10.22]. And let the rectangular area CF, equal\n',
#         ' . DF [Prop. 6.1]. Thus, ED is commensurable in length\n',
#         '.with DF [Prop. 10.11]. And ED is rational, and incom,, mensurable in length with CD. DF is thus also ratio . nal [Def. 10.3], and incommensurable in length with DC\n',
#         '[Prop. 10.13]. Thus, CD and DF are rational, and commensurable in square only. And the square-root of a (rectangle contained) by rational (straight-lines which are)\n',
#         'commensurable in square only is medial [Prop. 10.21].\n'],
#        dtype='<U276'),
#  '[Prop 10.24]': array(['[Props. 6.1, 10.11]. And DA (is) medial. Thus, AC (is)\n',
#         'also medial [Prop. 10.23 corr.]. (Which is) the very thing\n'],
#        dtype='<U276'),
#  '[Prop 10.25]': array(['., FG [Prop. 10.22]. And since AD is commensurable with\n',
#         ' , , GH is to NL, so FH (is) to KL [Prop. 6.1]. Thus, FH is\n',
#         ' ,. commensurable in length with KL [Prop. 10.11]. Thus,\n',
#         ',.FH and KL is rational [Prop. 10.19]. And since DB is\n',
#         ' , AC [Props. 6.1]. And as AB (is) to BO, so AC (is) to\n',
#         ', . CO [Prop. 6.1]. Thus, as DA is to AC, so AC (is) to\n',
#         ',also, as FH is to HK, so HK (is) to KL [Props. 6.1,\n',
#         ' .. is equal to the (square) on HK [Prop. 6.17]. And the\n',
#         'HN is rational [Prop. 10.19]. And if it is incommensurable in length with FG then KH and HM are rational\n',
#         'thus, HN is medial [Prop. 10.21]. Thus, HN is either rational or medial. And HN (is) equal to AC. Thus, AC is\n'],
#        dtype='<U276'),
#  '[Prop 10.26]': array([' Thus, HE and EG are each rational, and incommensu.rable in length with EF [Prop. 10.22]. And since DB\n',
#         ', . with EF [Prop. 10.20]. But, EG is also rational, and in , commensurable in length with EF. Thus, EG is incom ,mensurable in length with GH [Prop. 10.13]. And as\n',
#         ', EG is to GH, so the (square) on EG (is) to the (rectan ,, gle contained) by EG and GH [Prop. 10.13 lem.]. Thus,\n',
#         ',the (square) on EG is incommensurable with the (rect , ,, angle contained) by EG and GH [Prop. 10.11]. But, the\n',
#         'EG and GH [Prop. 10.6]. For (the former) is double\n',
#         'GH is incommensurable with twice the (rectangle contained) by EG and GH [Prop. 10.13]. And thus the sum\n',
#         'EH [Prop. 2.4], is incommensurable with the (sum of\n',
#         'the squares) on EG and GH [Prop. 10.16]. And the (sum\n'],
#        dtype='<U276'),
#  '[Prop 10.27]': array([' ,, have been taken [Prop. 6.13]. And let it be contrived\n',
#         ', , ,. that as A (is) to B, so C (is) to D [Prop. 6.12].\n',
#         ' ., [Prop. 6.17]ùis thus medial [Prop 10.21]. Thus, C is\n',
#         '. ,.medial [Prop. 10.21]. And since as A is to B, [so] C (is)\n',
#         ', , [Prop. 10.11]. And C is medial. Thus, D is also medial\n',
#         ', [Prop. 10.23]. Thus, C and D are medial (straight-lines\n',
#         ' . D [Prop. 5.16]. But, as A (is) to C, (so) C (is) to B.\n',
#         'And thus as C (is) to B, so B (is) to D [Prop. 5.11].\n',
#         'the (square) on B [Prop. 6.17]. And the (square) on B\n'],
#        dtype='<U276'),
#  '[Prop 10.28]': array([',, and B, have been taken [Prop. 6.13]. And let it be con, , ,.trived that as B (is) to C, (so) D (is) to E [Prop. 6.12].\n',
#         ' . A and Bùthat is to say, the (square) on D [Prop. 6.17]ù\n',
#         ', .is medial [Prop. 10.21]. Thus, D (is) medial [Prop. 10.21].\n',
#         ' , ,,and as B is to C, (so) D (is) to E, D and E are thus com . , mensurable in square only [Prop. 10.11]. And D (is) me,dial. E (is) thus also medial [Prop. 10.23]. Thus, D and\n',
#         ' . alternately, as B (is) to D, (so) C (is) to E [Prop. 5.16].\n',
#         '[Prop. 6.16]. And the (rectangle contained) by A and C\n',
#         'is medial [Prop. 10.21]. Thus, the (rectangle contained)\n',
#         '.or if an odd (number is subtracted) from an odd (num . ,ber), then the remainder is even [Props. 9.24, 9.26], the\n',
#         ' .square on CD, is equal to the square on BD [Prop. 2.6].\n',
#         ', , , square [Prop. 9.1]. Thus, two square numbers have\n',
#         ' ., equal to the square on BE [Prop. 2.6]. But, the (num . , , ber created) from (multiplying) AB and BC, plus the\n',
#         'the (square) on BF [Prop. 2.6]. And the (number created) from (multiplying) AB and BC, plus the (square)\n'],
#        dtype='<U276'),
#  '[Prop 10.29]': array([', ,and two square numbers, CD and DE, such that the dif ,ference between them, CE, is not square [Prop. 10.28\n',
#         '. square on BA (is) to the square on AF [Prop. 10.6 corr.].\n',
#         ',AF [Prop. 10.6]. And the (square) on AB (is) rational\n',
#         'with AF [Prop. 10.9]. Thus, the rational (straight-lines)\n',
#         '. BF [Props. 5.19 corr., 3.31, 1.47]. And CD has to DE\n',
#         '. has to (some) square number. AB is thus commensurable in length with BF [Prop. 10.9]. And the (square)\n',
#         'FB [Prop. 1.47]. Thus, the square on AB is greater than\n'],
#        dtype='<U276'),
#  '[Prop 10.30]': array([',, them, CD, is not square [Prop. 10.28 lem. II]. And let the\n',
#         ' , ,(is) to the (square) on AF [Prop. 10.6 corr]. And let FB\n',
#         ', AB (is) to the (square) on BF [Props. 5.19 corr., 3.31,\n',
#         '. (some) square number either. Thus, AB is incommensurable in length with BF [Prop. 10.9]. And the square on\n',
#         'FB [Prop. 1.47], (which is) incommensurable (in length)\n'],
#        dtype='<U276'),
#  '[Prop 10.31]': array([' .in length with (A) [Prop. 10.29]. And let the (square)\n',
#         ' , ,, [Prop. 10.21]. Thus, the (square) on C (is) also medial.\n',
#         ' , , Thus, C (is) also medial [Prop. 10.21]. And let the (rect , , ,angle contained) by C and D be equal to the (square)\n',
#         'B (is) to the (square) on B [Prop. 10.21 lem.], but the\n',
#         ',C and D, so C (is) to D [Prop. 10.21 lem.]. And thus\n',
#         '. in square only with D [Prop. 10.11]. And C is medial.\n',
#         'Thus, D (is) also medial [Prop. 10.23]. And since as A is\n',
#         '(C) [Prop. 10.14].\n', '[Prop. 10.30].ç\n'], dtype='<U276'),
#  '[Prop 10.32]': array(['. , , . length) with (A) [Prop. 10.29]. And let the (square)\n',
#         ' ,, Thus, the (square) on D (is) medial. Thus, D is also me, ,dial [Prop. 10.21]. And let the (rectangle contained) by\n',
#         ',.C [Prop. 10.21 lem.], but the (square) on D is equal to\n',
#         ' , ., E, so D (is) to E [Prop. 10.21 lem.]. And thus as A\n',
#         'in square only with E [Prop. 10.11]. And D (is) me, ,dial. Thus, E (is) also medial [Prop. 10.23]. And since\n',
#         'on) E by the (square) on (some straight-line) commensurable (in length) with (D) [Prop. 10.14]. So, I also\n',
#         'square only] [Prop. 10.21], the (rectangle contained) by\n',
#         '(A) [Prop. 10.30].ç\n',
#         ',whole, ABC, and to one another [Prop. 6.8]. And since\n',
#         ' . to BA, so BA (is) to BD [Prop. 6.4]. Thus, the (rectan gle contained) by CBD is equal to the (square) on AB\n',
#         ' . [Prop. 6.17].\n',
#         ', . base, the (straight-line so) drawn is the mean propor,,tional to the pieces of the base [Prop. 6.8 corr.], thus as\n',
#         ' . , DA [Prop. 6.17].\n',
#         'is to CA, so BA (is) to AD [Prop. 6.4]. Thus, the (rectangle contained) by BC and AD is equal to the (rectangle\n',
#         'contained) by BA and AC [Prop. 6.16]. (Which is) the\n'],
#        dtype='<U276'),
#  '[Prop 10.33]': array([' ,, (AB) [Prop. 10.30]. And let BC have been cut in half at\n',
#         'have been applied to AB [Prop. 6.28], and let it be the\n',
#         ', , incommensurable (in length) with EB [Prop. 10.18].\n',
#         ' , , AB and BE to the (square) on BF [Prop. 10.32 lem.].\n',
#         ' , (square) on FB [Prop. 10.11]. Thus, AF and FB are in, . commensurable in square. And since AB is rational, the\n',
#         ' , ,(squares) on AF and FB is also rational [Prop. 1.47].\n',
#         'AB and BC is commensurable with the (rectangle contained) by AB and EF [Prop. 10.6]. And the (rectangle contained) by AB and BC (is) medial [Prop. 10.21].\n',
#         'medial [Prop. 10.23 corr.]. And the (rectangle contained)\n',
#         'AF and FB [Prop. 10.32 lem.]. Thus, the (rectangle contained) by AF and FB (is) also medial. And the sum of\n'],
#        dtype='<U276'),
#  '[Prop 10.34]': array([' ,on) BC by the (square) on (some straight-line) incom- mensurable (in length) with (AB) [Prop. 10.31]. And\n',
#         ', , [Prop. 6.28]. Thus, AF [is] incommensurable in length\n',
#         ',with FB [Prop. 10.18]. And let FD have been drawn\n',
#         ' ,,and BF [Prop. 10.11]. And the (rectangle contained) by\n',
#         ' []- DB [Prop. 10.32 lem.]. Thus, the (square) on AD is also\n',
#         'on AD and DB (is) thus also medial [Props. 3.31, 1.47].\n',
#         'rational [Prop. 10.6, Def. 10.4]. And the (rectangle contained) by AB and FD (is) equal to the (rectangle contained) by AD and DB [Prop. 10.32 lem.]. And hence\n'],
#        dtype='<U276'),
#  '[Prop 10.35]': array([', - (AB) [Prop. 10.32]. And let the semi-circle ADB have\n',
#         ', , [Prop. 10.18], AD is also incommensurable in square\n',
#         ', with DB [Prop. 10.11]. And since the (square) on AB\n',
#         ', .thus also medial [Props. 3.31, 1.47]. And since the (rect ,, . angle contained) by AF and FB is equal to the (square)\n',
#         ' , and FD (is) also medial. And it is equal to the (rectan, , . gle contained) by AD and DB [Prop. 10.32 lem.]. Thus,\n',
#         '[Prop. 10.13]. And hence the (square) on AB is also\n',
#         'and BE [Prop. 10.11]. But the (sum of the squares) on\n',
#         'AD and DB is equal to the (square) on AB [Prop. 1.47].\n'],
#        dtype='<U276'),
#  '[Prop 10.36]': array([' BC [Prop. 10.11]. But, twice the (rectangle contained)\n',
#         ' ,, ,contained) by AB and BC [Prop. 10.6]. And (the sum\n',
#         ' ,[]and BC are commensurable in square only [Prop. 10.15].\n',
#         'and BC [Prop. 10.13]. And, via composition, twice the\n',
#         'on AC [Prop. 2.4]ùis incommensurable with the sum of\n',
#         'the (squares) on AB and BC [Prop. 10.16]. And the sum\n'],
#        dtype='<U276'),
#  '[Prop 10.37]': array([' . that is, the (square) on AC [Prop. 2.4]ùis incommensurable with the (rectangle contained) by AB and BC\n',
#         '[Prop. 10.16]. And the (rectangle contained) by AB and\n'],
#        dtype='<U276'),
#  '[Prop 10.38]': array(['. (area), be laid down together [Prop. 10.28]. I say that\n',
#         ' [Prop. 1.44]. And since the (square) on AC is equal to\n',
#         ', ,, . the (rectangle contained) by AB and BC [Prop. 2.4], so\n',
#         ', , with DE [Prop. 10.22]. Therefore, since AB is incom , .mensurable in length with BC, and as AB is to BC, so\n',
#         ', . AB and BC [Prop. 10.21 lem.], the (square) on AB is\n',
#         ' AB and BC [Prop. 10.11]. But, the sum of the squares\n',
#         ',AB [Prop. 10.15], and twice the (rectangle contained) by\n',
#         '. . AB and BC is commensurable with the (rectangle contained) by AB and BC [Prop. 10.6]. Thus, the sum of the\n',
#         'the (rectangle contained) by AB and BC [Prop. 10.13].\n',
#         'HG [Props. 6.1, 10.11]. Thus, DH and HG are rational (straight-lines which are) commensurable in square\n',
#         'only. Hence, DG is irrational [Prop. 10.36]. And DE (is)\n',
#         'rational (straight-lines) is irrational [Prop. 10.20]. The\n'],
#        dtype='<U276'),
#  '[Prop 10.39]': array([' For let the two straight-lines, AB and BC, incommen, , surable in square, and fulfilling the prescribed (condi. tions), be laid down together [Prop. 10.33]. I say that\n',
#         ',,is [thus] also medial [Props. 10.6, 10.23 corr.]. And the\n',
#         '. BCùthat is, the (square) on AC [Prop. 2.4]ùis also incommensurable with the sum of the (squares) on AB and\n',
#         'BC [Prop. 10.16] [and the sum of the (squares) on AB\n'],
#        dtype='<U276'),
#  '[Prop 10.40]': array([' For let the two straight-lines, AB and BC, incommen, , surable in square, (and) fulfilling the prescribed (condi. tions), be laid down together [Prop. 10.34]. I say that\n',
#         ' . . is also incommensurable with twice the (rectangle contained) by AB and BC [Prop. 10.16]. And twice the\n'],
#        dtype='<U276'),
#  '[Prop 10.41]': array([' For let the two straight-lines, AB and BC, incommen, , surable in square, (and) fulfilling the prescribed (condi. tions), be laid down together [Prop. 10.35]. I say that\n',
#         '.square on AC [Prop. 2.4]. And since the sum of the\n',
#         ' . surable in length with DE [Prop. 10.22]. So, for the same\n',
#         '. . DF is incommensurable with GH. Hence, DG is also incommensurable (in length) with GK [Props. 6.1, 10.11].\n',
#         'called binomial [Prop. 10.36]. And DE (is) rational.\n',
#         '(square) on EB [Prop. 2.5], but, moreover, the (rectan , , . gle contained) by AD and DB, plus the (square) on DE,\n',
#         ',, is also equal to the (square) on EB [Prop. 2.5], the (rect., angle contained) by AC and CB, plus the (square) on\n'],
#        dtype='<U276'),
#  '[Prop 10.42]': array([' . in square only [Prop. 10.36]. I say that AB cannot be\n',
#         'on AB [Prop. 2.4]. But, (the sum of) the (squares) on AC\n',
#         'medial (areas) [Prop. 10.21]. The very thing is absurd.\n',
#         'rational (area) [Prop. 10.26].\n'], dtype='<U276'),
#  '[Prop 10.43]': array(['. containing a rational (area) [Prop. 10.37]. I say that AB\n',
#         '[Prop. 10.41 lem.]. And twice the (rectangle contained)\n',
#         'medial (areas). The very thing is absurd [Prop. 10.26].\n'],
#        dtype='<U276'),
#  '[Prop 10.44]': array([' , . , containing a medial (area) [Prop. 10.38]. So, (it is) clear\n',
#         ', above [Prop. 10.41 lem.]. And AD and DB are medial\n',
#         ' , , []. Thus, the remainder, HK, is equal to twice the (rectan gle contained) by AC and CB [Prop. 2.4]. So, again,\n',
#         ', , .(is) thus [also] medial. And it is applied to the ratio ,, . nal (straight-line) EF. Thus, EH is rational, and incom, , mensurable in length with EF [Prop. 10.22]. So, for the\n',
#         ',(rectangle contained) by AC and CB [Prop. 10.21 lem.].\n',
#         ',(rectangle contained) by AC and CB [Prop. 10.11]. But,\n',
#         '(the sum of) the (squares) on AC and CB is commensu ,rable with the (square) on AC. For, AC and CB are com , ,mensurable in square [Prop. 10.15]. And twice the (rect , . , angle contained) by AC and CB is commensurable with\n',
#         ',, the (rectangle contained) by AC and CB [Prop. 10.6].\n',
#         '. AC and CB [Prop. 10.13]. But, EG is equal to (the sum\n',
#         'mensurable in length with HN [Props. 6.1, 10.11]. And\n',
#         'then the whole (straight-line) is that irrational called binomial [Prop. 10.36]. Thus, EN is a binomial (straightline) which has been divided (into its component terms)\n',
#         '(which is absurd [Prop. 10.42]). And EH is not the same\n',
#         'DB [Prop. 10.59 lem.]. Thus, (the sum of) the (squares)\n',
#         '[Prop. 6.1]. Thus, EH is not the same as MN. (Which\n'],
#        dtype='<U276'),
#  '[Prop 10.45]': array([' . medial [Prop. 10.39]. I say that AB cannot be (so) di, , vided at another point.\n',
#         'impossible [Prop. 10.26]. Thus, a major (straight-line)\n'],
#        dtype='<U276'),
#  '[Prop 10.46]': array([' , ,(squares) on AC and CB medial, and twice the (rectan. gle contained) by AC and CB rational [Prop. 10.40]. I\n',
#         '(areas). The very thing is impossible [Prop. 10.26]. Thus,\n'],
#        dtype='<U276'),
#  '[Prop 10.47]': array([',, - and CB) [Prop. 10.41]. I say that AB cannot be divided\n',
#         ' , ,. AB [Prop. 2.4]. So, again, let EL, equal to (the sum of)\n',
#         'incommensurable in length with EF [Prop. 10.22]. So,\n',
#         'incommensurable with HN [Props. 6.1, 10.11]. And\n',
#         'at H [Prop. 10.36]. So, similarly, we can show that it has\n',
#         'thing is absurd [Prop. 10.42]. Thus, the square-root of\n'],
#        dtype='<U276'),
#  '[Prop 10.48]': array([',,to (some) square number [Prop. 10.28 lem. I]. And let\n',
#         ',to the (square) on FG [Prop. 10.6 corr.]. And AB has to\n',
#         ' , with the (square) on FG [Prop. 10.6]. And EF is ra tional. Thus, FG (is) also rational. And since BA does\n',
#         '[Prop 10.9]. EF and FG are thus rational (straight-lines\n',
#         'a binomial (straight-line) [Prop. 10.36]. I say that (it is)\n',
#         ' , . the (square) on FG [Prop. 5.14]. Therefore, let (the sum\n',
#         ' ,(square) on H [Prop. 5.19 corr.]. And AB has to BC\n',
#         'rable in length with H [Prop. 10.9]. Thus, the square on\n',
#         '1k 2 [Prop. 10.85], are the roots of x\n'], dtype='<U276'),
#  '[Prop 10.49]': array([', ,(has) to (some) square number [Prop. 10.28 lem. I]. And\n',
#         ' , (is) to the (square) on FG [Prop. 10.6 corr.]. Thus, the\n',
#         ',FG [Prop. 10.6]. Thus, FG is also a rational (straight., line). And since the number CA does not have to AB\n',
#         ' , (has) to (some) square number either. Thus, EF is in , []. commensurable in length with FG [Prop. 10.9]. EF and\n',
#         ' , FG are thus rational (straight-lines which are) commen ,surable in square only. Thus, EG is a binomial (straight.,line) [Prop. 10.36]. So, we must show that (it is) also a\n',
#         ' . the (square) on GF (is) to the (square) on FE [Prop. 5.7\n',
#         ', [Prop. 5.14]. Let (the sum of) the (squares) on EF and\n',
#         '. (square) on H [Prop. 5.19 corr.]. But, AB has to BC\n',
#         '(has) to (some) square number. Thus, FG is commensurable in length with H [Prop. 10.9]. Hence, the square on\n',
#         ' 2k [Prop. 10.86], are the roots of x\n'], dtype='<U276'),
#  '[Prop 10.50]': array(['. (is) to the (square) on FG [Prop. 10.6 corr.]. Thus, the\n',
#         ' ,FG [Prop. 10.6]. And E is a rational (straight-line).\n',
#         ' ,[Prop. 10.9]. So, again, let it have been contrived that\n',
#         '(is) to the (square) on GH [Prop. 10.6 corr.]. Thus, the\n',
#         ' .,GH [Prop. 10.6]. And FG (is) a rational (straight-line).\n',
#         '[Prop. 10.9]. FG and GH are thus rational (straight,lines which are) commensurable in square only. Thus,\n',
#         ' FH is a binomial (straight-line) [Prop. 10.36]. So, I say\n',
#         ' , to the (square) on GH [Prop. 5.22]. And D does not\n',
#         ' . [Prop. 10.9]. And since as BA is to AC, so the (square)\n',
#         '(is) thus greater than the (square) on GH [Prop. 5.14].\n',
#         'to the (square) on K [Prop. 5.19 corr.]. And AB has\n',
#         'commensurable in length with K [Prop. 10.9]. Thus,\n',
#         ' 2) [Prop. 10.87], are the roots of x\n'], dtype='<U276'),
#  '[Prop 10.51]': array([' , square number [Prop. 10.28 lem. I]. And let the rational\n',
#         ' , (is) to the (square) on FG [Prop. 10.6 corr.]. Thus, the\n',
#         'FG [Prop. 10.6]. Thus, FG is also a rational (straight ., line). And since BA does not have to AC the ratio which\n',
#         ' .in length with FG [Prop. 10.9]. Thus, EF and FG\n',
#         ' . ,[Prop. 10.36]. So, I say that (it is) also a fourth (binomial\n',
#         ' ., [Prop. 5.14]. Therefore, let (the sum of) the squares on\n',
#         '. EF (is) to the (square) on H [Prop. 5.19 corr.]. And AB\n',
#         '[Prop. 10.9]. Thus, the square on EF is greater than (the\n',
#         ') [Prop. 10.88], are the roots of x\n'], dtype='<U276'),
#  '[Prop 10.52]': array([',[][Prop. 10.38 lem.]. And let some rational straight-line\n',
#         ',.[Prop. 10.6 corr.]. And CA does not have to AB the ra338\n',
#         ',FG are rational (straight-lines which are) commensu. rable in square only [Prop. 10.9]. Thus, EG is a binomial\n',
#         ',(straight-line) [Prop. 10.36]. So, I say that (it is) also a\n',
#         ' .[Prop. 5.7 corr.]. Thus, the (square) on GF (is) greater\n',
#         ' than the (square) on FE [Prop. 5.14]. Therefore, let\n',
#         'on H [Prop. 5.19 corr.]. And AB does not have to BC\n',
#         'incommensurable in length with H [Prop. 10.9]. Hence,\n',
#         '1) [Prop. 10.89], are the roots of x\n'], dtype='<U276'),
#  '[Prop 10.53]': array([', (some) square number (has) to (some) square number ei ,ther [Prop. 10.28 lem. I]. And let some rational straight line E be laid down. And let it have been contrived that\n',
#         ' ,on FG [Prop. 10.6 corr.]. Thus, the (square) on E (is)\n',
#         ',commensurable with the (square) on FG [Prop. 10.6].\n',
#         ' ,with FG [Prop. 10.9]. So, again, let it have be contrived\n',
#         'the (square) on GH [Prop. 10.6 corr.]. The (square) on\n',
#         ' ., [Prop. 10.6]. The (square) on HG (is) thus rational.\n',
#         '. FG is incommensurable in length with GH [Prop. 10.9].\n',
#         ', (straight-line) [Prop. 10.36]. So, we must show that (it\n',
#         ' , to the (square) on GH [Prop. 5.22]. And D does not\n',
#         ' . [Prop. 10.9]. And (E) was also shown (to be) incom , , mensurable (in length) with FG. Thus, FG and GH\n',
#         'than the (square) on GH [Prop. 5.14]. Therefore, let\n',
#         '[Prop. 5.19 corr.]. And AB does not have to BC the ratio which (some) square number (has) to (some) square\n',
#         'incommensurable in length with K [Prop. 10.9]. The\n',
#         ' [Prop. 10.90], are the roots of x\n',
#         ' ,,of AK and HC [Prop. 1.34]. Thus, AH and KC are also\n',
#         ',,BE, so DG (is) to BC [Prop. 6.1], thus also as AB (is)\n',
#         '., . to DG, so DG (is) to BC [Prop. 5.11]. Thus, DG is the\n',
#         ' ,,, to KD, so KC (is) to CG [Prop. 5.18]. But as AK (is)\n',
#         '.,(is) to CB [Prop. 6.1]. Thus, also, as AC (is) to DC,\n',
#         '. so DC (is) to BC [Prop. 5.11]. Thus, DC is the mean\n'],
#        dtype='<U276'),
#  '[Prop 10.54]': array(['.- are) commensurable (in length) [Prop 10.17]. Therefore,\n',
#         '., constructed, and (the square) NQ, equal to (the parallelogram) GK [Prop. 2.14]. And let MN be laid down so\n',
#         ' , , to NP. And let the parallelogram SQ have been com pleted. SQ is thus a square [Prop. 10.53 lem.]. And since\n',
#         ' , . [Prop. 6.17]. And thus as AH (is) to EL, (so) EL (is)\n',
#         ',. to KG [Prop. 6.1]. Thus, EL is the mean proportional to\n',
#         ' ,, , (namely), SN and NQ [Prop. 10.53 lem.]. EL is thus\n',
#         ',.equal to MR. Hence, it is also equal to PO [Prop. 1.43].\n',
#         ' ,and GE [Prop. 10.15]. And AE was also assumed (to\n',
#         ' . [Prop. 10.12]. And AB is rational. AG and GE are\n',
#         '[Prop. 10.19]. But, AH is equal to SN, and GK to NQ.\n',
#         '[Prop. 10.13]. Hence, AH is also incommensurable with\n',
#         'EL [Props. 6.1, 10.11]. But, AH is equal to SN, and\n',
#         '[Prop. 6.1]. PN is thus incommensurable (in length)\n',
#         'with NR [Prop. 10.11]. And PN (is) equal to MN, and\n',
#         'Thus, MO is (both) a binomial (straight-line) [Prop.\n'],
#        dtype='<U276'),
#  '[Prop 10.55]': array(['[Prop. 10.17]. And let GH, EK, and FL have been\n',
#         ',., , [Prop. 10.53 lem.] that MR is the mean proportional to\n',
#         ', ]. , [Prop. 10.13]. And since AG is commensurable (in\n',
#         ',with each of AG and GE [Prop. 10.15]. But, AE is in, , commensurable in length with AB. Thus, AG and GE\n',
#         ' .,[Prop. 10.13]. Thus, BA, AG, and (BA, and) GE are\n',
#         ',,is a medial (area) [Prop. 10.21]. Hence, each of SN\n',
#         '. MN and NO are commensurable in square] [Props. 6.1,\n',
#         'incommensurable (in length) with EF [Prop. 10.13].\n',
#         '[Props. 6.1, 10.11]. But MN and NO have also been\n',
#         '[Prop. 10.12]. And they (are) each rational. Thus, ELù\n',
#         'that is to say, MRù(is) rational [Prop. 10.19]. And MR\n',
#         'first bimedial [Prop. 10.37].\n'], dtype='<U276'),
#  '[Prop 10.56]': array(['in length with EK [Prop. 10.13]. And they are (both)\n',
#         'ELùthat is to say, MRù[is] thus medial [Prop. 10.21].\n',
#         'Thus, MO is a second bimedial (straight-line) [Prop.\n'],
#        dtype='<U276'),
#  '[Prop 10.57]': array(['. in length with GE [Prop. 10.18]. Let GH, EK, and FL\n',
#         ' , .[] with NQ [Props. 6.1, 10.11]. Thus, MN and NO are\n',
#         ', , ,incommensurable in square. And since AE is commensu.rable in length with AB, AK is rational [Prop. 10.19].\n',
#         ' ,rable in length with AB [Prop. 10.13]ùthat is to say,\n',
#         '[Prop. 10.13]. Thus, EK and EF are rational (straightlines which are) commensurable in square only. LEù\n',
#         'that is to say, MRù(is) thus medial [Prop. 10.21]. And it\n',
#         'whole is the irrational (straight-line which is) called major [Prop. 10.39].\n'],
#        dtype='<U276'),
#  '[Prop 10.58]': array([' , . GE [Prop. 10.18], AH is thus also incommensurable\n',
#         ' , . (square) on NO [Props. 6.1, 10.11]. Thus, MN and\n',
#         ', , are) commensurable in square only] [Prop. 10.13]. Thus,\n',
#         ' - and NOùis medial [Prop. 10.21]. And since DE is\n',
#         '[Prop. 10.12]. And EK (is) rational. Thus, ELùthat\n',
#         'by MNOù(is) also rational [Prop. 10.19]. MN and NO\n',
#         'Thus, MO is the square-root of a rational plus a medial (area) [Prop. 10.40]. And (it is) the square-root of\n'],
#        dtype='<U276'),
#  '[Prop 10.59]': array(['. and NOùis medial [Prop. 10.21]. Again, since ED\n',
#         ' [Prop. 10.13]. Thus, FE and EK are rational (straight .lines which are) commensurable in square only. Thus,\n',
#         '. contained) by MNOùis medial [Prop. 10.21]. And since\n',
#         '. incommensurable with EL [Props. 6.1, 10.11]. But, AK\n',
#         'Thus, MO is the square-root of (the sum of) two medial (areas) [Prop. 10.41]. And (it is) the square-root of\n',
#         ' . , [] to the (square) on AD [Prop. 2.5]. Hence, the (rectangle\n',
#         'sum of) the (squares) on AD and DC [Prop. 2.9]. Thus,\n'],
#        dtype='<U276'),
#  '[Prop 10.60]': array([' . AC and CB is equal to MF [Prop. 2.4]. Let MG have\n',
#         ' ,in square only [Prop. 10.36]. Thus, the (squares) on AC\n',
#         ' , , . CB (is rational) [Prop. 10.15], and is equal to DL. Thus,\n',
#         ' length with DE [Prop. 10.20]. Again, since AC and CB\n',
#         ', ,CBùthat is to say, MFùis thus medial [Prop. 10.21].\n',
#         ', with MLùthat is to say, with DE [Prop. 10.22]. And\n',
#         ' .[Prop. 10.13]. And they are rational. DM and MG are\n',
#         ', , [Prop. 10.36]. So, we must show that (it is) also a first\n',
#         ', [Prop. 10.53 lem.], MO is thus also the mean propor tional to DH and KL. Thus, as DH is to MO, so\n',
#         ', , (so) MN (is) to MK [Prop. 6.1]. Thus, the (rectan . gle contained) by DK and KM is equal to the (square)\n',
#         'on MN [Prop. 6.17]. And since the (square) on AC is\n',
#         'commensurable with KL. Hence, DK is also commensurable with KM [Props. 6.1, 10.11]. And since (the sum\n',
#         '(rectangle contained) by AC and CB [Prop. 10.59 lem.],\n',
#         'greater than MG [Props. 6.1, 5.14]. And the (rectangle contained) by DK and KM is equal to the (square)\n',
#         '[Prop. 10.17]. Thus, the square on DM is greater than\n'],
#        dtype='<U276'),
#  '[Prop 10.61]': array([' .[Prop. 10.37]. Hence, the (squares) on AC and CB\n',
#         ' [],are also medial [Prop. 10.21]. Thus, DL is medial\n',
#         ' . [Props. 10.15, 10.23 corr.]. And it has been applied to the\n',
#         ',rational (straight-line) DE. MD is thus rational, and in., commensurable in length with DE [Prop. 10.22]. Again,\n',
#         ',say, with DE [Prop. 10.20]. DM is thus incommensu . rable in length with MG [Prop. 10.13]. And they are\n',
#         '. [Prop. 10.36]. So, we must show that (it is) also a second\n',
#         'CB [Prop. 10.59], DL (is) thus also greater than MF.\n',
#         'Hence, DM (is) also (greater) than MG [Prop. 6.1].\n',
#         'KM [Props. 6.1, 10.11]. And the (rectangle contained)\n',
#         'length) with (DM) [Prop. 10.17]. And MG is commensurable in length with DE.\n'],
#        dtype='<U276'),
#  '[Prop 10.62]': array([' .and containing a medial (area) [Prop. 10.38]. Hence,\n',
#         ' , [Props. 10.15, 10.23 corr.]. And it is equal to DL. Thus,\n',
#         ',commensurable in length with DE [Prop. 10.22]. So,\n',
#         ',. ACB [Prop. 10.21 lem.], the (square) on AC (is) also incommensurable with the (rectangle contained) by ACB\n',
#         ' .[Prop. 10.11]. And hence the sum of the (squares) on\n',
#         '[Props. 10.12, 10.13]. Hence, DM is also incommensurable (in length) with MG [Props. 6.1, 10.11]. And\n',
#         '[Prop. 10.36]. [So] we must show that (it is) also a third\n',
#         'MG by the (square) on (some straight-line) commensurable (in length) with (DM) [Prop. 10.17]. And neither\n'],
#        dtype='<U276'),
#  '[Prop 10.63]': array([' . ,, , [Prop. 10.39]. Therefore, since the sum of the (squares)\n',
#         ' .,DE [Prop. 10.20]. Again, since twice the (rectangle con tained) by AC and CBùthat is to say, MFùis medial,\n',
#         ' ,DE [Prop. 10.22]. DM is thus also incommensurable\n',
#         ' .in length with MG [Prop. 10.13]. DM and MG are\n',
#         ',[Prop. 10.36]. [So] we must show that (it is) also a fourth\n',
#         'KM [Props. 6.1, 10.11]. And if there are two unequal\n',
#         'lesser by the (square) on (some straight-line) incommensurable in length with the greater [Prop. 10.18]. Thus,\n'],
#        dtype='<U276'),
#  '[Prop 10.64]': array([', , (rectangle contained) by them rational [Prop. 10.40].\n',
#         '., and incommensurable in length with DE [Prop. 10.22].\n',
#         ', and commensurable (in length) with DE [Prop. 10.20].\n',
#         ' . [Prop. 10.13]. Thus, DM and MG are rational (straight ,[] ,lines which are) commensurable in square only. Thus,\n',
#         ' . DG is a binomial (straight-line) [Prop. 10.36]. So, I say\n',
#         '(DM) [Prop. 10.18]. And DM and MG are [rational]\n'],
#        dtype='<U276'),
#  '[Prop 10.65]': array([' , the (rectangle contained) by them [Prop. 10.41]. Hence,\n',
#         ' .,[Prop. 10.22]. And since the sum of the (squares) on\n',
#         ' length) with MG [Props. 6.1, 10.11]. DM and MG are\n',
#         '[Prop. 10.36]. So, I say that (it is) also a sixth (binomial\n',
#         'on) MG by the (square) on (some straight-line) incommensurable in length with (DM) [Prop. 10.18]. And neither of DM and MG is commensurable in length with the\n'],
#        dtype='<U276'),
#  '[Prop 10.66]': array([' ,[Prop. 10.36]. Let it have been contrived that as AB (is)\n',
#         '. to CD, so AE (is) to CF [Prop. 6.12]. Thus, the remain , . , der EB is also to the remainder FD, as AB (is) to CD\n',
#         ', . [Props. 6.16, 5.19 corr.]. And AB (is) commensurable\n',
#         '. ,[](in length) with CF, and EB with FD [Prop. 10.11].\n',
#         ' . [Prop. 5.11]. Thus, alternately, as AE is to EB, (so)\n',
#         'CF (is) to FD [Prop. 5.16]. And AE and EB [are]\n',
#         ',also commensurable in square only [Prop. 10.11]. And\n',
#         ' ,[Prop. 10.36]. So, I say that it is the same in order as\n',
#         ' .length) with (CF) [Prop. 10.14]. And if AE is com, mensurable (in length) with (some previously) laid down\n',
#         ' ,.,rational (straight-line) then CF will also be commensu ,. , rable (in length) with it [Prop. 10.12]. And, on account\n',
#         ' . laid down rational (straight-line) then FD is also commensurable (in length) with it [Prop. 10.12], and, again,\n',
#         'be commensurable (in length) with it [Prop. 10.13], and\n',
#         '(in length) with (CF) [Prop. 10.14]. And if AE is commensurable (in length) with the (previously) laid down\n',
#         '(in length) with it [Prop. 10.12], and each (of AB and\n'],
#        dtype='<U276'),
#  '[Prop 10.67]': array([', which are) commensurable in square only [Props. 10.37,\n',
#         ',, .CD, (so) AE (is) to CF [Prop. 6.12]. And thus as the\n',
#         ',, , [Props. 5.19 corr., 6.16]. And AB (is) commensurable\n',
#         ' ., . [Prop. 10.11]. And AE and EB (are) medial. Thus, CF\n',
#         ' ,,and FD (are) also medial [Prop. 10.23]. And since as\n',
#         ' ,also commensurable in square only [Prop. 10.11]. And\n',
#         ', ,. also as the (square) on AE (is) to the (rectangle con tained) by AEB, so the (square) on CF (is) to the (rect . angle contained) by CFD [Prop. 10.21 lem.]. Alternately, as the (square) on AE (is) to the (square) on\n',
#         '(rectangle contained) by CFD [Prop. 5.16]. And the\n',
#         'CFD [Prop. 10.11]. Therefore, either the (rectangle\n',
#         'are each second (bimedial straight-lines) [Props. 10.23,\n'],
#        dtype='<U276'),
#  '[Prop 10.68]': array([', , (rectangle contained) by them medial [Prop. 10.39]. And\n',
#         ' ,,so EB (is) to FD [Prop. 5.11]. And AB (is) commen , ,surable (in length) with CD. Thus, AE and EB (are)\n',
#         ',also commensurable (in length) with CF and FD, re,spectively [Prop. 10.11]. And since as AE is to CF, so\n',
#         ', CF (is) to FD [Prop. 5.16], and thus, via composition,\n',
#         ' .as AB is to BE, so CD (is) to DF [Prop. 5.18]. And thus\n',
#         ' (square) on CD (is) to the (square) on DF [Prop. 6.20].\n',
#         ', FD [Prop. 5.16]. And the (square) on AB (is) commen surable with the (square) on CD. Thus, (the sum of) the\n',
#         ' (the sum of) the (squares) on CF and FD [Prop. 10.11].\n',
#         'and FD (is) also medial [Prop. 10.23 corr.]. CF and FD\n',
#         'square [Prop 10.13], simultaneously making the sum of\n',
#         'irrational (straight-line) called major [Prop. 10.39].\n'],
#        dtype='<U276'),
#  '[Prop 10.69]': array([' ,[Prop. 10.40]. And let the same construction have been\n',
#         '(area) [Prop. 10.40]. (Which is) the very thing it was\n'],
#        dtype='<U276'),
#  '[Prop 10.70]': array([', , ,by AE and EB [Prop. 10.41]. And let the same construc,tion have been made as in the previous (propositions).\n',
#         'Thus, CD is the square-root of (the sum of) two medial (areas) [Prop. 10.41]. (Which is) the very thing it\n'],
#        dtype='<U276'),
#  '[Prop 10.71]': array(['.commensurable in length with EF [Prop. 10.20]. Again,\n',
#         '. , and incommensurable in length with EF [Prop. 10.22].\n',
#         '.,to HK [Prop. 6.1]. Thus, EH is also incommensurable\n',
#         ' , ,in length with HK [Prop. 10.11]. And they are both ra . tional. Thus, EH and HK are rational (straight-lines\n',
#         'component terms) at H [Prop. 10.36]. And since AB\n',
#         ' ,also greater than HK [Prop. 5.14]. Therefore, the square\n',
#         ' . (straight-line) then the square-root of the area is a bino . mial (straight-line) [Prop. 10.54]. Thus, the square-root\n',
#         ', called major [Prop. 10.57]. Thus, the square-root of area\n',
#         ' than HI. Hence, EH is also less than HK [Props. 6.1,\n',
#         'the square-root of the area is a first bimedial (straightline) [Prop. 10.55]. Thus, the square-root of area EI is\n',
#         'plus a medial (area) [Prop. 10.58]. Thus, the square-root\n'],
#        dtype='<U276'),
#  '[Prop 10.72]': array([' in length with EF [Prop. 10.22]. And since AB is incom. mensurable with CD, and AB is equal to EG, and CD\n',
#         ',as EG (is) to HI, so EH is to HK [Prop. 6.1]. EH is\n',
#         ' thus incommensurable in length with HK [Prop. 10.11].\n',
#         ' (straight-line) [Prop. 10.36]. And the square on EH is\n',
#         ' area is a second bimedial (straight-line) [Prop. 10.56].\n',
#         ' sum of) two medial (areas) [Prop. 10.59]. Hence, the\n',
#         'straight-line) to which it is applied [Prop. 10.22]. And\n',
#         'rational (straight-line), produces as breadth a first binomial [Prop. 10.60]. And the (square) on a first bimedial\n',
#         '(straight-line), applied to a rational (straight-line), produces as breadth a second binomial [Prop. 10.61]. And\n',
#         'binomial [Prop. 10.62]. And the (square) on a major\n',
#         '(straight-line), applied to a rational (straight-line), produces as breadth a fourth binomial [Prop. 10.63]. And\n',
#         'breadth a fifth binomial [Prop. 10.64]. And the (square)\n',
#         'a sixth binomial [Prop. 10.65]. And the aforementioned\n'],
#        dtype='<U276'),
#  '[Prop 10.73]': array([' ,, , (rectangle contained) by AB and BC [Prop. 10.21 lem.],\n',
#         ' , ,(rectangle contained) by AB and BC [Prop. 10.11]. But,\n',
#         ' , the (sum of the) squares on AB and BC is commen., surable with the (square) on AB [Prop. 10.15], and\n',
#         'BC [Prop. 10.6]. And, inasmuch as the (sum of the\n',
#         '[Prop. 2.7], the (sum of the squares) on AB and BC is\n',
#         'on AC [Props. 10.13, 10.16]. And the (sum of the\n'],
#        dtype='<U276'),
#  '[Prop 10.74]': array([' , ,AB [Prop. 10.27]. I say that the remainder AC is an ir , . , rational (straight-line). Let it be called the first apotome\n',
#         'AB and BC is also incommensurable with the remaining (square) on AC [Prop. 2.7], since if the whole is incommensurable with one of the (constituent magnitudes)\n',
#         'then the original magnitudes will also be incommensurable (with one another) [Prop. 10.16]. And twice the\n'],
#        dtype='<U276'),
#  '[Prop 10.75]': array(['from the medial (straight-line) AB [Prop. 10.28]. I say\n',
#         'the (square) on AC [Prop. 2.7]. And since the (squares)\n',
#         ', , , one another), DE (is) thus also medial [Props. 10.15,\n',
#         'and incommensurable in length with DI [Prop. 10.22].\n',
#         ' , .is thus also medial [Prop. 10.23 corr.]. And it is equal\n',
#         ' , . , , length with DI [Prop. 10.22]. And since AB and BC are\n',
#         ',AB and BC [Props. 10.21 lem., 10.11]. But, the (sum\n',
#         ', the (square) on AB [Prop. 10.15], and twice the (rectan .gle contained) by AB and BC is commensurable with the\n',
#         '. (rectangle contained) by AB and BC [Prop. 10.6]. Thus,\n',
#         'BC [Prop. 10.13]. And DE is equal to the (sum of the\n',
#         'DF [Prop. 6.1]. Thus, GD is incommensurable with DF\n',
#         '[Prop. 10.11]. And they are both rational (straight-lines).\n',
#         '[Prop. 10.73]. And DI (is) rational. And the (area) contained by a rational and an irrational (straight-line) is\n',
#         'irrational [Prop. 10.20], and its square-root is irrational.\n'],
#        dtype='<U276'),
#  '[Prop 10.76]': array([' ,straight-line AB [Prop. 10.33]. I say that the remainder\n',
#         'the remaining (square) on AC [Props. 2.7, 10.16]. And\n'],
#        dtype='<U276'),
#  '[Prop 10.77]': array([' ,AB [Prop. 10.34]. I say that the remainder AC is the\n',
#         '. on AC is also incommensurable with twice the (rectangle contained) by AB and BC [Props. 2.7, 10.16]. And\n'],
#        dtype='<U276'),
#  '[Prop 10.78]': array([',(conditions), have been subtracted from the (straight. line) AB [Prop. 10.35]. I say that the remainder AC is\n',
#         ' . ,to the (square) on AC [Prop. 2.7]. Hence, AC is the\n',
#         ', , incommensurable in length with DI [Prop 10.22]. Again,\n',
#         '. as breadth. Thus, DF is also rational, and incommen [],surable in length with DI [Prop. 10.22]. And since the\n',
#         'DH, so DG also is to DF [Prop. 6.1]. Thus, DG (is) incommensurable (in length) with DF [Prop. 10.11]. And\n',
#         'only. Thus, FG is an apotome [Prop. 10.73]. And FH\n',
#         '(straight-line) and an apotome is irrational [Prop. 10.20],\n'],
#        dtype='<U276'),
#  '[Prop 10.79]': array([' commensurable in square only [Prop. 10.73]. I say that\n',
#         ',are) commensurable in square only [Prop. 10.73]. And\n',
#         ',,(namely), the (square) on AB [Prop. 2.7]. Thus, alter ,nately, by whatever (area) the (sum of the squares) on\n',
#         'and CB by a rational (area). The very thing is impossible. For both are medial (areas) [Prop. 10.21], and a\n',
#         'a rational (area) [Prop. 10.26]. Thus, another rational\n'],
#        dtype='<U276'),
#  '[Prop 10.80]': array([',(namely, that contained) by AC and CB [Prop. 10.74].\n',
#         ' ,, .[Prop. 10.74]. And since by whatever (area) the (sum of\n',
#         '[Prop. 2.7]. Thus, alternately, by whatever (area) the\n',
#         '[Props. 10.15, 10.23 corr.], and a medial (area) cannot exceed a(nother) medial (area) by a rational (area)\n',
#         '[Prop. 10.26].\n'], dtype='<U276'),
#  '[Prop 10.81]': array([',contained) by AC and CB [Prop. 10.75]. I say that\n',
#         ' (namely, that contained) by AD and DB [Prop. 10.75].\n',
#         ' . to the (square) on AB [Prop. 2.7]. Hence, AB is the\n',
#         ' the (rectangle contained) by AD and DB [Prop. 2.7].\n',
#         ',[Props. 10.15, 10.23 corr.]. And it is applied to the ratio, . nal (straight-line) EF, producing EM as breadth. Thus,\n',
#         ' ,, [Prop. 10.22]. Again, since the (rectangle contained) by\n',
#         ' ,, by AC and CB is also medial [Prop. 10.23 corr.]. And it\n',
#         '.,as breadth. Thus, HM is also rational, and incommen surable in length with EF [Prop. 10.22]. And since AC\n',
#         ' to CB, so the (square) on AC is to the (rectangle con. tained) by AC and CB [Prop. 10.21 corr.]. Thus, the\n',
#         '(square) on AC is incommensurable with the (rectan ,gle contained) by AC and CB [Prop. 10.11]. But, the\n',
#         'with the (square) on AC, and twice the (rectangle contained) by AC and CB is commensurable with the (rectangle contained) by AC and CB [Prop. 10.6]. Thus,\n',
#         'CB [Prop. 10.13]. And EG is equal to the (sum of the\n',
# ...
#         'with CD [Prop. 10.20]. Therefore, since the (sum of the\n',
#         'FM [Prop. 6.1]. Thus, CM (is) incommensurable in\n',
#         'length with FM [Prop. 10.11]. And they are both rational (straight-lines). Thus, CM and MF are rational\n',
#         'CF is thus an apotome [Prop. 10.73]. So, I say that (it\n',
#         ', , ,to the squares on AG and GB [Prop. 10.21 lem.], and\n',
#         ',[Prop. 5.11]. But, as CH (is) to NL, so CK is to NM,\n',
#         ', , and as NL (is) to KL, so NM is to MK [Prop. 6.1].\n',
#         '[ Thus, as CK (is) to NM, so NM is to KM [Prop. 5.11].\n',
#         ', ].to the (square) on NM [Prop. 6.17]ùthat is to say, to\n',
#         'commensurable in length with (CM) [Prop. 10.17]. The\n'],
#        dtype='<U276'),
#  '[Prop 10.99]': array(['in square only, containing a medial (area) [Prop. 10.75].\n',
#         ', . , (is) thus also medial [Props. 10.15, 10.23 corr.]. And it\n',
#         ', has been applied to the rational (straight-line) CD, pro, .ducing CM as breadth. Thus, CM is rational, and incom, . mensurable in length with CD [Prop. 10.22]. And since\n',
#         ', []AB, the remainder LF is thus equal to twice the (rectangle contained) by AG and GB [Prop. 2.7]. Therefore,\n',
#         '. , CD [Prop. 10.22]. And since AG and GB are commen surable in square only, AG [is] thus incommensurable in\n',
#         ', GB [Props. 6.1, 10.11]. But, the (sum of the squares)\n',
#         ' .,GB [Prop. 10.13]. But, CL is equal to the (sum of the\n',
#         ' [,]is to FM [Prop. 6.1]. CM is thus incommensurable in\n',
#         '., , length with FM [Prop. 10.11]. And they are both rational (straight-lines). Thus, CM and MF are rational\n',
#         ' ,CF is thus an apotome [Prop. 10.73]. So, I say that (it\n',
#         ' . in length) with KM [Props. 6.1, 10.11]. And since the\n',
#         '(rectangle contained) by AG and GB is the mean proportional to the (squares) on AG and GB [Prop. 10.21 lem.],\n',
#         'and as NL (is) to KL, so NM (is) to KM [Prop. 6.1].\n',
#         'Thus, as CK (is) to MN, so MN is to KM [Prop. 5.11].\n',
#         'part of the (square) on FM [Prop. 6.17]. Therefore,\n',
#         '(in length) with (CM) [Prop. 10.17]. And neither of\n'],
#        dtype='<U276'),
#  '[Prop 10.100]': array([' ,. the squares on AG and GB rational, and twice the (rect,angle contained) by AG and GB medial [Prop. 10.76].\n',
#         ' , .as breadth. Thus, CM (is) also rational, and commen ,, surable in length with CD [Prop. 10.20]. And since the\n',
#         'contained) by AG and GB [Prop. 2.7]. Therefore, let\n',
#         ', [Prop. 10.22]. And since the sum of the (squares) on AG\n',
#         ', ,FL, so CM is to MF [Prop. 6.1]. CM is thus incommen, , surable in length with MF [Prop. 10.11]. And both are\n',
#         ' .CF is thus an apotome [Prop. 10.73]. [So], I say that (it\n',
#         'CK is to KM [Prop. 6.1]. CK is thus incommensurable\n',
#         ' ,, in length with KM [Prop. 10.11]. And since the (rectan.gle contained) by AG and GB is the mean proportional\n',
#         ' to the (squares) on AG and GB [Prop. 10.21 lem.], and\n',
#         'KL, so NM is to KM [Prop. 6.1]. Thus, as CK (is) to\n',
#         'MN, so MN is to KM [Prop. 5.11]. The (rectangle contained) by CK and KM is thus equal to the (square) on\n',
#         'FM [Prop. 6.17]. Therefore, since CM and MF are two\n',
#         '(in length) with (CM) [Prop. 10.18]. And the whole of\n'],
#        dtype='<U276'),
#  '[Prop 10.101]': array([', the (rectangle contained) by them rational [Prop. 10.77].\n',
#         ' , , ,been applied to the rational (straight-line) CD, produc , .ing CM as breadth. CM is thus rational, and incommen, surable (in length) with CD [Prop. 10.22]. And since\n',
#         '[] , AB, the remainder FL is thus equal to twice the (rect.angle contained) by AG and GB [Prop. 2.7]. Therefore,\n',
#         ' ,[Prop. 10.20]. And since CL is medial, and FL rational,\n',
#         ', , FL, so CM (is) to MF [Prop. 6.1]. CM is thus incom,. mensurable in length with MF [Prop. 10.11]. And both\n',
#         ', , thus an apotome [Prop. 10.73]. So, I say that (it is) also\n',
#         'And as CH (is) to KL, so CK (is) to KM [Prop. 6.1].\n',
#         '[Prop. 10.11]. Therefore, since CM and MF are two unequal straight-lines, and (some area), equal to the fourth\n',
#         '[Prop. 10.18]. And the attachment FM is commensurable with the (previously) laid down rational (straightline) CD. Thus, CF is a fifth apotome [Def. 10.15].\n'],
#        dtype='<U276'),
#  '[Prop 10.102]': array(['the (rectangle contained) by AG and GB [Prop. 10.78].\n',
#         '.CD [Prop. 10.22]. Therefore, since CL is equal to the\n',
#         '[]. , [Prop. 2.7]. And twice the (rectangle contained) by AG\n',
#         ', . in length with CD [Prop. 10.22]. And since the (sum\n',
#         ' ., (is) to FL, so CM is to MF [Prop. 6.1]. Thus, CM is\n',
#         'incommensurable in length with MF [Prop. 10.11]. And\n',
#         ',, CF is thus an apotome [Prop. 10.73]. So, I say that (it\n',
#         '[Prop. 6.1]. Thus, CK is incommensurable (in length)\n',
#         'with KM [Prop. 10.11]. And since the (rectangle contained) by AG and GB is the mean proportional to the\n',
#         '(squares) on AG and GB [Prop. 10.21 lem.], and CH\n',
#         'incommensurable (in length) with (CM) [Prop. 10.18].\n'],
#        dtype='<U276'),
#  '[Prop 10.103]': array(['. are) commensurable in square only [Prop. 10.73]. And\n',
#         ' [] is the same as the ratio of AB to CD [Prop. 6.12]. Thus,\n',
#         ',. also, as one is to one, (so) all [are] to all [Prop. 5.12].\n',
#         '.,CF, and BE with DF [Prop. 10.11]. And AE and\n',
#         '. [Prop. 10.13]. [CD is thus an apotome. So, I say that (it\n',
#         ', FD [Prop. 5.16]. So, the square on AE is greater\n',
#         'on) FD by the (square) on (some straight-line) commen. surable (in length) with (CF) [Prop. 10.14]. And if AE\n',
#         'rational (straight-line) then so (is) CF [Prop. 10.12],\n',
#         'either of CF or FD [Prop. 10.13]. And if the (square)\n',
#         '(CF) [Prop. 10.14]. And if AE is commensurable in\n',
#         'length with a (previously) laid down rational (straightline), so (is) CF [Prop. 10.12], and if BE (is commensurable), so (is) DF, and if neither of AE or EB\n',
#         '[Prop. 10.13].\n'], dtype='<U276'),
#  '[Prop 10.104]': array(['. ,in square only [Props. 10.74, 10.75]. And let it have\n',
#         '.,[Prop. 6.12]. Thus, AE [is] also commensurable (in\n',
#         ' . length) with CF, and BE with DF [Props. 5.12, 10.11].\n',
#         ',, ],square only [Props. 10.23, 10.13]. Thus, CD is an apo , ,tome of a medial (straight-line) [Props. 10.74, 10.75].\n',
#         ' , ]. [Props. 5.12, 5.16] [but as AE (is) to EB, so the (square)\n',
#         '. and EB, so the (square) on CF also (is) to the (rectangle contained) by CF and FD [Prop. 10.21 lem.] [and,\n',
#         'CF and FD [Props. 5.16, 10.11]. Therefore, either the\n',
#         'FD [is] also medial [Prop. 10.23 corr.].\n',
#         'Therefore, CD is the apotome of a medial (straightline), and is the same in order as AB [Props. 10.74,\n'],
#        dtype='<U276'),
#  '[Prop 10.105]': array([',.[Prop. 10.76], CF and FD are thus also (straight-lines\n',
#         ',, which are) incommensurable in square [Prop. 10.13].\n',
#         '][Props. 5.12, 5.16], thus also as the (square) on AE is\n',
#         ' ,- (square) on FD [Prop. 6.22]. Thus, via composition, as\n',
#         ',. ,the (square) on FD [Prop. 5.18], [also alternately]. And\n',
#         ', ,on DF [Prop. 10.104]. The sum of the squares on AE\n',
#         ' , , .squares on CF and FD [Prop. 5.16, 10.11]. And the sum\n',
#         ',,of the (squares) on AE and EB is rational [Prop. 10.76].\n',
#         'CF and FD [Prop. 10.21 lem.], and the square on AE\n',
#         'And the (rectangle contained) by AE and EB (is) medial [Prop. 10.76]. Thus, the (rectangle contained) by\n',
#         'CF and FD (is) also medial [Prop. 10.23 corr.]. CF and\n',
#         'Thus, CD is a minor (straight-line) [Prop. 10.76].\n'],
#        dtype='<U276'),
#  '[Prop 10.106]': array([', , [Prop. 10.77]. And let the same construction have been\n',
#         '(area) makes a medial whole [Prop. 10.77]. (Which is)\n'],
#        dtype='<U276'),
#  '[Prop 10.107]': array([', ,,them [Prop. 10.78]. And, as was shown (previously), AE\n',
#         '(area) makes a medial whole [Prop. 10.78]. (Which is)\n'],
#        dtype='<U276'),
#  '[Prop 10.108]': array([' . (straight-line) FG. Thus, FH (is) rational, and commen. surable in length with FG [Prop. 10.20], and FK (is)\n',
#         '[Prop. 10.22]. Thus, FH is incommensurable in length\n',
#         ' .with FK [Prop. 10.13]. FH and FK are thus rational\n',
#         ', . Thus, KH is an apotome [Prop. 10.73], and KF an at tachment to it. So, the square on HF is greater than\n',
#         'by a rational (straight-line) and a first apotome is an apotome [Prop. 10.91]. Thus, the square-root of LHùthat\n',
#         'fourth apotome [Prop. 10.14]. And the square-root of an\n',
#         'apotome is a minor (straight-line) [Prop. 10.94]. (Which\n'],
#        dtype='<U276'),
#  '[Prop 10.109]': array(['mensurable in square only [Prop. 10.13]. KH is thus\n',
#         'an apotome [Prop. 10.73], and FK an attachment to it.\n',
#         ' ,a first apotome of a medial (straight-line) [Prop. 10.92].\n',
#         'a medial whole [Prop. 10.95]. (Which is) the very thing\n'],
#        dtype='<U276'),
#  '[Prop 10.110]': array([' ,. FK will each be rational (straight-lines), and incommen , , surable in length with FG [Prop. 10.22]. And since BC\n',
#         ' . FK [Props. 6.1, 10.11]. Thus, FH and FK are ratio ]. nal (straight-lines which are) commensurable in square\n',
#         ' only. KH is thus as apotome [Prop. 10.73], [and FK\n',
#         'a medial (straight-line) [Prop. 10.93]. Hence, the squareroot of LHùthat is to say, (of) ECùis a second apotome\n',
#         'a sixth apotome is that (straight-line) which with a medial (area) makes a medial whole [Prop. 10.96]. Thus,\n'],
#        dtype='<U276'),
#  '[Prop 10.111]': array([', ,apotome, DE is a first apotome [Prop. 10.97]. Let EF\n',
#         '. DE is thus a first binomial [Prop. 10.60]. Let (DE) have\n',
#         '. is also commensurable in length with DG [Prop. 10.12].\n',
#         'DF [Prop. 10.15]. [Therefore, since DF is commensurable with GF, and DF is rational, GF is thus also rational. Therefore, since DF is commensurable in length\n',
#         '[Prop. 10.13]. GF and FE [are] thus rational (straightlines which are) commensurable in square only. Thus,\n',
#         'EG is an apotome [Prop. 10.73]. But, (it is) also rational. The very thing is impossible.\n',
#         '[P∞risma. [Corollary]\n',
#         ', [Prop. 10.22]. And the (square) on an apotome, ap,plied to a rational (straight-line), produces as breadth a\n',
#         '- first apotome [Prop. 10.97]. And the (square) on a first\n',
#         ' ,[Prop. 10.98]. And the (square) on a second apotome of\n',
#         '- a medial (straight-line), applied to a rational (straight .line), produces as breadth a third apotome [Prop. 10.99].\n',
#         ' , , , And (square) on a minor (straight-line), applied to a ra , , , tional (straight-line), produces as breadth a fourth apo.tome [Prop. 10.100]. And (square) on that (straight-line)\n',
#         ' , a fifth apotome [Prop. 10.101]. And (square) on that\n',
#         ',medial whole, applied to a rational (straight-line), pro , duces as breadth a sixth apotome [Prop. 10.102]. There, fore, since the aforementioned breadths differ from the\n',
#         'as a binomial [Prop. 10.111], and (that) the (irrational\n'],
#        dtype='<U276'),
#  '[Prop 10.112]': array([',.(is) to EF [Prop. 6.16]. And CB (is) greater than BD.\n',
#         ' , Thus, G is also greater than EF [Props. 5.16, 5.14]. Let\n',
#         '., to FE [Prop. 5.17]. Let it have been contrived that as\n',
#         ',, , , the following [Prop. 5.12]. And as FK (is) to KE, so CD\n',
#         '. . is to DB [Prop. 5.11]. And, thus, as HK (is) to KF, so\n',
#         '.CD is to DB [Prop. 5.11]. And the (square) on CD (is)\n',
#         ', ,commensurable with the (square) on DB [Prop. 10.36].\n',
#         ' the (square) on KF [Props. 6.22, 10.11]. And as the\n',
#         ', , in length with KE [Prop. 10.11]. Hence, HE is also com. .mensurable in length with EK [Prop. 10.15]. And since\n',
#         ' [], [Prop. 10.20]. And, hence, the (straight-line) commensu. rable (in length) with it, EK, is also rational [Def. 10.3],\n',
#         ', , and commensurable in length with BD [Prop. 10.12].\n',
#         ' CD and DB are (straight-lines which are) commensu,rable in square only, FK and KE are also commensu . rable in square only [Prop. 10.11]. And KE is rational.\n',
#         ' , , Thus, EF is an apotome [Prop. 10.73].\n',
#         'commensurable (in length) with [CD] then the square\n',
#         'length) with (FK) [Prop. 10.14]. And if CD is commensurable in length with a (previously) laid down rational (straight-line), (so) also (is) FK [Props. 10.11,\n',
#         'KE [Prop. 10.12]. And if neither of CD or DB (is commensurable), neither also (are) either of FK or KE.\n',
#         '(in length) with (FK) [Prop. 10.14]. And if CD is commensurable in length with a (previously) laid down rational (straight-line), (so) also (is) FK [Props. 10.11,\n',
#         '[Prop. 10.12]. And if neither of CD or DB (is commensurable), neither also (are) either of FK or KE. Hence,\n'],
#        dtype='<U276'),
#  '[Prop 10.113]': array([' , . CD are rational (straight-lines which are) commensu rable in square only [Prop. 10.73]. And let the (rectangle\n',
#         ', with BC [Prop. 10.20]. Therefore, since the (rectangle\n',
#         ',[]. BD, so KH (is) to G [Prop. 6.16]. And BC (is) greater\n',
#         ',[], than BD. Thus, KH (is) also greater than G [Prop. 5.16,\n',
#         ' , to CD, so KH (is) to HE [Prop. 5.19 corr.]. Let it have\n',
#         ' , to HEùthat is to say, [as] BC (is) to CD [Prop. 5.19].\n',
#         ' .[Prop. 10.11]. And since as KH is to HE, (so) KF (is)\n',
#         ' ,, . also as KF (is) to FH, (so) HF (is) to FE [Prop. 5.11].\n',
#         ' , commensurable in square. Thus, KF is also commensu. rable in length with FE [Prop. 10.11]. Hence, KF [is]\n',
#         ', , also commensurable in length with KE [Prop. 10.15].\n',
#         ' length with BC [Prop. 10.12]. And since as BC is to\n',
#         ' .so DC (is) to FH [Prop. 5.16]. And BC (is) commen , ,, ,surable (in length) with KF. Thus, FH (is) also com , , , . mensurable in length with CD [Prop. 10.11]. And BC\n',
#         '[Prop. 10.36].\n',
#         'length) with (KF) [Prop. 10.14]. And if BC is commensurable in length with a (previously) laid down rational (straight-line), (so) also (is) KF [Prop. 10.12].\n',
#         'FH [Prop. 10.12]. And if neither of BC or CD (are\n',
#         '[Prop. 10.13].\n',
#         '(in length) with (KF) [Prop. 10.14]. And if BC is commensurable in length with a (previously) laid down rational (straight-line), (so) also (is) KF [Prop. 10.12]. And\n',
#         'if CD is commensurable, (so) also (is) FH [Prop. 10.12].\n',
#         'And if neither of BC or CD (are commensurable), neither also (are) either of KF or FH [Prop. 10.13].\n'],
#        dtype='<U276'),
#  '[Prop 10.114]': array([' .[Prop. 10.112]. But, CE and ED are also commensu.rable with AF and FB (respectively), and in the same ra , , tio. Thus, as AF is to FB, so KM (is) to ML. Thus, alter , nately, as AF is to KM, so BF (is) to LM [Prop. 5.16].\n',
#         ', AF (is) to KM [Prop. 5.19]. And AF (is) commensu. ,rable with KM [Prop. 10.12]. AB is thus also commen. surable with KL [Prop. 10.11]. And as AB is to KL,\n',
#         '., . (rectangle contained) by CD and KL [Prop. 6.1]. Thus,\n',
#         ', KL [Prop. 10.11]. And the (rectangle contained) by CD\n'],
#        dtype='<U276'),
#  '[Prop 10.115]': array(['(straight-line) is irrational [Prop. 10.20]. And (C is) not\n'],
#        dtype='<U276')}

# %% [markdown]
# Each proposition cleaning

# %%
# %%writefile functions.py

def has_ref(string):
    """
    It finds whether the string has reference in itself.
    """
    return 'Prop.' in string or 'C.N.' in string or 'Post.' in string or 'Def.' in string

def remove_refs_detail(refs_list):
    """
    Deletes lemas and corollaries in refernce names.
    like: '[Prop. 5.19 corr.]'
    """
    for i in range(len(refs_list)):
        sec_space_index = refs_list[i].replace(' ', '#', 1).find(' ')
        refs_list[i] = refs_list[i][:sec_space_index] + ']'
    return refs_list

def std_ref_form(ref_string):
    """
    input: '[ ... ]' kind string
    Deletes unnecessary chars from the string.
    Seperates combined references.
    returns the refernces in a list.
    """
    if ',' not in ref_string: #Single ref
        refs_list = [ref_string]
    else: #twice refs.
        comma_index = ref_string.find(',')
        if has_ref(ref_string[comma_index:]):
            #seperate refs
            ref_string = ref_string.replace(', ',']#[')
            refs_list = ref_string.split('#')
        else:
            #copy the ref name
            first_point = ref_string.find('.')
            second_ref = ref_string[:first_point+1] + ref_string[comma_index+1:]
            first_ref = ref_string[:comma_index]+']'
            refs_list = [first_ref, second_ref]
        
#     if ' corr.' in ref_string:
#         ref_string = ref_string.replace(' corr.','')
    
#     while ',' in ref_string:
#         comma_index = ref_string.find(', ')
#         if ref_string[comma_index+2].isnumeric(): #combined referenced with same type [Prop. 10.4, 10.6]
#             space_index = ref_string.find(' ')
#             if has_ref(ref_string[:space_index+1]):
#                 ref_string = ref_string.replace(', ',','+ ref_string[1:space_index])
#         ref_string = ref_string.replace(',',']#[')
#         ref_string = ref_string.replace(', ',']#[')
    
#     refs_list = ref_string.split('#')
    refs_list = remove_refs_detail(refs_list)
    return refs_list

def correct_left_unclosed_bras_inline(line):
    """
    corrects the unclosed brackets.
    means correct case: '[  [ ]' -> '[  ]#[ ]'
    it suffice not to correct right open ones because we start our search for references with '[' and not with ']'
    """
    return line.replace('[',']#[')

def proposition_cleaner(lines):
    """
    Lines is a list of strings dedicated to each propositon proof.
    This function should return its referenced notions in a single list of name strings.
    """
    ref_names = []
    for line_num in range(len(lines)):
        lines[line_num] = correct_left_unclosed_bras_inline(lines[line_num])
        
        for i in range(len(lines[line_num])):
            if lines[line_num][i] == '[':
                end_ref = lines[line_num][i:].find(']') + i
                if has_ref(lines[line_num][i:end_ref + 1]): #check if it has info.
                    ref_names.extend(std_ref_form(lines[line_num][i: end_ref + 1])) #put the standard refs. in the list.
    
    while '[]' in ref_names:
        ref_names.remove('[]')
    
    return ref_names

# %%
# from functions import proposition_cleaner
proposition_cleaner(desired_book_propos_dict['[Prop 10.113]'])
# Out:
# ['[Prop. 10.73]',
#  '[Prop. 10.20]',
#  '[Prop. 6.16]',
#  '[Prop. 5.19]',
#  '[Prop. 5.19]',
#  '[Prop. 10.11]',
#  '[Prop. 5.11]',
#  '[Prop. 10.11]',
#  '[Prop. 10.15]',
#  '[Prop. 10.12]',
#  '[Prop. 5.16]',
#  '[Prop. 10.11]',
#  '[Prop. 10.36]',
#  '[Prop. 10.14]',
#  '[Prop. 10.12]',
#  '[Prop. 10.12]',
#  '[Prop. 10.13]',
#  '[Prop. 10.14]',
#  '[Prop. 10.12]',
#  '[Prop. 10.12]',
#  '[Prop. 10.13]']

# %%
for key in desired_book_propos_dict.keys():
    desired_book_propos_dict[key] = proposition_cleaner(desired_book_propos_dict[key])
desired_book_propos_dict
# Out:
# {'[Prop 10.1]': [],
#  '[Prop 10.2]': [],
#  '[Prop 10.3]': ['[Prop. 10.2]'],
#  '[Prop 10.4]': ['[Prop. 10.3]',
#   '[Prop. 10.3]',
#   '[Prop. 10.3]',
#   '[Prop. 10.3]',
#   '[Prop. 10.3]'],
#  '[Prop 10.5]': ['[Prop. 5.7]', '[Prop. 5.22]'],
#  '[Prop 10.6]': ['[Prop. 5.7]',
#   '[Prop. 5.22]',
#   '[Prop. 5.11]',
#   '[Prop. 5.9]',
#   '[Prop. 6.19]'],
#  '[Prop 10.7]': ['[Prop. 10.6]'],
#  '[Prop 10.8]': ['[Prop. 10.5]'],
#  '[Prop 10.9]': ['[Prop. 10.5]',
#   '[Prop. 6.20]',
#   '[Prop. 8.11]',
#   '[Prop. 8.11]',
#   '[Prop. 10.6]'],
#  '[Prop 10.10]': ['[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 6.13]',
#   '[Prop. 10.11]'],
#  '[Prop 10.11]': ['[Prop. 10.5]',
#   '[Prop. 10.6]',
#   '[Prop. 10.7]',
#   '[Prop. 10.8]'],
#  '[Prop 10.12]': ['[Prop. 10.5]',
#   '[Prop. 10.5]',
#   '[Prop. 8.4]',
#   '[Prop. 5.11]',
#   '[Prop. 5.11]',
#   '[Prop. 5.22]',
#   '[Prop. 10.6]'],
#  '[Prop 10.13]': ['[Prop. 10.12]',
#   '[Prop. 4.1]',
#   '[Prop. 3.31]',
#   '[Prop. 1.47]',
#   '[Prop. 1.47]'],
#  '[Prop 10.14]': ['[Prop. 6.22]',
#   '[Prop. 5.17]',
#   '[Prop. 6.22]',
#   '[Prop. 5.7]',
#   '[Prop. 5.22]',
#   '[Prop. 10.11]'],
#  '[Prop 10.15]': [],
#  '[Prop 10.16]': [],
#  '[Prop 10.17]': ['[Prop. 1.3]',
#   '[Prop. 2.5]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.12]',
#   '[Prop. 10.15]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.12]',
#   '[Prop. 10.15]'],
#  '[Prop 10.18]': ['[Prop. 10.16]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.16]',
#   '[Prop. 10.16]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.16]'],
#  '[Prop 10.19]': ['[Prop. 6.1]', '[Prop. 10.11]'],
#  '[Prop 10.20]': ['[Prop. 6.1]', '[Prop. 10.11]'],
#  '[Prop 10.21]': ['[Prop. 6.1]', '[Prop. 10.11]', '[Prop. 6.1]'],
#  '[Prop 10.22]': ['[Prop. 10.21]',
#   '[Prop. 6.14]',
#   '[Prop. 6.22]',
#   '[Prop. 10.11]',
#   '[Def. 10.4]',
#   '[Prop. 10.11]',
#   '[Prop. 10.13]',
#   '[Prop. 10.11]'],
#  '[Prop 10.23]': ['[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Def. 10.3]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]'],
#  '[Prop 10.24]': ['[Prop. 10.23]'],
#  '[Prop 10.25]': ['[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.19]',
#   '[Prop. 6.1]',
#   '[Prop. 6.17]',
#   '[Prop. 10.19]',
#   '[Prop. 10.21]'],
#  '[Prop 10.26]': ['[Prop. 10.22]',
#   '[Prop. 10.20]',
#   '[Prop. 10.13]',
#   '[Prop. 10.13]',
#   '[Prop. 10.11]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 2.4]',
#   '[Prop. 10.16]'],
#  '[Prop 10.27]': ['[Prop. 6.13]',
#   '[Prop. 6.12]',
#   '[Prop. 6.17]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 5.16]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]'],
#  '[Prop 10.28]': ['[Prop. 6.13]',
#   '[Prop. 6.12]',
#   '[Prop. 6.17]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 5.16]',
#   '[Prop. 6.16]',
#   '[Prop. 10.21]',
#   '[Prop. 2.6]',
#   '[Prop. 9.1]',
#   '[Prop. 2.6]',
#   '[Prop. 2.6]'],
#  '[Prop 10.29]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.9]',
#   '[Prop. 1.47]'],
#  '[Prop 10.30]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 1.47]'],
#  '[Prop 10.31]': ['[Prop. 10.29]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.14]',
#   '[Prop. 10.30]'],
#  '[Prop 10.32]': ['[Prop. 10.29]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.14]',
#   '[Prop. 10.21]',
#   '[Prop. 10.30]',
#   '[Prop. 6.8]',
#   '[Prop. 6.4]',
#   '[Prop. 6.17]',
#   '[Prop. 6.8]',
#   '[Prop. 6.17]',
#   '[Prop. 6.4]',
#   '[Prop. 6.16]'],
#  '[Prop 10.33]': ['[Prop. 10.30]',
#   '[Prop. 6.28]',
#   '[Prop. 10.18]',
#   '[Prop. 10.32]',
#   '[Prop. 10.11]',
#   '[Prop. 1.47]',
#   '[Prop. 10.6]',
#   '[Prop. 10.21]',
#   '[Prop. 10.23]',
#   '[Prop. 10.32]'],
#  '[Prop 10.34]': ['[Prop. 10.31]',
#   '[Prop. 6.28]',
#   '[Prop. 10.18]',
#   '[Prop. 10.11]',
#   '[Prop. 10.32]',
#   '[Prop. 10.6]',
#   '[Def. 10.4]',
#   '[Prop. 10.32]'],
#  '[Prop 10.35]': ['[Prop. 10.32]',
#   '[Prop. 10.18]',
#   '[Prop. 10.11]',
#   '[Prop. 10.32]',
#   '[Prop. 10.13]',
#   '[Prop. 10.11]',
#   '[Prop. 1.47]'],
#  '[Prop 10.36]': ['[Prop. 10.11]',
#   '[Prop. 10.6]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 2.4]',
#   '[Prop. 10.16]'],
#  '[Prop 10.37]': ['[Prop. 2.4]', '[Prop. 10.16]'],
#  '[Prop 10.38]': ['[Prop. 10.28]',
#   '[Prop. 1.44]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.20]'],
#  '[Prop 10.39]': ['[Prop. 10.33]', '[Prop. 2.4]', '[Prop. 10.16]'],
#  '[Prop 10.40]': ['[Prop. 10.34]', '[Prop. 10.16]'],
#  '[Prop 10.41]': ['[Prop. 10.35]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.36]',
#   '[Prop. 2.5]',
#   '[Prop. 2.5]'],
#  '[Prop 10.42]': ['[Prop. 10.36]',
#   '[Prop. 2.4]',
#   '[Prop. 10.21]',
#   '[Prop. 10.26]'],
#  '[Prop 10.43]': ['[Prop. 10.37]', '[Prop. 10.41]', '[Prop. 10.26]'],
#  '[Prop 10.44]': ['[Prop. 10.38]',
#   '[Prop. 10.41]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.42]',
#   '[Prop. 10.59]',
#   '[Prop. 6.1]'],
#  '[Prop 10.45]': ['[Prop. 10.39]', '[Prop. 10.26]'],
#  '[Prop 10.46]': ['[Prop. 10.40]', '[Prop. 10.26]'],
#  '[Prop 10.47]': ['[Prop. 10.41]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.36]',
#   '[Prop. 10.42]'],
#  '[Prop 10.48]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.85]'],
#  '[Prop 10.49]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.86]'],
#  '[Prop 10.50]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.87]'],
#  '[Prop 10.51]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.88]'],
#  '[Prop 10.52]': ['[Prop. 10.38]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.7]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.89]'],
#  '[Prop 10.53]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.90]',
#   '[Prop. 1.34]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 5.18]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]'],
#  '[Prop 10.54]': ['[Prop. 2.14]',
#   '[Prop. 10.53]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 10.15]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]'],
#  '[Prop 10.55]': ['[Prop. 10.17]',
#   '[Prop. 10.53]',
#   '[Prop. 10.13]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.13]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.37]'],
#  '[Prop 10.56]': ['[Prop. 10.13]', '[Prop. 10.21]'],
#  '[Prop 10.57]': ['[Prop. 10.18]',
#   '[Prop. 10.19]',
#   '[Prop. 10.13]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.39]'],
#  '[Prop 10.58]': ['[Prop. 10.18]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.40]'],
#  '[Prop 10.59]': ['[Prop. 10.21]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.41]',
#   '[Prop. 2.5]',
#   '[Prop. 2.9]'],
#  '[Prop 10.60]': ['[Prop. 2.4]',
#   '[Prop. 10.36]',
#   '[Prop. 10.15]',
#   '[Prop. 10.20]',
#   '[Prop. 10.21]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.53]',
#   '[Prop. 6.1]',
#   '[Prop. 6.17]',
#   '[Prop. 10.59]',
#   '[Prop. 10.17]'],
#  '[Prop 10.61]': ['[Prop. 10.37]',
#   '[Prop. 10.21]',
#   '[Prop. 10.22]',
#   '[Prop. 10.20]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.59]',
#   '[Prop. 6.1]',
#   '[Prop. 10.17]'],
#  '[Prop 10.62]': ['[Prop. 10.38]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.17]'],
#  '[Prop 10.63]': ['[Prop. 10.39]',
#   '[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.18]'],
#  '[Prop 10.64]': ['[Prop. 10.40]',
#   '[Prop. 10.22]',
#   '[Prop. 10.20]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.18]'],
#  '[Prop 10.65]': ['[Prop. 10.41]',
#   '[Prop. 10.22]',
#   '[Prop. 10.36]',
#   '[Prop. 10.18]'],
#  '[Prop 10.66]': ['[Prop. 10.36]',
#   '[Prop. 6.12]',
#   '[Prop. 10.11]',
#   '[Prop. 5.11]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]'],
#  '[Prop 10.67]': ['[Prop. 6.12]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]'],
#  '[Prop 10.68]': ['[Prop. 10.39]',
#   '[Prop. 5.11]',
#   '[Prop. 10.11]',
#   '[Prop. 5.16]',
#   '[Prop. 5.18]',
#   '[Prop. 6.20]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.39]'],
#  '[Prop 10.69]': ['[Prop. 10.40]', '[Prop. 10.40]'],
#  '[Prop 10.70]': ['[Prop. 10.41]', '[Prop. 10.41]'],
#  '[Prop 10.71]': ['[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 10.54]',
#   '[Prop. 10.57]',
#   '[Prop. 10.55]',
#   '[Prop. 10.58]'],
#  '[Prop 10.72]': ['[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.56]',
#   '[Prop. 10.59]',
#   '[Prop. 10.22]',
#   '[Prop. 10.60]',
#   '[Prop. 10.61]',
#   '[Prop. 10.62]',
#   '[Prop. 10.63]',
#   '[Prop. 10.64]',
#   '[Prop. 10.65]'],
#  '[Prop 10.73]': ['[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 2.7]'],
#  '[Prop 10.74]': ['[Prop. 10.27]', '[Prop. 2.7]', '[Prop. 10.16]'],
#  '[Prop 10.75]': ['[Prop. 10.28]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.23]',
#   '[Prop. 10.22]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.20]'],
#  '[Prop 10.76]': ['[Prop. 10.33]'],
#  '[Prop 10.77]': ['[Prop. 10.34]'],
#  '[Prop 10.78]': ['[Prop. 10.35]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.20]'],
#  '[Prop 10.79]': ['[Prop. 10.73]',
#   '[Prop. 10.73]',
#   '[Prop. 2.7]',
#   '[Prop. 10.21]',
#   '[Prop. 10.26]'],
#  '[Prop 10.80]': ['[Prop. 10.74]',
#   '[Prop. 10.74]',
#   '[Prop. 2.7]',
#   '[Prop. 10.26]'],
#  '[Prop 10.81]': ['[Prop. 10.75]',
#   '[Prop. 10.75]',
#   '[Prop. 2.7]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.23]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.79]'],
#  '[Prop 10.82]': ['[Prop. 10.76]',
#   '[Prop. 10.76]',
#   '[Prop. 2.7]',
#   '[Prop. 10.26]'],
#  '[Prop 10.83]': ['[Prop. 10.77]', '[Prop. 10.77]', '[Prop. 10.26]'],
#  '[Prop 10.84]': ['[Prop. 10.78]',
#   '[Prop. 10.78]',
#   '[Prop. 2.7]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.22]',
#   '[Prop. 10.73]',
#   '[Prop. 10.79]'],
#  '[Prop 10.85]': ['[Prop. 10.28]',
#   '[Prop. 10.6.]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]'],
#  '[Prop 10.86]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]'],
#  '[Prop 10.87]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]'],
#  '[Prop 10.88]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]'],
#  '[Prop 10.89]': ['[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]'],
#  '[Prop 10.90]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]'],
#  '[Prop 10.91]': ['[Prop. 10.73]',
#   '[Prop. 10.17]',
#   '[Prop. 10.15]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 6.26]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]'],
#  '[Prop 10.92]': ['[Prop. 10.73]',
#   '[Prop. 10.17]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.15]',
#   '[Prop. 10.19]',
#   '[Prop. 6.26]',
#   '[Prop. 10.17]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.74]'],
#  '[Prop 10.93]': ['[Prop. 10.73]',
#   '[Prop. 10.17]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 6.26]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 10.75]'],
#  '[Prop 10.94]': ['[Prop. 10.73]',
#   '[Prop. 10.18]',
#   '[Prop. 10.19]',
#   '[Prop. 10.21]',
#   '[Prop. 6.26]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.13]',
#   '[Prop. 1.43]',
#   '[Prop. 10.76]'],
#  '[Prop 10.95]': ['[Prop. 10.73]',
#   '[Prop. 10.18]',
#   '[Prop. 10.21]',
#   '[Prop. 10.19]',
#   '[Prop. 6.26]',
#   '[Prop. 10.77]'],
#  '[Prop 10.96]': ['[Prop. 10.73]',
#   '[Prop. 10.18]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 6.26]',
#   '[Prop. 10.78]'],
#  '[Prop 10.97]': ['[Prop. 10.73]',
#   '[Prop. 2.7]',
#   '[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.17]'],
#  '[Prop 10.98]': ['[Prop. 10.74]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.20]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.21]',
#   '[Prop. 5.11]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]',
#   '[Prop. 10.17]'],
#  '[Prop 10.99]': ['[Prop. 10.75]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]',
#   '[Prop. 10.17]'],
#  '[Prop 10.100]': ['[Prop. 10.76]',
#   '[Prop. 10.20]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]',
#   '[Prop. 10.18]'],
#  '[Prop 10.101]': ['[Prop. 10.77]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.20]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.18]',
#   '[Def. 10.15]'],
#  '[Prop 10.102]': ['[Prop. 10.78]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 10.18]'],
#  '[Prop 10.103]': ['[Prop. 10.73]',
#   '[Prop. 6.12]',
#   '[Prop. 5.12]',
#   '[Prop. 10.11]',
#   '[Prop. 10.13]',
#   '[Prop. 5.16]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]'],
#  '[Prop 10.104]': ['[Prop. 6.12]', '[Prop. 10.21]', '[Prop. 10.23]'],
#  '[Prop 10.105]': ['[Prop. 10.76]',
#   '[Prop. 10.13]',
#   '[Prop. 6.22]',
#   '[Prop. 5.18]',
#   '[Prop. 10.104]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.76]',
#   '[Prop. 10.21]',
#   '[Prop. 10.76]',
#   '[Prop. 10.23]',
#   '[Prop. 10.76]'],
#  '[Prop 10.106]': ['[Prop. 10.77]', '[Prop. 10.77]'],
#  '[Prop 10.107]': ['[Prop. 10.78]', '[Prop. 10.78]'],
#  '[Prop 10.108]': ['[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 10.73]',
#   '[Prop. 10.91]',
#   '[Prop. 10.14]',
#   '[Prop. 10.94]'],
#  '[Prop 10.109]': ['[Prop. 10.13]',
#   '[Prop. 10.73]',
#   '[Prop. 10.92]',
#   '[Prop. 10.95]'],
#  '[Prop 10.110]': ['[Prop. 10.22]',
#   '[Prop. 10.73]',
#   '[Prop. 10.93]',
#   '[Prop. 10.96]'],
#  '[Prop 10.111]': ['[Prop. 10.97]',
#   '[Prop. 10.60]',
#   '[Prop. 10.12]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.73]',
#   '[Prop. 10.22]',
#   '[Prop. 10.97]',
#   '[Prop. 10.98]',
#   '[Prop. 10.99]',
#   '[Prop. 10.100]',
#   '[Prop. 10.101]',
#   '[Prop. 10.102]',
#   '[Prop. 10.111]'],
#  '[Prop 10.112]': ['[Prop. 6.16]',
#   '[Prop. 5.17]',
#   '[Prop. 5.12]',
#   '[Prop. 5.11]',
#   '[Prop. 5.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.20]',
#   '[Def. 10.3]',
#   '[Prop. 10.12]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]'],
#  '[Prop 10.113]': ['[Prop. 10.73]',
#   '[Prop. 10.20]',
#   '[Prop. 6.16]',
#   '[Prop. 5.19]',
#   '[Prop. 5.19]',
#   '[Prop. 10.11]',
#   '[Prop. 5.11]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.12]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]'],
#  '[Prop 10.114]': ['[Prop. 10.112]',
#   '[Prop. 5.16]',
#   '[Prop. 5.19]',
#   '[Prop. 10.12]',
#   '[Prop. 10.11]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]'],
#  '[Prop 10.115]': ['[Prop. 10.20]']}

# %% [markdown]
# # Netwokx comes to the scene

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
first_book_network = nx.DiGraph(desired_book_propos_dict)

# %%
first_book_network.edges()
# Out:
# OutEdgeView([('[Prop 10.3]', '[Prop. 10.2]'), ('[Prop 10.4]', '[Prop. 10.3]'), ('[Prop 10.5]', '[Prop. 5.7]'), ('[Prop 10.5]', '[Prop. 5.22]'), ('[Prop 10.6]', '[Prop. 5.7]'), ('[Prop 10.6]', '[Prop. 5.22]'), ('[Prop 10.6]', '[Prop. 5.11]'), ('[Prop 10.6]', '[Prop. 5.9]'), ('[Prop 10.6]', '[Prop. 6.19]'), ('[Prop 10.7]', '[Prop. 10.6]'), ('[Prop 10.8]', '[Prop. 10.5]'), ('[Prop 10.9]', '[Prop. 10.5]'), ('[Prop 10.9]', '[Prop. 6.20]'), ('[Prop 10.9]', '[Prop. 8.11]'), ('[Prop 10.9]', '[Prop. 10.6]'), ('[Prop 10.10]', '[Prop. 10.6]'), ('[Prop 10.10]', '[Prop. 10.9]'), ('[Prop 10.10]', '[Prop. 6.13]'), ('[Prop 10.10]', '[Prop. 10.11]'), ('[Prop 10.11]', '[Prop. 10.5]'), ('[Prop 10.11]', '[Prop. 10.6]'), ('[Prop 10.11]', '[Prop. 10.7]'), ('[Prop 10.11]', '[Prop. 10.8]'), ('[Prop 10.12]', '[Prop. 10.5]'), ('[Prop 10.12]', '[Prop. 8.4]'), ('[Prop 10.12]', '[Prop. 5.11]'), ('[Prop 10.12]', '[Prop. 5.22]'), ('[Prop 10.12]', '[Prop. 10.6]'), ('[Prop 10.13]', '[Prop. 10.12]'), ('[Prop 10.13]', '[Prop. 4.1]'), ('[Prop 10.13]', '[Prop. 3.31]'), ('[Prop 10.13]', '[Prop. 1.47]'), ('[Prop 10.14]', '[Prop. 6.22]'), ('[Prop 10.14]', '[Prop. 5.17]'), ('[Prop 10.14]', '[Prop. 5.7]'), ('[Prop 10.14]', '[Prop. 5.22]'), ('[Prop 10.14]', '[Prop. 10.11]'), ('[Prop 10.17]', '[Prop. 1.3]'), ('[Prop 10.17]', '[Prop. 2.5]'), ('[Prop 10.17]', '[Prop. 10.15]'), ('[Prop 10.17]', '[Prop. 10.6]'), ('[Prop 10.17]', '[Prop. 10.12]'), ('[Prop 10.18]', '[Prop. 10.16]'), ('[Prop 10.18]', '[Prop. 10.6]'), ('[Prop 10.18]', '[Prop. 10.13]'), ('[Prop 10.19]', '[Prop. 6.1]'), ('[Prop 10.19]', '[Prop. 10.11]'), ('[Prop 10.20]', '[Prop. 6.1]'), ('[Prop 10.20]', '[Prop. 10.11]'), ('[Prop 10.21]', '[Prop. 6.1]'), ('[Prop 10.21]', '[Prop. 10.11]'), ('[Prop 10.22]', '[Prop. 10.21]'), ('[Prop 10.22]', '[Prop. 6.14]'), ('[Prop 10.22]', '[Prop. 6.22]'), ('[Prop 10.22]', '[Prop. 10.11]'), ('[Prop 10.22]', '[Def. 10.4]'), ('[Prop 10.22]', '[Prop. 10.13]'), ('[Prop 10.23]', '[Prop. 10.22]'), ('[Prop 10.23]', '[Prop. 6.1]'), ('[Prop 10.23]', '[Prop. 10.11]'), ('[Prop 10.23]', '[Def. 10.3]'), ('[Prop 10.23]', '[Prop. 10.13]'), ('[Prop 10.23]', '[Prop. 10.21]'), ('[Prop 10.24]', '[Prop. 10.23]'), ('[Prop 10.25]', '[Prop. 10.22]'), ('[Prop 10.25]', '[Prop. 6.1]'), ('[Prop 10.25]', '[Prop. 10.11]'), ('[Prop 10.25]', '[Prop. 10.19]'), ('[Prop 10.25]', '[Prop. 6.17]'), ('[Prop 10.25]', '[Prop. 10.21]'), ('[Prop 10.26]', '[Prop. 10.22]'), ('[Prop 10.26]', '[Prop. 10.20]'), ('[Prop 10.26]', '[Prop. 10.13]'), ('[Prop 10.26]', '[Prop. 10.11]'), ('[Prop 10.26]', '[Prop. 10.6]'), ('[Prop 10.26]', '[Prop. 2.4]'), ('[Prop 10.26]', '[Prop. 10.16]'), ('[Prop 10.27]', '[Prop. 6.13]'), ('[Prop 10.27]', '[Prop. 6.12]'), ('[Prop 10.27]', '[Prop. 6.17]'), ('[Prop 10.27]', '[Prop. 10.21]'), ('[Prop 10.27]', '[Prop. 10.11]'), ('[Prop 10.27]', '[Prop. 10.23]'), ('[Prop 10.27]', '[Prop. 5.16]'), ('[Prop 10.27]', '[Prop. 5.11]'), ('[Prop 10.28]', '[Prop. 6.13]'), ('[Prop 10.28]', '[Prop. 6.12]'), ('[Prop 10.28]', '[Prop. 6.17]'), ('[Prop 10.28]', '[Prop. 10.21]'), ('[Prop 10.28]', '[Prop. 10.11]'), ('[Prop 10.28]', '[Prop. 10.23]'), ('[Prop 10.28]', '[Prop. 5.16]'), ('[Prop 10.28]', '[Prop. 6.16]'), ('[Prop 10.28]', '[Prop. 2.6]'), ('[Prop 10.28]', '[Prop. 9.1]'), ('[Prop 10.29]', '[Prop. 10.6]'), ('[Prop 10.29]', '[Prop. 10.9]'), ('[Prop 10.29]', '[Prop. 1.47]'), ('[Prop 10.30]', '[Prop. 10.28]'), ('[Prop 10.30]', '[Prop. 10.6]'), ('[Prop 10.30]', '[Prop. 10.9]'), ('[Prop 10.30]', '[Prop. 1.47]'), ('[Prop 10.31]', '[Prop. 10.29]'), ('[Prop 10.31]', '[Prop. 10.21]'), ('[Prop 10.31]', '[Prop. 10.11]'), ('[Prop 10.31]', '[Prop. 10.23]'), ('[Prop 10.31]', '[Prop. 10.14]'), ('[Prop 10.31]', '[Prop. 10.30]'), ('[Prop 10.32]', '[Prop. 10.29]'), ('[Prop 10.32]', '[Prop. 10.21]'), ('[Prop 10.32]', '[Prop. 10.11]'), ('[Prop 10.32]', '[Prop. 10.23]'), ('[Prop 10.32]', '[Prop. 10.14]'), ('[Prop 10.32]', '[Prop. 10.30]'), ('[Prop 10.32]', '[Prop. 6.8]'), ('[Prop 10.32]', '[Prop. 6.4]'), ('[Prop 10.32]', '[Prop. 6.17]') ...

# %%
nx.draw(first_book_network)

# %%
plt.hist(dict(first_book_network.degree()).values())
# Out:
# (array([131.,  56.,  33.,   8.,   1.,   0.,   4.,   0.,   2.,   1.]),
#  array([ 0. ,  4.5,  9. , 13.5, 18. , 22.5, 27. , 31.5, 36. , 40.5, 45. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Cleaning all the books

# %%
# %%writefile -a functions.py

def book_to_props_dict(book_num,book_lines):
    """
    This function will extract the propositions of given book and return them in one dictionary.
    """
    lines_mask = [False]*len(book_lines)
    for i in range(len(book_lines)):
        lines_mask[i] = '[P' in book_lines[i] or '[C' in book_lines[i] or '[D' in book_lines[i] or 'Proposition' in book_lines[i]
    book_lines = book_lines[lines_mask]
    
    props_num = 1
    props_index = []
    for i in range(len(book_lines)):
        if 'Proposition' in book_lines[i]:
            props_index.append(i)
            book_lines[i] = 'Proposition '+ str(props_num)
            props_num+=1
    
    book_lines_propos_dict = {}
    props_titles = [ '[Prop. {}.{}]'.format(book_num,i) for i in range(1,len(props_index)+1) ]
    book_lines_propos_dict = { x:[] for x in props_titles }
    props_index.append(-1)
    
    for i in range(len(props_index)-1):
        book_lines_propos_dict[props_titles[i]] = book_lines[ props_index[i]+1:props_index[i+1] ]
    
    for key in book_lines_propos_dict.keys():
        book_lines_propos_dict[key] = proposition_cleaner(book_lines_propos_dict[key])
    
    return book_lines_propos_dict

# %%
# from functions import book_to_props_dict

book_to_props_dict(10,book_glossary['ELEMENTS BOOK 10\n'])
# Out:
# {'[Prop. 10.1]': ['[Def. 5.4]'],
#  '[Prop. 10.2]': ['[Def. 10.1]'],
#  '[Prop. 10.3]': ['[Prop. 10.2]'],
#  '[Prop. 10.4]': ['[Prop. 10.3]',
#   '[Prop. 10.3]',
#   '[Def. 10.1]',
#   '[Prop. 10.3]',
#   '[Prop. 10.3]',
#   '[Prop. 10.3]'],
#  '[Prop. 10.5]': ['[Def. 7.20]', '[Prop. 5.7]', '[Def. 7.20]', '[Prop. 5.22]'],
#  '[Prop. 10.6]': ['[Def. 7.20]',
#   '[Prop. 5.7]',
#   '[Def. 7.20]',
#   '[Prop. 5.22]',
#   '[Prop. 5.11]',
#   '[Prop. 5.9]',
#   '[Def. 10.1]',
#   '[Prop. 6.19]'],
#  '[Prop. 10.7]': ['[Prop. 10.6]'],
#  '[Prop. 10.8]': ['[Prop. 10.5]'],
#  '[Prop. 10.9]': ['[Prop. 10.5]',
#   '[Prop. 6.20]',
#   '[Prop. 8.11]',
#   '[Prop. 8.11]',
#   '[Prop. 10.6]'],
#  '[Prop. 10.10]': ['[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 6.13]',
#   '[Def. 5.9]',
#   '[Prop. 10.11]'],
#  '[Prop. 10.11]': ['[Prop. 10.5]',
#   '[Prop. 10.6]',
#   '[Prop. 10.7]',
#   '[Prop. 10.8]'],
#  '[Prop. 10.12]': ['[Prop. 10.5]',
#   '[Prop. 10.5]',
#   '[Prop. 8.4]',
#   '[Prop. 5.11]',
#   '[Prop. 5.11]',
#   '[Prop. 5.22]',
#   '[Prop. 10.6]'],
#  '[Prop. 10.13]': ['[Prop. 10.12]',
#   '[Prop. 4.1]',
#   '[Prop. 3.31]',
#   '[Prop. 1.47]',
#   '[Prop. 1.47]'],
#  '[Prop. 10.14]': ['[Prop. 6.22]',
#   '[Prop. 5.17]',
#   '[Prop. 6.22]',
#   '[Prop. 5.7]',
#   '[Prop. 5.22]',
#   '[Prop. 10.11]'],
#  '[Prop. 10.15]': ['[Def. 10.1]', '[Def. 10.1]'],
#  '[Prop. 10.16]': ['[Def. 10.1]', '[Def. 10.1]', '[Def. 10.1]', '[Def. 10.1]'],
#  '[Prop. 10.17]': ['[Prop. 1.3]',
#   '[Prop. 2.5]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.12]',
#   '[Prop. 10.15]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.12]',
#   '[Prop. 10.15]'],
#  '[Prop. 10.18]': ['[Prop. 10.16]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.16]',
#   '[Prop. 10.16]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.16]'],
#  '[Prop. 10.19]': ['[Def. 10.4]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Def. 10.4]'],
#  '[Prop. 10.20]': ['[Def. 10.4]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Def. 10.3]'],
#  '[Prop. 10.21]': ['[Def. 10.4]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Def. 10.4]',
#   '[Def. 10.4]',
#   '[Prop. 6.1]'],
#  '[Prop. 10.22]': ['[Prop. 10.21]',
#   '[Prop. 6.14]',
#   '[Prop. 6.22]',
#   '[Prop. 10.11]',
#   '[Def. 10.4]',
#   '[Prop. 10.11]',
#   '[Prop. 10.13]',
#   '[Prop. 10.11]'],
#  '[Prop. 10.23]': ['[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Def. 10.3]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]'],
#  '[Prop. 10.24]': ['[Prop. 10.23]'],
#  '[Prop. 10.25]': ['[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.19]',
#   '[Prop. 6.1]',
#   '[Prop. 6.17]',
#   '[Prop. 10.19]',
#   '[Prop. 10.21]'],
#  '[Prop. 10.26]': ['[Prop. 10.22]',
#   '[Prop. 10.20]',
#   '[Prop. 10.13]',
#   '[Prop. 10.13]',
#   '[Prop. 10.11]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 2.4]',
#   '[Prop. 10.16]',
#   '[Def. 10.4]',
#   '[Def. 10.4]'],
#  '[Prop. 10.27]': ['[Prop. 6.13]',
#   '[Prop. 6.12]',
#   '[Prop. 6.17]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 5.16]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]'],
#  '[Prop. 10.28]': ['[Prop. 6.13]',
#   '[Prop. 6.12]',
#   '[Prop. 6.17]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 5.16]',
#   '[Prop. 6.16]',
#   '[Prop. 10.21]',
#   '[Prop. 2.6]',
#   '[Prop. 9.1]',
#   '[Prop. 2.6]',
#   '[Prop. 2.6]'],
#  '[Prop. 10.29]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Def. 10.4]',
#   '[Prop. 10.9]',
#   '[Prop. 10.9]',
#   '[Prop. 1.47]'],
#  '[Prop. 10.30]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 1.47]'],
#  '[Prop. 10.31]': ['[Prop. 10.29]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.14]',
#   '[Prop. 10.30]'],
#  '[Prop. 10.32]': ['[Prop. 10.29]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.14]',
#   '[Prop. 10.21]',
#   '[Prop. 10.30]',
#   '[Prop. 6.8]',
#   '[Prop. 6.4]',
#   '[Prop. 6.17]',
#   '[Prop. 6.8]',
#   '[Prop. 6.17]',
#   '[Prop. 6.4]',
#   '[Prop. 6.16]'],
#  '[Prop. 10.33]': ['[Prop. 10.30]',
#   '[Prop. 6.28]',
#   '[Prop. 10.18]',
#   '[Prop. 10.32]',
#   '[Prop. 10.11]',
#   '[Prop. 1.47]',
#   '[Prop. 10.6]',
#   '[Prop. 10.21]',
#   '[Prop. 10.23]',
#   '[Prop. 10.32]'],
#  '[Prop. 10.34]': ['[Prop. 10.31]',
#   '[Prop. 6.28]',
#   '[Prop. 10.18]',
#   '[Prop. 10.11]',
#   '[Prop. 10.32]',
#   '[Prop. 10.6]',
#   '[Def. 10.4]',
#   '[Prop. 10.32]'],
#  '[Prop. 10.35]': ['[Prop. 10.32]',
#   '[Prop. 10.18]',
#   '[Prop. 10.11]',
#   '[Prop. 10.32]',
#   '[Prop. 10.13]',
#   '[Prop. 10.11]',
#   '[Prop. 1.47]'],
#  '[Prop. 10.36]': ['[Prop. 10.11]',
#   '[Prop. 10.6]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 2.4]',
#   '[Prop. 10.16]',
#   '[Def. 10.4]',
#   '[Def. 10.4]'],
#  '[Prop. 10.37]': ['[Prop. 2.4]', '[Prop. 10.16]', '[Def. 10.4]'],
#  '[Prop. 10.38]': ['[Prop. 10.28]',
#   '[Prop. 1.44]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.20]',
#   '[Def. 10.4]'],
#  '[Prop. 10.39]': ['[Prop. 10.33]',
#   '[Def. 10.4]',
#   '[Prop. 2.4]',
#   '[Prop. 10.16]',
#   '[Def. 10.4]'],
#  '[Prop. 10.40]': ['[Prop. 10.34]', '[Prop. 10.16]', '[Def. 10.4]'],
#  '[Prop. 10.41]': ['[Prop. 10.35]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.36]',
#   '[Def. 10.4]',
#   '[Prop. 2.5]',
#   '[Prop. 2.5]'],
#  '[Prop. 10.42]': ['[Prop. 10.36]',
#   '[Prop. 2.4]',
#   '[Prop. 10.21]',
#   '[Prop. 10.26]'],
#  '[Prop. 10.43]': ['[Prop. 10.37]', '[Prop. 10.41]', '[Prop. 10.26]'],
#  '[Prop. 10.44]': ['[Prop. 10.38]',
#   '[Prop. 10.41]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.42]',
#   '[Prop. 10.59]',
#   '[Prop. 6.1]'],
#  '[Prop. 10.45]': ['[Prop. 10.39]', '[Prop. 10.26]'],
#  '[Prop. 10.46]': ['[Prop. 10.40]', '[Prop. 10.26]'],
#  '[Prop. 10.47]': ['[Prop. 10.41]',
#   '[Prop. 2.4]',
#   '[Prop. 10.22]',
#   '[Prop. 10.36]',
#   '[Prop. 10.42]'],
#  '[Prop. 10.48]': ['[Prop. 10.28]',
#   '[Def. 10.3]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.5]',
#   '[Prop. 10.85]'],
#  '[Prop. 10.49]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.86]'],
#  '[Prop. 10.50]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.87]'],
#  '[Prop. 10.51]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.88]'],
#  '[Prop. 10.52]': ['[Prop. 10.38]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.7]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.89]'],
#  '[Prop. 10.53]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.36]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 5.14]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Prop. 10.90]',
#   '[Prop. 1.34]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 5.18]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]'],
#  '[Prop. 10.54]': ['[Def. 10.5]',
#   '[Prop. 2.14]',
#   '[Prop. 10.53]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 10.15]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]'],
#  '[Prop. 10.55]': ['[Def. 10.6]',
#   '[Prop. 10.17]',
#   '[Prop. 10.53]',
#   '[Prop. 10.13]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.13]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.37]'],
#  '[Prop. 10.56]': ['[Def. 10.7]', '[Prop. 10.13]', '[Prop. 10.21]'],
#  '[Prop. 10.57]': ['[Def. 10.8]',
#   '[Prop. 10.18]',
#   '[Prop. 10.19]',
#   '[Prop. 10.13]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.39]'],
#  '[Prop. 10.58]': ['[Prop. 10.18]',
#   '[Def. 10.9]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.40]'],
#  '[Prop. 10.59]': ['[Def. 10.10]',
#   '[Prop. 10.21]',
#   '[Def. 10.10]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.41]',
#   '[Prop. 2.5]',
#   '[Prop. 2.9]'],
#  '[Prop. 10.60]': ['[Prop. 2.4]',
#   '[Prop. 10.36]',
#   '[Prop. 10.15]',
#   '[Prop. 10.20]',
#   '[Prop. 10.21]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.53]',
#   '[Prop. 6.1]',
#   '[Prop. 6.17]',
#   '[Prop. 10.59]',
#   '[Prop. 10.17]'],
#  '[Prop. 10.61]': ['[Prop. 10.37]',
#   '[Prop. 10.21]',
#   '[Prop. 10.22]',
#   '[Prop. 10.20]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.59]',
#   '[Prop. 6.1]',
#   '[Prop. 10.17]'],
#  '[Prop. 10.62]': ['[Prop. 10.38]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.17]'],
#  '[Prop. 10.63]': ['[Prop. 10.39]',
#   '[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.18]'],
#  '[Prop. 10.64]': ['[Prop. 10.40]',
#   '[Prop. 10.22]',
#   '[Prop. 10.20]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.18]',
#   '[Def. 10.9]'],
#  '[Prop. 10.65]': ['[Prop. 10.41]',
#   '[Prop. 10.22]',
#   '[Prop. 10.36]',
#   '[Prop. 10.18]'],
#  '[Prop. 10.66]': ['[Prop. 10.36]',
#   '[Prop. 6.12]',
#   '[Prop. 10.11]',
#   '[Prop. 5.11]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Def. 10.5]',
#   '[Prop. 10.12]',
#   '[Def. 10.6]',
#   '[Prop. 10.13]',
#   '[Def. 10.7]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Def. 10.8]',
#   '[Def. 10.9]',
#   '[Def. 10.10]'],
#  '[Prop. 10.67]': ['[Prop. 6.12]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]'],
#  '[Prop. 10.68]': ['[Prop. 10.39]',
#   '[Prop. 5.11]',
#   '[Prop. 10.11]',
#   '[Prop. 5.16]',
#   '[Prop. 5.18]',
#   '[Prop. 6.20]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.23]',
#   '[Prop. 10.39]'],
#  '[Prop. 10.69]': ['[Prop. 10.40]', '[Prop. 10.40]'],
#  '[Prop. 10.70]': ['[Prop. 10.41]', '[Prop. 10.41]'],
#  '[Prop. 10.71]': ['[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Prop. 5.14]',
#   '[Def. 10.5]',
#   '[Prop. 10.54]',
#   '[Def. 10.8]',
#   '[Prop. 10.57]',
#   '[Def. 10.6]',
#   '[Prop. 10.55]',
#   '[Def. 10.9]',
#   '[Prop. 10.58]'],
#  '[Prop. 10.72]': ['[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.36]',
#   '[Def. 10.7]',
#   '[Prop. 10.56]',
#   '[Def. 10.10]',
#   '[Prop. 10.59]',
#   '[Prop. 10.22]',
#   '[Prop. 10.60]',
#   '[Prop. 10.61]',
#   '[Prop. 10.62]',
#   '[Prop. 10.63]',
#   '[Prop. 10.64]',
#   '[Prop. 10.65]'],
#  '[Prop. 10.73]': ['[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 2.7]',
#   '[Def. 10.4]'],
#  '[Prop. 10.74]': ['[Prop. 10.27]',
#   '[Prop. 2.7]',
#   '[Prop. 10.16]',
#   '[Def. 10.4]'],
#  '[Prop. 10.75]': ['[Prop. 10.28]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.23]',
#   '[Prop. 10.22]',
#   '[Prop. 10.15]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.20]',
#   '[Def. 10.4]'],
#  '[Prop. 10.76]': ['[Prop. 10.33]', '[Def. 10.4]'],
#  '[Prop. 10.77]': ['[Prop. 10.34]', '[Def. 10.4]'],
#  '[Prop. 10.78]': ['[Prop. 10.35]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.20]'],
#  '[Prop. 10.79]': ['[Prop. 10.73]',
#   '[Prop. 10.73]',
#   '[Prop. 2.7]',
#   '[Prop. 10.21]',
#   '[Prop. 10.26]'],
#  '[Prop. 10.80]': ['[Prop. 10.74]',
#   '[Prop. 10.74]',
#   '[Prop. 2.7]',
#   '[Prop. 10.26]'],
#  '[Prop. 10.81]': ['[Prop. 10.75]',
#   '[Prop. 10.75]',
#   '[Prop. 2.7]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.23]',
#   '[Prop. 10.22]',
#   '[Prop. 10.21]',
#   '[Prop. 10.11]',
#   '[Prop. 10.6]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.79]'],
#  '[Prop. 10.82]': ['[Prop. 10.76]',
#   '[Prop. 10.76]',
#   '[Prop. 2.7]',
#   '[Prop. 10.26]'],
#  '[Prop. 10.83]': ['[Prop. 10.77]', '[Prop. 10.77]', '[Prop. 10.26]'],
#  '[Prop. 10.84]': ['[Prop. 10.78]',
#   '[Prop. 10.78]',
#   '[Prop. 2.7]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.22]',
#   '[Prop. 10.73]',
#   '[Prop. 10.79]'],
#  '[Prop. 10.85]': ['[Prop. 10.28]',
#   '[Prop. 10.6.]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.11]'],
#  '[Prop. 10.86]': ['[Prop. 10.28]',
#   '[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.12]'],
#  '[Prop. 10.87]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.13]'],
#  '[Prop. 10.88]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.14]'],
#  '[Prop. 10.89]': ['[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.15]'],
#  '[Prop. 10.90]': ['[Prop. 10.6]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.6]',
#   '[Prop. 10.9]',
#   '[Prop. 10.73]',
#   '[Prop. 5.22]',
#   '[Prop. 10.9]',
#   '[Prop. 10.13]',
#   '[Prop. 5.19]',
#   '[Prop. 10.9]',
#   '[Def. 10.16]'],
#  '[Prop. 10.91]': ['[Prop. 10.73]',
#   '[Def. 10.11]',
#   '[Prop. 10.17]',
#   '[Prop. 10.15]',
#   '[Prop. 10.12]',
#   '[Prop. 10.19]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 6.26]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]'],
#  '[Prop. 10.92]': ['[Prop. 10.73]',
#   '[Def. 10.12]',
#   '[Prop. 10.17]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.15]',
#   '[Prop. 10.19]',
#   '[Prop. 6.26]',
#   '[Prop. 10.17]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.74]'],
#  '[Prop. 10.93]': ['[Prop. 10.73]',
#   '[Def. 10.13]',
#   '[Prop. 10.17]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.21]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 6.26]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.53]',
#   '[Prop. 1.43]',
#   '[Prop. 10.75]'],
#  '[Prop. 10.94]': ['[Prop. 10.73]',
#   '[Def. 10.14]',
#   '[Prop. 10.18]',
#   '[Prop. 10.19]',
#   '[Prop. 10.21]',
#   '[Prop. 6.26]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 10.13]',
#   '[Prop. 1.43]',
#   '[Prop. 10.76]'],
#  '[Prop. 10.95]': ['[Prop. 10.73]',
#   '[Def. 10.15]',
#   '[Prop. 10.18]',
#   '[Prop. 10.21]',
#   '[Prop. 10.19]',
#   '[Prop. 6.26]',
#   '[Prop. 10.77]'],
#  '[Prop. 10.96]': ['[Prop. 10.73]',
#   '[Def. 10.16]',
#   '[Prop. 10.18]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 6.26]',
#   '[Prop. 10.78]'],
#  '[Prop. 10.97]': ['[Prop. 10.73]',
#   '[Prop. 2.7]',
#   '[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 6.17]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.17]',
#   '[Def. 10.15]'],
#  '[Prop. 10.98]': ['[Prop. 10.74]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.20]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.21]',
#   '[Prop. 5.11]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]',
#   '[Prop. 10.17]',
#   '[Def. 10.16]'],
#  '[Prop. 10.99]': ['[Prop. 10.75]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]',
#   '[Prop. 10.17]',
#   '[Def. 10.13]'],
#  '[Prop. 10.100]': ['[Prop. 10.76]',
#   '[Prop. 10.20]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 6.1]',
#   '[Prop. 5.11]',
#   '[Prop. 6.17]',
#   '[Prop. 10.18]',
#   '[Def. 10.14]'],
#  '[Prop. 10.101]': ['[Prop. 10.77]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.20]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.18]',
#   '[Def. 10.15]'],
#  '[Prop. 10.102]': ['[Prop. 10.78]',
#   '[Prop. 10.22]',
#   '[Prop. 2.7]',
#   '[Prop. 10.22]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]',
#   '[Prop. 10.21]',
#   '[Prop. 10.18]',
#   '[Def. 10.16]'],
#  '[Prop. 10.103]': ['[Prop. 10.73]',
#   '[Prop. 6.12]',
#   '[Prop. 5.12]',
#   '[Prop. 10.11]',
#   '[Prop. 10.13]',
#   '[Prop. 5.16]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]'],
#  '[Prop. 10.104]': ['[Prop. 6.12]',
#   '[Prop. 10.21]',
#   '[Def. 10.4]',
#   '[Prop. 10.23]'],
#  '[Prop. 10.105]': ['[Prop. 10.76]',
#   '[Prop. 10.13]',
#   '[Prop. 6.22]',
#   '[Prop. 5.18]',
#   '[Prop. 10.104]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Prop. 10.76]',
#   '[Def. 10.4]',
#   '[Prop. 10.21]',
#   '[Prop. 10.76]',
#   '[Prop. 10.23]',
#   '[Prop. 10.76]'],
#  '[Prop. 10.106]': ['[Prop. 10.77]', '[Prop. 10.77]'],
#  '[Prop. 10.107]': ['[Prop. 10.78]', '[Prop. 10.78]'],
#  '[Prop. 10.108]': ['[Prop. 10.20]',
#   '[Prop. 10.22]',
#   '[Prop. 10.13]',
#   '[Prop. 10.73]',
#   '[Def. 10.1]',
#   '[Prop. 10.91]',
#   '[Prop. 10.14]',
#   '[Prop. 10.94]'],
#  '[Prop. 10.109]': ['[Prop. 10.13]',
#   '[Prop. 10.73]',
#   '[Def. 10.12]',
#   '[Prop. 10.92]',
#   '[Def. 10.15]',
#   '[Prop. 10.95]'],
#  '[Prop. 10.110]': ['[Prop. 10.22]',
#   '[Prop. 10.73]',
#   '[Def. 10.3]',
#   '[Prop. 10.93]',
#   '[Def. 10.16]',
#   '[Prop. 10.96]'],
#  '[Prop. 10.111]': ['[Prop. 10.97]',
#   '[Def. 10.10]',
#   '[Prop. 10.60]',
#   '[Def. 10.5]',
#   '[Prop. 10.12]',
#   '[Prop. 10.15]',
#   '[Prop. 10.13]',
#   '[Prop. 10.73]',
#   '[Prop. 10.22]',
#   '[Prop. 10.97]',
#   '[Prop. 10.98]',
#   '[Prop. 10.99]',
#   '[Prop. 10.100]',
#   '[Prop. 10.101]',
#   '[Prop. 10.102]',
#   '[Prop. 10.111]'],
#  '[Prop. 10.112]': ['[Prop. 6.16]',
#   '[Prop. 5.17]',
#   '[Prop. 5.12]',
#   '[Prop. 5.11]',
#   '[Prop. 5.11]',
#   '[Prop. 10.36]',
#   '[Def. 5.9]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.20]',
#   '[Def. 10.3]',
#   '[Prop. 10.12]',
#   '[Prop. 10.11]',
#   '[Prop. 10.73]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]'],
#  '[Prop. 10.113]': ['[Prop. 10.73]',
#   '[Prop. 10.20]',
#   '[Prop. 6.16]',
#   '[Prop. 5.19]',
#   '[Prop. 5.19]',
#   '[Prop. 10.11]',
#   '[Prop. 5.11]',
#   '[Def. 5.9]',
#   '[Prop. 10.11]',
#   '[Prop. 10.15]',
#   '[Prop. 10.12]',
#   '[Prop. 5.16]',
#   '[Prop. 10.11]',
#   '[Def. 10.3]',
#   '[Prop. 10.13]',
#   '[Prop. 10.36]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]',
#   '[Prop. 10.14]',
#   '[Prop. 10.12]',
#   '[Prop. 10.12]',
#   '[Prop. 10.13]'],
#  '[Prop. 10.114]': ['[Prop. 10.112]',
#   '[Prop. 5.16]',
#   '[Prop. 5.19]',
#   '[Prop. 10.12]',
#   '[Prop. 10.11]',
#   '[Prop. 6.1]',
#   '[Prop. 10.11]'],
#  '[Prop. 10.115]': ['[Def. 10.4]', '[Prop. 10.20]', '[Prop. 10.20]']}

# %% [markdown]
# # Saving the total references

# %%
import pickle
for i in range(1,len(book_glossary.keys())+1):
    a_file = open("books_references_dictionaries/ref_in_book_{}.pkl".format(i), "wb")
    pickle.dump( book_to_props_dict(i,book_glossary['ELEMENTS BOOK {}\n'.format(i)]) , a_file)
    a_file.close()
